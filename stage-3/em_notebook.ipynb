# %% [markdown]
# # Entity matching (EM) for Laptops

# %% [markdown]
# This jupyter notebook contains the commands used for each step in the entity matching process for laptop products from Amazon and Walmart.
# We used the Basic EM workflow 3 as our guide for this process.

# %% [markdown]
# # Step 1: Reading in the input tables A, B.

# %%
import sys
import py_entitymatching as em
import pandas as pd
import os

path_A = 'data/amazon_products.csv'
path_B = 'data/walmart_products.csv'

# Load the csv files as dataframes and set the key attribute in the dataframe
A = em.read_csv_metadata(path_A, key='id')
B = em.read_csv_metadata(path_B, key='id')
print('len(A):' + str(len(A)))
print('len(B):' + str(len(B)))
print('len (A X B):' + str(len(A)*len(B)))
# Out:
# len(A):3000
# len(B):4847
# len (A X B):14541000

# %% [markdown]
# # Step 2: Block tables to get candidate set
#
# In this step, we apply a blocking sequence on the input tables to get the candidate set C.

# %%
# Create an initial blocker
ob = em.OverlapBlocker()

# Use block_tables to apply blocking over two input tables.
C1 = ob.block_tables(A,B, 'model', 'model', 
                     l_output_attrs=['id','model','extended_title'], 
                     r_output_attrs=['id','model','extended_title'],
                     overlap_size=8,
                     q_val=5,
                     word_level=False,
                     show_progress=False,
                     n_jobs=-1
                     )
len(C1)
# Out:
# 2594

# %% [markdown]
# ## Debugging blocker output

# %%
# Debug blocker output
dbg = em.debug_blocker(C1, A, B, 
                        attr_corres=[
                            ('product_title','product_title'),
                            ('brand', 'brand'), 
                            ('model','model'),
                            ('extended_title','extended_title')],
                            verbose=True)
### Display first few tuple pairs from the debug_blocker's output
dbg
# Out:
#      _id ltable_id rtable_id  \
# 0      0      a389     w3337
# 1      1      a389     w3221
# 2      2      a389     w3226
# 3      3     a1838     w3122
# 4      4     a1356     w3178
# 5      5     a1356     w3150
# 6      6      a389     w3335
# 7      7     a1838     w3078
# 8      8     a1356     w3117
# 9      9     a1356     w3179
# 10    10      a888     w3438
# 11    11     a1838     w3121
# 12    12      a389     w3438
# 13    13     a1356     w3149
# 14    14     a1997     w3305
# 15    15      a888     w3286
# 16    16      a888     w3221
# 17    17     a1838     w3336
# 18    18     a1997     w3263
# 19    19     a1356     w3180
# 20    20      a888     w3226
# 21    21     a1997     w3059
# 22    22      a389     w3071
# 23    23     a1356     w3223
# 24    24     a1838     w3077
# 25    25     a1997     w3063
# 26    26     a1997     w3381
# 27    27     a1997     w3257
# 28    28     a1356     w3225
# 29    29      a438     w1808
# ..   ...       ...       ...
# 170  170      a389     w3151
# 171  171     a1838     w3176
# 172  172      a888     w3151
# 173  173     a1838     w3072
# 174  174      a888     w3288
# 175  175     a2104     w2951
# 176  176     a2490      w344
# 177  177     a2104     w3055
# 178  178      a389     w3223
# 179  179      a389     w3116
# 180  180      a888     w3222
# 181  181      a888     w3177
# 182  182     a2773     w4444
# 183  183     a1838     w3181
# 184  184       a40      w978
# 185  185     a1107     w4162
# 186  186     a1356     w3224
# 187  187     a1356     w3335
# 188  188     a1356     w3337
# 189  189     a1602      w742
# 190  190     a1602     w1264
# 191  191     a2110      w734
# 192  192       a70     w1177
# 193  193       a70      w953
# 194  194     a1480     w2363
# 195  195      a888     w3336
# 196  196     a1838     w3286
# 197  197     a1356     w3290
# 198  198      a777      w634
# 199  199     a1997     w3065
#
#                                                                                     ltable_product_title  \
# 0    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 1    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 2    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 3    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 4    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 5    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 6    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 7    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 8    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 9    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 10   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 11   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 12   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 13   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 14       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 15   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 16   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 17   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 18       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 19   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 20   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 21       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 22   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 23   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 24   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 25       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 26       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 27       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 28   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 29                       acer nx.g85aa.003 chromebook 11.6 denim cb3 131 c3kd intel celeron 2gb 16gb ssd
# ..                                                                                                   ...
# 170  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 171  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 174  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 175  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 176  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 177  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 178  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 180  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 181  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 182    lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows 10 80sr002sus
# 183  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 184  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 185                     apple macbook air mqd32ll a 13 1.8ghz intel core i5 dual core 8gb 128gb ssd mac
# 186  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 187  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 188  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 189  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 190  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 191                      lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle
# 192                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 193                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                                                hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack
# 195  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 198  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
# 199      lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
#
#             ltable_brand                 ltable_model  \
# 0                 lenovo                          NaN
# 1                 lenovo                          NaN
# 2                 lenovo                          NaN
# 3                 lenovo                          NaN
# 4                 lenovo                          NaN
# 5                 lenovo                          NaN
# 6                 lenovo                          NaN
# 7                 lenovo                          NaN
# 8                 lenovo                          NaN
# 9                 lenovo                          NaN
# 10                lenovo                          NaN
# 11                lenovo                          NaN
# 12                lenovo                          NaN
# 13                lenovo                          NaN
# 14                lenovo                          NaN
# 15                lenovo                          NaN
# 16                lenovo                          NaN
# 17                lenovo                          NaN
# 18                lenovo                          NaN
# 19                lenovo                          NaN
# 20                lenovo                          NaN
# 21                lenovo                          NaN
# 22                lenovo                          NaN
# 23                lenovo                          NaN
# 24                lenovo                          NaN
# 25                lenovo                          NaN
# 26                lenovo                          NaN
# 27                lenovo                          NaN
# 28                lenovo                          NaN
# 29                  acer                 nx.g85aa.003
# ..                   ...                          ...
# 170               lenovo                          NaN
# 171               lenovo                          NaN
# 172               lenovo                          NaN
# 173               lenovo                          NaN
# 174               lenovo                          NaN
# 175               lenovo                          NaN
# 176                   hp  hp envy x360 15t ash silver
# 177               lenovo                          NaN
# 178               lenovo                          NaN
# 179               lenovo                          NaN
# 180               lenovo                          NaN
# 181               lenovo                          NaN
# 182               lenovo      ideapad 510 80sr002sus
# 183               lenovo                          NaN
# 184                   hp          hp 15.6 touchscreen
# 185                apple                          NaN
# 186               lenovo                          NaN
# 187               lenovo                          NaN
# 188               lenovo                          NaN
# 189  michaelelectronics2                hp 17z laptop
# 190  michaelelectronics2                hp 17z laptop
# 191                   lg                          NaN
# 192                   hp                        hp 15
# 193                   hp                        hp 15
# 194                   hp                          NaN
# 195               lenovo                          NaN
# 196               lenovo                          NaN
# 197               lenovo                          NaN
# 198                 dell                        t8tjg
# 199               lenovo                          NaN
#
#                                                                                    ltable_extended_title  \
# 0    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 1    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 2    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 3    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 4    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 5    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 6    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 7    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 8    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 9    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 10   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 11   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 12   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 13   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 14              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 15   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 16   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 17   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 18              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 19   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 20   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 21              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 22   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 23   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 24   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 25              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 26              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 27              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 28   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 29                    acer nx.g85aa.003 chromebook 11.6 denim cb3 131 c3kd intel celeron 2gb 16gb ssd os
# ..                                                                                                   ...
# 170  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 171  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 174  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 175  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 176  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 177  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 178  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 180  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 181  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 182  lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows 10 80sr002su...
# 183  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 184  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 185                    apple macbook air mqd32ll a 13 1.8ghz intel core i5 dual core 8gb 128gb ssd mac x
# 186  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 187  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 188  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 189  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 190  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 191           lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle windows 10
# 192                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 193                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                                     hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack windows 10
# 195  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 198  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
# 199             lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
#
#                                                                                     rtable_product_title  \
# 0    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 1    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 2    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 3    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x...
# 4    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 5    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440...
# 6    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 7    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x...
# 8    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 9    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 10   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 11   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x10...
# 12   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 13   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 14        lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 15   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 16   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 17   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 18   lenovo thinkpad t460s touch windows 10 intel core i7 6600u 8gb 1tb ssd 14 ips fhd 1920x1080 touc...
# 19   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440...
# 20   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 21   lenovo thinkpad t460s touch windows 7 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 tou...
# 22   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x1...
# 23   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# 24   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x10...
# 25   lenovo thinkpad t460s touch windows 8.1 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 t...
# 26        lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 27        lenovo thinkpad t460s windows 8.1 intel core i7 6600u 8gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 28   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 29                        refurbished acer chromebook 11.6 denim cb3 131 c3kd intel celeron 2gb 16gb ssd
# ..                                                                                                   ...
# 170  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 171  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 inte...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 fhd ips 1920x1080 i...
# 174  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 int...
# 175  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 256gb ssd 8gb 14 fhd ips 1920x1080 int...
# 176  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 177  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 1tb ssd 8gb 14 fhd ips 1920x1080 intel...
# 178  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 180  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 181  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 182  refurbished lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows ...
# 183  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 in...
# 184  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 185                     apple 13 macbook air 1.8ghz intel core i5 dual core 8gb 128gb ssd mac mqd32ll a
# 186  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x...
# 187  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 188  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 189  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 190  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 191                      lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle
# 192                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 193                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                                                hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack
# 195  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 198  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
# 199      lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
#
#             rtable_brand              rtable_model  \
# 0                 lenovo                       NaN
# 1                 lenovo                       NaN
# 2                 lenovo                       NaN
# 3                 lenovo                       NaN
# 4                 lenovo                       NaN
# 5                 lenovo                       NaN
# 6                 lenovo                       NaN
# 7                 lenovo                       NaN
# 8                 lenovo                       NaN
# 9                 lenovo                       NaN
# 10                lenovo                       NaN
# 11                lenovo                       NaN
# 12                lenovo                       NaN
# 13                lenovo                       NaN
# 14                lenovo                       NaN
# 15                lenovo                       NaN
# 16                lenovo                       NaN
# 17                lenovo                       NaN
# 18                lenovo                       NaN
# 19                lenovo                       NaN
# 20                lenovo                       NaN
# 21                lenovo                       NaN
# 22                lenovo                       NaN
# 23                lenovo                       NaN
# 24                lenovo                       NaN
# 25                lenovo                       NaN
# 26                lenovo                       NaN
# 27                lenovo                       NaN
# 28                lenovo                       NaN
# 29                  acer                       NaN
# ..                   ...                       ...
# 170               lenovo                       NaN
# 171               lenovo                       NaN
# 172               lenovo                       NaN
# 173               lenovo                       NaN
# 174               lenovo                       NaN
# 175               lenovo                       NaN
# 176  michaelelectronics2  hp 15 02336 x360 fhd me7
# 177               lenovo                       NaN
# 178               lenovo                       NaN
# 179               lenovo                       NaN
# 180               lenovo                       NaN
# 181               lenovo                       NaN
# 182               lenovo                       NaN
# 183               lenovo                       NaN
# 184                   hp                      2018
# 185                apple                       NaN
# 186               lenovo                       NaN
# 187               lenovo                       NaN
# 188               lenovo                       NaN
# 189  michaelelectronics2       hp 17 02339 hdt me2
# 190  michaelelectronics2       hp 17 02339 hdt me8
# 191                   lg           15z970 a.aas7u1
# 192                   hp                       NaN
# 193                   hp                       NaN
# 194                   hp               2kw14ua#aba
# 195               lenovo                       NaN
# 196               lenovo                       NaN
# 197               lenovo                       NaN
# 198                 dell                       NaN
# 199               lenovo                       NaN
#
#                                                                                    rtable_extended_title
# 0    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 1    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 2    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 3    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x...
# 4    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 5    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440...
# 6    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 7    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x...
# 8    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 9    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 10   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 11   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x10...
# 12   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 13   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 14               lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080
# 15   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 16   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 17   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 18   lenovo thinkpad t460s touch windows 10 intel core i7 6600u 8gb 1tb ssd 14 ips fhd 1920x1080 touc...
# 19   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440...
# 20   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 21   lenovo thinkpad t460s touch windows 7 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 tou...
# 22   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x1...
# 23   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# 24   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x10...
# 25   lenovo thinkpad t460s touch windows 8.1 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 t...
# 26               lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 1tb ssd 14 ips fhd 1920x1080
# 27               lenovo thinkpad t460s windows 8.1 intel core i7 6600u 8gb 1tb ssd 14 ips fhd 1920x1080
# 28   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 29                       refurbished acer chromebook 11.6 denim cb3 131 c3kd intel celeron 2gb 16gb ssd
# ..                                                                                                   ...
# 170  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 171  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 inte...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 fhd ips 1920x1080 i...
# 174  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 int...
# 175  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 256gb ssd 8gb 14 fhd ips 1920x1080 int...
# 176  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 177  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 1tb ssd 8gb 14 fhd ips 1920x1080 intel...
# 178  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 180  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 181  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 182  refurbished lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows ...
# 183  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 in...
# 184  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 185    apple 13 macbook air 1.8ghz intel core i5 dual core 8gb 128gb ssd mac mqd32ll a microsoft windows
# 186  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x...
# 187  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 188  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 189  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 190  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 191           lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle windows 10
# 192                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 193                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                         hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack 2kw14ua#aba windows 10
# 195  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 198  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
# 199             lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
#
# [200 rows x 11 columns]

# %% [markdown]
# Looking at the debug blocker's output, we observe that the initial blocker is dropping a lot of potential matches.
# Blocking on the column brand alone seems incorrect.

# %%
# # Create overlap blocker
ob = em.OverlapBlocker()

# # Block tables using 'extended_title' attribute 
C2 = ob.block_tables(A, B, 'extended_title', 'extended_title', 
                     l_output_attrs=['id','model','extended_title'], 
                     r_output_attrs=['id','model','extended_title'],
                     overlap_size=25,
                     q_val=5,
                     word_level=False,
                     show_progress=False,
                     n_jobs=-1
                    )
# Updated blocking sequence
# A, B ------ overlap blocker [extended_title] ---------> C1--|
#                                                             |----> C
# A, B ------ overlap blocker [model] ------------------> C2--|

C = em.combine_blocker_outputs_via_union([C1,C2])
print ('Reduction on AxB by applying the blocker:' + str(int((len(A)*len(B))/len(C))) + 'x')
# Out:
# Reduction on AxB by applying the blocker:45x

# %%
# Debug blocker output
dbg = em.debug_blocker(C, A, B, 
                        attr_corres=[
                            ('product_title','product_title'),
                            ('brand', 'brand'), 
                            ('model','model'),
                            ('extended_title','extended_title')],
                            verbose=True)
### Display first few tuple pairs from the debug_blocker's output
dbg
# Out:
#      _id ltable_id rtable_id  \
# 0      0      a166     w1725
# 1      1      a820     w4318
# 2      2     a1166     w4520
# 3      3     a1739      w526
# 4      4     a1144      w953
# 5      5     a1739      w425
# 6      6     a1731      w809
# 7      7     a1144     w1177
# 8      8      a551     w2500
# 9      9     a1876     w1652
# 10    10     a2844      w953
# 11    11     a1739     w3023
# 12    12     a1739       w69
# 13    13     a2844     w1177
# 14    14     a1685      w558
# 15    15     a2024     w2957
# 16    16     a2873     w3218
# 17    17     a2844      w809
# 18    18     a2873      w454
# 19    19     a2144     w2300
# 20    20     a2654     w4496
# 21    21      a287     w2530
# 22    22      a551     w2245
# 23    23     a1194      w958
# 24    24      a432      w144
# 25    25      a498     w2736
# 26    26      a800      w976
# 27    27     a2873      w450
# 28    28      a432      w361
# 29    29     a2627     w2421
# ..   ...       ...       ...
# 170  170      a103     w4551
# 171  171      a103     w4539
# 172  172     a2100     w2566
# 173  173     a2105     w1894
# 174  174     a2116     w2546
# 175  175     a2124      w247
# 176  176     a2124     w2638
# 177  177     a2078     w3512
# 178  178     a2078     w2927
# 179  179       a74     w1099
# 180  180     a2078     w2755
# 181  181      a117     w2308
# 182  182      a119      w997
# 183  183      a132     w1713
# 184  184     a2076     w2021
# 185  185     a2068     w2632
# 186  186     a2068     w1389
# 187  187     a2068     w1374
# 188  188     a2206     w2753
# 189  189     a2905     w2574
# 190  190     a2267     w2148
# 191  191     a2267      w575
# 192  192     a2257     w2308
# 193  193     a2256      w997
# 194  194       a70     w2148
# 195  195     a2225     w2452
# 196  196     a2218     w1227
# 197  197     a2218     w1189
# 198  198       a70     w2202
# 199  199     a2209      w716
#
#                                                                                     ltable_product_title  \
# 0                                 hp chromebook t4m32ut#aba 14 intel celeron 4 gb 16 gb ssd chrome black
# 1                                                   hp 15 amd a9 9420 apu 8gb 1tb windows 10 15 bw030nr
# 2                                                acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10
# 3                                                lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd
# 4                                            hp 250 g5 15.6 intel core i3 5005u windows 10 8gb 1tb drive
# 5                                                lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd
# 6                                        newest hp 15.6 hd intel pentium 8gb 1tb hdd writerhd windows 10
# 7                                            hp 250 g5 15.6 intel core i3 5005u windows 10 8gb 1tb drive
# 8                                hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 9        msi pe70 7rd 027 17.3 work intel core i7 7700hq gtx 1050 16gb ddr4 128gb ssd 1tb windows 10 pro
# 10                                hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 home
# 11                                               lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd
# 12                                               lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd
# 13                                hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 home
# 14   2018 hp envy x360 2 1 15.6 full hd touchscreen pc intel quad core i7 8550u 12gb 1tb 7200rpm hddb...
# 15             lenovo thinkpad t570 20h9000nus core i7 7600u 2.8 ghz win 10 8 gb 256 gb ssd 15.6 ips fhd
# 16                                                        thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd
# 17                                hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 home
# 18                                                        thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd
# 19   acer aspire v nitro vn7 15.6 fhd touchscreen intel core i7 6500u 2.50 ghz nvidia geforce gtx 950...
# 20                lenovo ideapad 720s 14 fhd ips intel core i5 7200u 8gb 256gb ssd windows 10 80xc0003us
# 21           hp 15.6 hd touchscreen pc intel core i5 7200u 8gb 2tb hdd 128gb ssd hdmi rw windows 10 home
# 22                               hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 23   hp 15.6 hd latest intel core i5 7200u 2.5ghz 12gb ddr4 1tb hdd hdmi supermulti hd windows 10 silver
# 24                        dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10
# 25                    hp elitebook 840 g4 14 windows intel core i7 2.7 ghz 16 gb 512 gb ssd 1ge45ut#aba
# 26                             lenovo ideapad 110 80ud001rus 15.6 intel core i5 6200u 8gb 1tb windows 10
# 27                                                        thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd
# 28                        dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10
# 29           2018 acer 15.6 intel core i3 7100u 2.4ghz 4gb 128gb ssd intel hd 620 sd hdmi hd windows 10
# ..                                                                                                   ...
# 170                  asus zenbook ux303ua 13.3 fhd touchscreen intel core i5 8 gb 256 gb ssd windows 10
# 171                  asus zenbook ux303ua 13.3 fhd touchscreen intel core i5 8 gb 256 gb ssd windows 10
# 172  hp envy 17t touch 17.3 full hd 8th gen intel core i7 8550u 4.0 ghz 16gb 2tb hdd 4gb nvidia gefor...
# 173                                      dell chromebook 11 3380 intel celeron 3855u x2 1.6ghz 4gb 16gb
# 174                                                            hp 15 ba040nr 15.6 amd a10 8 gb 1 tb hdd
# 175                              lenovo flex 5 15.6 2 1 intel core i7 8 gb 1tb hdd windows 10 80xb0004us
# 176                              lenovo flex 5 15.6 2 1 intel core i7 8 gb 1tb hdd windows 10 80xb0004us
# 177                                                hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd
# 178                                                hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd
# 179                                                    hp chromebook 11 g5 11.6 celeron 4gb 16gb x9u02ut
# 180                                                hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd
# 181       2017 hp pavilion pc 15.6 full hd ips wled intel i7 7500u 12gb ddr4 1tb hdd b&o windows 10 gray
# 182                         2018 dell 15.6 hd intel i5 7200u 8gb ddr4 256gb ssd rw hdmi windows 10 black
# 183                            acer chromebook 11.6 cb3 111 c670 intel celeron 2gb 16gb ssd manufacturer
# 184                           dell inspiron 15.6 touchscreen intel core i5 5200u 8gb 1tb hdd windows 10
# 185  alienware aw17r3 7092slv 17.3 fhd 6th intel core i7 16 gb 256 gb ssd 1 tb hdd nvidia geforce gtx...
# 186  alienware aw17r3 7092slv 17.3 fhd 6th intel core i7 16 gb 256 gb ssd 1 tb hdd nvidia geforce gtx...
# 187  alienware aw17r3 7092slv 17.3 fhd 6th intel core i7 16 gb 256 gb ssd 1 tb hdd nvidia geforce gtx...
# 188  dell xps 13 full hd infinityedge touchscreen intel core i5 7200u 8gb 128gb ssd corning gorilla g...
# 189  dell xps 13 9360 13.3 qhd touchscreen 7th gen intel core i7 7500u 16gb 512gb nvme ssd machined w...
# 190                                                                  hp 17.3 intel core i7 8gb 1tb black
# 191                                                                  hp 17.3 intel core i7 8gb 1tb black
# 192        newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 193       2017 dell pc 15.6 hd truelife intel i5 7200u 8gb ddr4 1t hdd rw 802.11ac hdmi windows 10 black
# 194                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 195              hp 2uk91ut#aba zbook 14u g4 14 windows intel core i7 2.7 ghz 8 gb 1 tb hdd space silver
# 196         2018 acer 15.6 intel core i3 7100u 2.4ghz 12gb 128gb ssd intel hd 620 sd hdmi hd windows 10
# 197         2018 acer 15.6 intel core i3 7100u 2.4ghz 12gb 128gb ssd intel hd 620 sd hdmi hd windows 10
# 198                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 199                          hp 3fb86ut zbook x2 g4 tablet core i7 7600u 2.8 ghz win 10 16 gb 512 gb ssd
#
#        ltable_brand    ltable_model  \
# 0                hp     t4m32ut#aba
# 1                hp      15 bw030nr
# 2              acer    nx.gr7aa.007
# 3            lenovo      20hk001jus
# 4                hp     x9u74ut#aba
# 5            lenovo      20hk001jus
# 6         hp laptop             NaN
# 7                hp     x9u74ut#aba
# 8                hp             NaN
# 9               msi    pe70 7rd 027
# 10               hp      15 ay197cl
# 11           lenovo      20hk001jus
# 12           lenovo      20hk001jus
# 13               hp      15 ay197cl
# 14               hp       envy x360
# 15           lenovo      20h9000nus
# 16           lenovo      20hd0057us
# 17               hp      15 ay197cl
# 18           lenovo      20hd0057us
# 19             acer             NaN
# 20           lenovo      80xc0004us
# 21               hp           t8tjg
# 22               hp             NaN
# 23               hp   hp 15 ay117cl
# 24             dell           t8tjg
# 25               hp     1ge45ut#aba
# 26           lenovo      80ud001rus
# 27           lenovo      20hd0057us
# 28             dell           t8tjg
# 29             acer            acer
# ..              ...             ...
# 170            asus   ux303ua dh51t
# 171            asus   ux303ua dh51t
# 172              hp     hp envy 17t
# 173  dell computers             NaN
# 174              hp     w2m95ua#aba
# 175          lenovo      80xb0004us
# 176          lenovo      80xb0004us
# 177              hp       13 d010nr
# 178              hp       13 d010nr
# 179              hp     x9u02ut#aba
# 180              hp       13 d010nr
# 181              hp      15 cc563st
# 182            dell           t8tjg
# 183            acer    cb3 111 c670
# 184            dell      dell i5548
# 185       alienware  aw17r3 7092slv
# 186       alienware  aw17r3 7092slv
# 187       alienware  aw17r3 7092slv
# 188            dell      xps13 9360
# 189            dell            9360
# 190              hp           t8tjg
# 191              hp           t8tjg
# 192              hp             NaN
# 193            dell           t8tjg
# 194              hp           hp 15
# 195              hp     2uk91ut#aba
# 196            acer            acer
# 197            acer            acer
# 198              hp           hp 15
# 199             NaN         3fb86ut
#
#                                                                                    ltable_extended_title  \
# 0                                      hp chromebook t4m32ut#aba 14 intel celeron 4 gb 16 gb ssd chrome
# 1                                                   hp 15 amd a9 9420 apu 8gb 1tb windows 10 15 bw030nr
# 2                                    acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10 nx.gr7aa.007
# 3               lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd lenovo 20hk001jus not applicable
# 4                                      hp 250 g5 15.6 intel core i3 5005u windows 10 8gb 1tb x9u74ut#aba
# 5               lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd lenovo 20hk001jus not applicable
# 6                                 newest hp 15.6 hd intel pentium 8gb 1tb hdd writerhd windows 10 laptop
# 7                                      hp 250 g5 15.6 intel core i3 5005u windows 10 8gb 1tb x9u74ut#aba
# 8                                hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 9           msi pe70 7rd 027 17.3 work intel core i7 7700hq gtx 1050 16gb ddr4 128gb ssd 1tb windows 10
# 10                          hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 15 ay197cl
# 11              lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd lenovo 20hk001jus not applicable
# 12              lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd lenovo 20hk001jus not applicable
# 13                          hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 15 ay197cl
# 14   2018 hp envy x360 2 1 15.6 full hd touchscreen pc intel quad core i7 8550u 12gb 1tb 7200rpm hddb...
# 15     lenovo thinkpad t570 20h9000nus core i7 7600u 2.8 ghz win 10 8 gb 256 gb ssd 15.6 ips fhd unknown
# 16                              thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd lenovo 20hd0057us unknown
# 17                          hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 15 ay197cl
# 18                              thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd lenovo 20hd0057us unknown
# 19   acer aspire v nitro vn7 15.6 fhd touchscreen intel core i7 6500u 2.50 ghz nvidia geforce gtx 950...
# 20     lenovo ideapad 720s 14 fhd ips intel core i5 7200u 8gb 256gb ssd windows 10 80xc0003us 80xc0004us
# 21          hp 15.6 hd touchscreen pc intel core i5 7200u 8gb 2tb hdd 128gb ssd hdmi rw windows 10 t8tjg
# 22                               hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 23   hp 15.6 hd latest intel core i5 7200u 2.5ghz 12gb ddr4 1tb hdd hdmi supermulti hd windows 10 15 ...
# 24                  dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10 t8tjg
# 25          hp elitebook 840 g4 14 windows intel core i7 2.7 ghz 16 gb 512 gb ssd 1ge45ut#aba 10 edition
# 26                            lenovo ideapad 110 80ud001rus 15.6 intel core i5 6200u 8gb 1tb windows 10
# 27                              thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd lenovo 20hd0057us unknown
# 28                  dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10 t8tjg
# 29           2018 acer 15.6 intel core i3 7100u 2.4ghz 4gb 128gb ssd intel hd 620 sd hdmi hd windows 10
# ..                                                                                                   ...
# 170  asus zenbook ux303ua 13.3 fhd touchscreen intel core i5 8 gb 256 gb ssd windows 10 asus ux303ua ...
# 171  asus zenbook ux303ua 13.3 fhd touchscreen intel core i5 8 gb 256 gb ssd windows 10 asus ux303ua ...
# 172  hp envy 17t touch 17.3 full hd 8th gen intel core i7 8550u 4.0 ghz 16gb 2tb hdd 4gb nvidia gefor...
# 173                          dell chromebook 11 3380 intel celeron 3855u x2 1.6ghz 4gb 16gb computers os
# 174                                         hp 15 ba040nr 15.6 amd a10 8 gb 1 tb hdd w2m95ua#aba windows
# 175                         lenovo flex 5 15.6 2 1 intel core i7 8 gb 1tb hdd windows 10 80xb0004us home
# 176                         lenovo flex 5 15.6 2 1 intel core i7 8 gb 1tb hdd windows 10 80xb0004us home
# 177                                         hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd windows
# 178                                         hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd windows
# 179                                        hp chromebook 11 g5 11.6 celeron 4gb 16gb x9u02ut x9u02ut#aba
# 180                                         hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd windows
# 181  2017 hp pavilion pc 15.6 full hd ips wled intel i7 7500u 12gb ddr4 1tb hdd b&o windows 10 15 cc5...
# 182                         2018 dell 15.6 hd intel i5 7200u 8gb ddr4 256gb ssd rw hdmi windows 10 t8tjg
# 183                                        acer chromebook 11.6 cb3 111 c670 intel celeron 2gb 16gb ssd
# 184                dell inspiron 15.6 touchscreen intel core i5 5200u 8gb 1tb hdd windows 10 i5548 other
# 185  alienware aw17r3 7092slv 17.3 fhd 6th intel core i7 16 gb 256 gb ssd 1 tb hdd nvidia geforce gtx...
# 186  alienware aw17r3 7092slv 17.3 fhd 6th intel core i7 16 gb 256 gb ssd 1 tb hdd nvidia geforce gtx...
# 187  alienware aw17r3 7092slv 17.3 fhd 6th intel core i7 16 gb 256 gb ssd 1 tb hdd nvidia geforce gtx...
# 188  dell xps 13 full hd infinityedge touchscreen intel core i5 7200u 8gb 128gb ssd corning gorilla g...
# 189  dell xps 13 9360 13.3 qhd touchscreen 7th gen intel core i7 7500u 16gb 512gb nvme ssd machined w...
# 190                                                       hp 17.3 intel core i7 8gb 1tb t8tjg windows 10
# 191                                                       hp 17.3 intel core i7 8gb 1tb t8tjg windows 10
# 192       newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 193       2017 dell pc 15.6 hd truelife intel i5 7200u 8gb ddr4 1t hdd rw 802.11ac hdmi windows 10 t8tjg
# 194                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 195              hp 2uk91ut#aba zbook 14u g4 14 windows intel core i7 2.7 ghz 8 gb 1 tb hdd space 10 pro
# 196         2018 acer 15.6 intel core i3 7100u 2.4ghz 12gb 128gb ssd intel hd 620 sd hdmi hd windows 10
# 197         2018 acer 15.6 intel core i3 7100u 2.4ghz 12gb 128gb ssd intel hd 620 sd hdmi hd windows 10
# 198                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 199                  hp 3fb86ut zbook x2 g4 tablet core i7 7600u 2.8 ghz win 10 16 gb 512 gb ssd unknown
#
#                                                                                     rtable_product_title  \
# 0                                                  hp chromebook 11 g5 11.6 celeron n3060 4 gb 16 gb ssd
# 1                                  manufacturer hp 15 bw070nr 15.6 amd a9 9420 3.0ghz 4gb 1tb windows 10
# 2                                   refurbished acer amd fx series 3 ghz 8 gb 256 gb ssd windows 10 home
# 3                                              lenovo thinkpad x1 tablet 12 core i7 7y75 8 gb 256 gb ssd
# 4                     hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 5                                              lenovo thinkpad x1 tablet 12 core i7 7y75 8 gb 256 gb ssd
# 6                       2017 hp touchscreen 15.6 hd intel i3 7100u dual core 8gb 1tb hdd hdmi windows 10
# 7                     hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 8                                      hp 15.6 15 ac143wm pc intel core i5 5200u 6gb 1tb windows 10 home
# 9    msi pe62 7rd 1095 15.6 intel core i7 7700hq 2.8ghz 32gb ddr4 1tb hdd 512gb ssd gtx 1050 usb3.0 w...
# 10                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 11                                            lenovo thinkpad x1 carbon 14 core i7 7500u 8 gb 256 gb ssd
# 12                                             lenovo thinkpad p40 yoga 14 core i7 6500u 8 gb 256 gb ssd
# 13                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 14       hp envy 15 w105wm x360 15.6 full hd ips touch 2 1 windows 10 intel core i7 6500u 8gb 1tb silver
# 15                                               lenovo thinkpad p51s 15.6 core i7 7500u 8 gb 256 gb ssd
# 16                                            lenovo thinkpad x1 carbon 14 core i7 7500u 8 gb 512 gb ssd
# 17                      2017 hp touchscreen 15.6 hd intel i3 7100u dual core 8gb 1tb hdd hdmi windows 10
# 18                                              lenovo thinkpad x1 yoga 14 core i5 7200u 8 gb 256 gb ssd
# 19                       acer 15.6 intel core i7 2.6ghz 16 gb 1 tb hdd 256 gb ssd windows 10 g9 593 72vt
# 20                                       lenovo thinkpad t440s intel i7 8gb 256gb ssd 14 fhd windows 10
# 21          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 22          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 23   2018 hp 15.6 hd touchscreen intel dual core i5 7200u 3.1ghz 8gb ddr4 1tb hdd hdmi hd 620 dts stu...
# 24      refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10 fingerprint
# 25                                                hp elitebook 1040 g3 14 core i7 6600u 16 gb 512 gb ssd
# 26                             refurbished lenovo flex 5 2 1 15.6 touch intel core i5 8gb 1tb windows 10
# 27                                              lenovo thinkpad x1 yoga 14 core i5 7300u 8 gb 256 gb ssd
# 28      refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10 fingerprint
# 29   newest acer aspire e15 15.6 fhd intel core i3 7100u 7th 4gb ddr4 1tb 5400rpm hd intel hd 620 win...
# ..                                                                                                   ...
# 170                              refurbished acer intel core i5 2.50 ghz 8 gb 256 gb ssd windows 10 home
# 171                              refurbished acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10 home
# 172                                                  hp envy 17t core i7 8550u 16gb 17.3 full hd 1tb hdd
# 173                           refurbished acer 11.6 chromebook 11 intel celeron 1.6ghz 4gb 16gb chromeos
# 174                                                  hp zbook 15 g4 15.6 core i7 7700hq 8 gb 1 tb hdd us
# 175                     refurbished acer nitro spin 5 intel core i7 1.8 ghz 8 gb 1tb hdd windows 10 home
# 176                                                   lenovo 320s 15ikb 15.6 core i7 7500u 8 gb 1 tb hdd
# 177                                               apple macbook air 13.3 core i5 8 gb 128 gb ssd english
# 178                                                lenovo thinkpad 13 13.3 core i5 7200u 8 gb 256 gb ssd
# 179                            hp chromebook 11 g6 ee 11.6 touchscreen chromebook celeron n3350 4gb 16gb
# 180                                                lenovo thinkpad 13 13.3 core i5 7200u 4 gb 128 gb ssd
# 181                              hp 15 ay107cl 15.6 hd intel core i7 7500u 16g 1tb hdd rw windows 10 red
# 182  dell inspiron 15.6 touchscreen hd intel dual core i5 7200u 2.5ghz 8gb ddr4 2tb hdd maxxaudio hdm...
# 183                                                   acer c720 chromebook 11.6 2gb 16gb ssd refurbished
# 184                        dell inspiron i355210040blk 15.6 windows 10 intel pentium n3710 8gb 1tb drive
# 185                refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 home
# 186                refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 home
# 187           alienware 17.3 intel core i7 7820hk quad core 2.9 ghz 16 gb ddr4 sdram 1 tb hdd 256 gb ssd
# 188                              dell xps 13 9360 core i5 8250u 128gb ssd 8gb 13.3 full hd touch display
# 189                           refurbished dell xps 13 9360 i7 8550u 8th gen 16gb 512gb ssd qhd touch rdr
# 190  hp 17.3 hd pc intel core i7 7500u 2.7ghz dual core 8gb ddr4 1tb hdd rw stereo speakers windows 1...
# 191                hp 17 bs020nr 17.3 touchscreen windows 10 intel core i3 6006u dual core 8gb 1tb drive
# 192                              hp 15 ay107cl 15.6 hd intel core i7 7500u 16g 1tb hdd rw windows 10 red
# 193  dell inspiron 15.6 touchscreen hd intel dual core i5 7200u 2.5ghz 8gb ddr4 2tb hdd maxxaudio hdm...
# 194  hp 17.3 hd pc intel core i7 7500u 2.7ghz dual core 8gb ddr4 1tb hdd rw stereo speakers windows 1...
# 195                                                   hp probook 470 g4 17.3 core i7 7500u 8 gb 1 tb hdd
# 196  lenovo ideapad 320 15.6 hd touchscreen intel dual core i3 7100u 2.4ghz 6gb ddr4 512gb ssd hdmi r...
# 197  lenovo ideapad 320 15.6 hd touchscreen intel dual core i3 7100u 2.4ghz 6gb ddr4 256gb ssd hdmi r...
# 198                               hp 15 ay039wm 15.6 fusion windows 10 intel core i3 6100u 8gb 1tb drive
# 199                                           hp zbook studio g4 15.6 core i7 7700hq 16 gb 512 gb ssd us
#
#     rtable_brand      rtable_model  \
# 0             hp       x9u02ut#aba
# 1             hp     15 bw070nr rf
# 2           acer      nh.q2uaa.003
# 3         lenovo        20jb002nus
# 4             hp               NaN
# 5         lenovo        20jb002lus
# 6             hp              2017
# 7             hp               NaN
# 8             hp       n5z06ua#aba
# 9            msi               NaN
# 10            hp               NaN
# 11        lenovo        20hr0057us
# 12        lenovo        20gq000bus
# 13            hp               NaN
# 14            hp       x0s29ua#aba
# 15        lenovo        20hb000aus
# 16        lenovo        20hr0058us
# 17            hp              2017
# 18        lenovo        20jf000bus
# 19          acer      nh.q1caa.001
# 20        lenovo               NaN
# 21            hp               NaN
# 22            hp              2017
# 23            hp              2018
# 24          dell               NaN
# 25           NaN               NaN
# 26        lenovo               NaN
# 27        lenovo        20jd000pus
# 28          dell               NaN
# 29          acer               NaN
# ..           ...               ...
# 170         acer      nx.gstaa.001
# 171         acer      nx.gtsaa.005
# 172           hp         17 u275cl
# 173         acer      nx.gn3aa.001
# 174           hp       1jd32ut#aba
# 175         acer      nh.q2yaa.002
# 176       lenovo        80x50002us
# 177        apple         mqd32ll a
# 178       lenovo        20j1001cus
# 179           hp       3pd93ut#aba
# 180       lenovo        20j1001fus
# 181           hp               NaN
# 182         dell               NaN
# 183         acer               NaN
# 184         dell     i355210040blk
# 185         acer      nh.q26aa.002
# 186         acer      nh.q1taa.001
# 187    alienware    aw17r4 7004slv
# 188          NaN               NaN
# 189         dell               NaN
# 190           hp               NaN
# 191           hp       1kv30ua#aba
# 192           hp               NaN
# 193         dell               NaN
# 194           hp               NaN
# 195           hp       z1z75ut#aba
# 196       lenovo  len320i37t 6512p
# 197       lenovo  len320i37t 6256p
# 198           hp       x0h85ua#aba
# 199          NaN               NaN
#
#                                                                                    rtable_extended_title
# 0                                   hp chromebook 11 g5 11.6 celeron n3060 4 gb 16 gb ssd x9u02ut#aba os
# 1          manufacturer hp 15 bw070nr 15.6 amd a9 9420 3.0ghz 4gb 1tb windows 10 15 bw070nr rf microsoft
# 2                           refurbished acer amd fx series 3 ghz 8 gb 256 gb ssd windows 10 nh.q2uaa.003
# 3                       lenovo thinkpad x1 tablet 12 core i7 7y75 8 gb 256 gb ssd 20jb002nus windows 10
# 4                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 5                       lenovo thinkpad x1 tablet 12 core i7 7y75 8 gb 256 gb ssd 20jb002lus windows 10
# 6                      2017 hp touchscreen 15.6 hd intel i3 7100u dual core 8gb 1tb hdd hdmi windows 10
# 7                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 8                               hp 15.6 15 ac143wm pc intel core i5 5200u 6gb 1tb windows 10 n5z06ua#aba
# 9    msi pe62 7rd 1095 15.6 intel core i7 7700hq 2.8ghz 32gb ddr4 1tb hdd 512gb ssd gtx 1050 usb3.0 w...
# 10                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 11                     lenovo thinkpad x1 carbon 14 core i7 7500u 8 gb 256 gb ssd 20hr0057us windows 10
# 12                       lenovo thinkpad p40 yoga 14 core i7 6500u 8 gb 256 gb ssd 20gq000bus windows 10
# 13                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 14   hp envy 15 w105wm x360 15.6 full hd ips touch 2 1 windows 10 intel core i7 6500u 8gb 1tb x0s29ua...
# 15                        lenovo thinkpad p51s 15.6 core i7 7500u 8 gb 256 gb ssd 20hb000aus windows 10
# 16                     lenovo thinkpad x1 carbon 14 core i7 7500u 8 gb 512 gb ssd 20hr0058us windows 10
# 17                     2017 hp touchscreen 15.6 hd intel i3 7100u dual core 8gb 1tb hdd hdmi windows 10
# 18                       lenovo thinkpad x1 yoga 14 core i5 7200u 8 gb 256 gb ssd 20jf000bus windows 10
# 19          acer 15.6 intel core i7 2.6ghz 16 gb 1 tb hdd 256 gb ssd windows 10 g9 593 72vt nh.q1caa.001
# 20                           lenovo thinkpad t440s intel i7 8gb 256gb ssd 14 fhd windows 10 professional
# 21          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 22          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 23   2018 hp 15.6 hd touchscreen intel dual core i5 7200u 3.1ghz 8gb ddr4 1tb hdd hdmi hd 620 dts stu...
# 24                 refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10
# 25                                               hp elitebook 1040 g3 14 core i7 6600u 16 gb 512 gb ssd
# 26                   refurbished lenovo flex 5 2 1 15.6 touch intel core i5 8gb 1tb windows 10 microsoft
# 27                       lenovo thinkpad x1 yoga 14 core i5 7300u 8 gb 256 gb ssd 20jd000pus windows 10
# 28                 refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10
# 29   newest acer aspire e15 15.6 fhd intel core i3 7100u 7th 4gb ddr4 1tb 5400rpm hd intel hd 620 win...
# ..                                                                                                   ...
# 170                      refurbished acer intel core i5 2.50 ghz 8 gb 256 gb ssd windows 10 nx.gstaa.001
# 171                      refurbished acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10 nx.gtsaa.005
# 172                             hp envy 17t core i7 8550u 16gb 17.3 full hd 1tb hdd 17 u275cl windows 10
# 173              refurbished acer 11.6 chromebook 11 intel celeron 1.6ghz 4gb 16gb chromeos nx.gn3aa.001
# 174                           hp zbook 15 g4 15.6 core i7 7700hq 8 gb 1 tb hdd us 1jd32ut#aba windows 10
# 175             refurbished acer nitro spin 5 intel core i7 1.8 ghz 8 gb 1tb hdd windows 10 nh.q2yaa.002
# 176                             lenovo 320s 15ikb 15.6 core i7 7500u 8 gb 1 tb hdd 80x50002us windows 10
# 177                                      apple macbook air 13.3 core i5 8 gb 128 gb ssd mqd32ll a sierra
# 178                         lenovo thinkpad 13 13.3 core i5 7200u 8 gb 256 gb ssd 20j1001cus windows 10
# 179             hp chromebook 11 g6 ee 11.6 touchscreen chromebook celeron n3350 4gb 16gb 3pd93ut#aba os
# 180                         lenovo thinkpad 13 13.3 core i5 7200u 4 gb 128 gb ssd 20j1001fus windows 10
# 181                                 hp 15 ay107cl 15.6 hd intel core i7 7500u 16g 1tb hdd rw windows 10
# 182  dell inspiron 15.6 touchscreen hd intel dual core i5 7200u 2.5ghz 8gb ddr4 2tb hdd maxxaudio hdm...
# 183                                                            acer c720 chromebook 11.6 2gb 16gb ssd os
# 184                dell inspiron i355210040blk 15.6 windows 10 intel pentium n3710 8gb 1tb i355210040blk
# 185        refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 nh.q26aa.002
# 186        refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 nh.q1taa.001
# 187  alienware 17.3 intel core i7 7820hk quad core 2.9 ghz 16 gb ddr4 sdram 1 tb hdd 256 gb ssd aw17r...
# 188                                     dell xps 13 9360 core i5 8250u 128gb ssd 8gb 13.3 full hd touch
# 189                refurbished dell xps 13 9360 i7 8550u 8th gen 16gb 512gb ssd qhd touch rdr windows 10
# 190   hp 17.3 hd pc intel core i7 7500u 2.7ghz dual core 8gb ddr4 1tb hdd rw stereo speakers windows 10
# 191          hp 17 bs020nr 17.3 touchscreen windows 10 intel core i3 6006u dual core 8gb 1tb 1kv30ua#aba
# 192                                 hp 15 ay107cl 15.6 hd intel core i7 7500u 16g 1tb hdd rw windows 10
# 193  dell inspiron 15.6 touchscreen hd intel dual core i5 7200u 2.5ghz 8gb ddr4 2tb hdd maxxaudio hdm...
# 194   hp 17.3 hd pc intel core i7 7500u 2.7ghz dual core 8gb ddr4 1tb hdd rw stereo speakers windows 10
# 195                            hp probook 470 g4 17.3 core i7 7500u 8 gb 1 tb hdd z1z75ut#aba windows 10
# 196  lenovo ideapad 320 15.6 hd touchscreen intel dual core i3 7100u 2.4ghz 6gb ddr4 512gb ssd hdmi r...
# 197  lenovo ideapad 320 15.6 hd touchscreen intel dual core i3 7100u 2.4ghz 6gb ddr4 256gb ssd hdmi r...
# 198                         hp 15 ay039wm 15.6 fusion windows 10 intel core i3 6100u 8gb 1tb x0h85ua#aba
# 199                                          hp zbook studio g4 15.6 core i7 7700hq 16 gb 512 gb ssd us
#
# [200 rows x 11 columns]

# %% [markdown]
# The blocker seem to have reduced the input size by 45x. However, on debugging the blocker we observe that it is still dropping potential matches. So, we are going to debug the blocker further.

# %%
def match_extended_title(attribute='extended_title',q_val=3, threshold=.5,debug=False):
    def jaccard_matcher(ltuple,rtuple, attribute=attribute, q_val=q_val, threshold=threshold,debug=debug):
        buffer = '#' * (q_val-1)
        l_attribute = buffer + ltuple[attribute] + buffer
        r_attribute = buffer + rtuple[attribute] + buffer
        l_grams = set()
        r_grams = set()
        # create sets of grams
        for attribute, grams in [(l_attribute,l_grams), (r_attribute,r_grams)]:
            for i in range(0,len(attribute)-(q_val-1)):
                grams.add(attribute[i:i+q_val])
               
        # compute jaccard
        intersection = list(set(l_grams) & set(r_grams))
        union = list(set(l_grams) | set(r_grams))
        if debug:
            print(union)
            print(intersection)
            print(len(intersection) / len(union))
        return len(intersection) / len(union) < threshold
    
    return jaccard_matcher

bb = em.BlackBoxBlocker()
bb.set_black_box_function(match_extended_title())
C3 = bb.block_candset(C2,  
                     show_progress=False,
                     n_jobs=-1
                     )
# Updated blocking sequence
# A, B --- overlap blocker [model] ---------------------> C1--------------------------------|
#                                                                                     union |---> C
# A, B --- overlap blocker [extended_title] ---> C2---> jaccard blocker [extended_title] ---|
C = em.combine_blocker_outputs_via_union([C1,C3])

# %%
# Debug again
dbg = em.debug_blocker(C, A, B)
dbg
# Out:
#      _id ltable_id rtable_id  \
# 0      0      a298     w3443
# 1      1      a298     w3400
# 2      2      a298     w3422
# 3      3      a298     w3439
# 4      4      a298     w3458
# 5      5      a298     w3394
# 6      6      a298     w3250
# 7      7      a298     w3327
# 8      8      a298     w3014
# 9      9      a298     w3015
# 10    10      a763     w2527
# 11    11     a2616     w1545
# 12    12     a2616     w1480
# 13    13     a2257      w619
# 14    14     a1883      w921
# 15    15     a1883     w2492
# 16    16     a2257      w659
# 17    17     a2860      w790
# 18    18     a2901     w2220
# 19    19     a1883     w2509
# 20    20     a1701     w2530
# 21    21      a298     w3016
# 22    22      a551      w603
# 23    23     a1883     w2762
# 24    24     a1329     w1459
# 25    25     a1617     w2954
# 26    26       a70       w17
# 27    27      a998      w674
# 28    28     a1514      w556
# 29    29     a1514      w557
# ..   ...       ...       ...
# 170  170     a1700     w1449
# 171  171     a1269      w528
# 172  172     a2087     w1503
# 173  173     a1549     w3282
# 174  174     a1589     w2490
# 175  175     a1700     w1434
# 176  176     a1608      w100
# 177  177     a2035     w2585
# 178  178     a1608      w391
# 179  179     a2055     w4551
# 180  180     a2055     w4539
# 181  181     a2054     w1175
# 182  182     a2054     w1174
# 183  183     a1738     w1556
# 184  184     a1685      w107
# 185  185     a1767     w1987
# 186  186     a1841      w374
# 187  187     a1829     w2249
# 188  188     a1815      w552
# 189  189     a1617     w3023
# 190  190     a1810     w3130
# 191  191     a1810     w3127
# 192  192     a1617     w2994
# 193  193     a1807     w4572
# 194  194     a1807      w872
# 195  195     a1617     w3068
# 196  196     a1767     w2016
# 197  197     a1883     w2740
# 198  198     a1617     w3075
# 199  199     a1617     w3076
#
#                                                                                     ltable_product_title  \
# 0    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 1    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 2    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 3    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 4    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 5    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 6    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 7    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 8    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 9    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 10                                      hp elitebook 840 g4 14 core i5 7200u 8 gb 256 gb ssd 1ge40ut#aba
# 11   prostar clevo pa71hs g 17.3” full hd ips g sync intel core i7 7700hq 16gb ddr4 gtx 1070 256gb nv...
# 12   prostar clevo pa71hs g 17.3” full hd ips g sync intel core i7 7700hq 16gb ddr4 gtx 1070 256gb nv...
# 13         newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 14                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 15                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 16         newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 17   dell xps 15 9560 4k uhd intel core i7 7700hq 16gb 512gb ssd nvidia gtx 1050 4gb gddr5 windows 10...
# 18                       hp pavilion 15.6 hd touchscreen intel core i5 8gb 1tb hdd windows 10 15 au057cl
# 19                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 20   2017 hp fhd 15.6 wled intel core i5 7200u 3.1ghz 8gb ddr4 1tb hdd usb 3.1 802.11 ac hdmi windows 10
# 21   lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 22                               hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 23                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 24   prostar clevo n870hp6 17.3” full hd ips intel core i7 7700hq 32gb ddr4 gtx 1060 500gb ssd 1tb hd...
# 25                   lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 26                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 27           hp 15.6 touchscreen quad core amd a12 3.6ghz 8gb 1tb hdd 4gb amd radeon r7 hdmi windows 10
# 28   2018 rca cambio 10.1 2 1 touchscreen tablet pc intel quad core 2gb 32gb microsoft office windows...
# 29   2018 rca cambio 10.1 2 1 touchscreen tablet pc intel quad core 2gb 32gb microsoft office windows...
# ..                                                                                                   ...
# 170  hp omen 17 17.3 uhd 4k vr ready intel i7 2tb hdd 512gb ssd 17.3 uhd 3840 x 2160 32gb geforce gtx...
# 171      lenovo thinkpad t470s windows 10 intel core i7 7600u 16gb 512gb ssd 14 ips wqhd 2560x1440 color
# 172  lg 14z970 a.aas7u1 gram intel i7 8gb 14 touchscreen elite suite 17 standard software bundle core...
# 173  lenovo thinkpad t470p 14 pc intel i7 quad core nvidia geforce 940mx 14 fhd 1920x1080 ips 32gb 51...
# 174                                                                 samsung np900x3t k01us 9 13.3 titan
# 175  hp omen 17 17.3 uhd 4k vr ready intel i7 2tb hdd 512gb ssd 17.3 uhd 3840 x 2160 32gb geforce gtx...
# 176                   dell xps 13 9365 13.3 qhd touch intel core i7 7y75 16gb 512gb ssd windows 10 black
# 177         dell tfg4h latitude 3380 13.3 hdf intel core i3 6006u 4gb ddr4 128gb solid state windows 10
# 178                   dell xps 13 9365 13.3 qhd touch intel core i7 7y75 16gb 512gb ssd windows 10 black
# 179                            acer aspire 5 a517 51g 54gk intel core i5 8 gb 256 gb ssd 17.3 windows 10
# 180                            acer aspire 5 a517 51g 54gk intel core i5 8 gb 256 gb ssd 17.3 windows 10
# 181                                    hp 17.3 hd intel core i5 7200u 8gb 1tb optical hd windows 10 gold
# 182                                    hp 17.3 hd intel core i5 7200u 8gb 1tb optical hd windows 10 gold
# 183  alienware aw15r2 8469slv 15.6 uhd 6th intel core i7 16 gb 1 tb hdd 256 gb sata ssd nvidia geforc...
# 184  2018 hp envy x360 2 1 15.6 full hd touchscreen pc intel quad core i7 8550u 12gb 1tb 7200rpm hddb...
# 185  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 186                                                               surface book wz3 00001 13.5 2 1 laptop
# 187  dell 4hcnk latitude 7480 14 fhd touch intel core i5 7300u 8gb ddr4 256gb solid state windows 10 pro
# 188                                           hp envy x360 2 1 15.6 touch intel core i5 8gb 750gb silver
# 189                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 190  lenovo thinkpad p51 20hh000gus intel quad core i7 7820hq 8gb 256gb nvme ssd 15.6 fhd ips 1920x10...
# 191  lenovo thinkpad p51 20hh000gus intel quad core i7 7820hq 8gb 256gb nvme ssd 15.6 fhd ips 1920x10...
# 192                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 193                            dell xps 13 9350 13.3 intel core i5 6200u 8gb 128gb ssd windows 10 silver
# 194                            dell xps 13 9350 13.3 intel core i5 6200u 8gb 128gb ssd windows 10 silver
# 195                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 196  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 197                hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 198                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 199                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
#
#             ltable_brand            ltable_model      ltable_operating_system  \
# 0                 lenovo              20fb002lus       windows 7 professional
# 1                 lenovo              20fb002lus       windows 7 professional
# 2                 lenovo              20fb002lus       windows 7 professional
# 3                 lenovo              20fb002lus       windows 7 professional
# 4                 lenovo              20fb002lus       windows 7 professional
# 5                 lenovo              20fb002lus       windows 7 professional
# 6                 lenovo              20fb002lus       windows 7 professional
# 7                 lenovo              20fb002lus       windows 7 professional
# 8                 lenovo              20fb002lus       windows 7 professional
# 9                 lenovo              20fb002lus       windows 7 professional
# 10                    hp             1ge40ut#aba               windows 10 pro
# 11               prostar                pa71hs g                   windows 10
# 12               prostar                pa71hs g                   windows 10
# 13                    hp                     NaN                   windows 10
# 14                    hp             x9v54ut#aba           windows 10 edition
# 15                    hp             x9v54ut#aba           windows 10 edition
# 16                    hp                     NaN                   windows 10
# 17                  dell                   t8tjg                   windows 10
# 18                    hp                 w2l56ua                   windows 10
# 19                    hp             x9v54ut#aba           windows 10 edition
# 20                    hp                   15 ay                   windows 10
# 21                lenovo              20fb002lus       windows 7 professional
# 22                    hp                     NaN                   windows 10
# 23                    hp             x9v54ut#aba           windows 10 edition
# 24               prostar                 n870hp6                   windows 10
# 25                lenovo              20bs00bgus       windows 7 professional
# 26                    hp                   hp 15                   windows 10
# 27                    hp                   t8tjg                   windows 10
# 28                   NaN                     NaN                  android 6.0
# 29                   NaN                     NaN                  android 6.0
# ..                   ...                     ...                          ...
# 170                   hp          new hp omen 17                          NaN
# 171               lenovo                     NaN               windows 10 pro
# 172         beach camera       e1lg14z970aaas7u1                   windows 10
# 173  michaelelectronics2                     NaN                   windows 10
# 174              samsung          np900x3t k01us              windows 10 home
# 175                   hp          new hp omen 17                          NaN
# 176                 dell                   9x0t5              windows 10 home
# 177                 dell                   tfg4h               windows 10 pro
# 178                 dell                   9x0t5              windows 10 home
# 179                 acer           a517 51g 54gk              windows 10 home
# 180                 acer           a517 51g 54gk              windows 10 home
# 181                   hp             1kv31ua#aba                   windows 10
# 182                   hp             1kv31ua#aba                   windows 10
# 183            alienware          aw15r2 8469slv                   windows 10
# 184                   hp               envy x360                   windows 10
# 185               lenovo                     NaN            windows 10 64 bit
# 186            microsoft               wz3 00001  microsoft windows 10 64 bit
# 187                 dell                   4hcnk               windows 10 pro
# 188                 envy  hp envy 15 u010dx x360                   windows 10
# 189               lenovo              20bs00bgus       windows 7 professional
# 190               lenovo              20hh000gus                   windows 10
# 191               lenovo              20hh000gus                   windows 10
# 192               lenovo              20bs00bgus       windows 7 professional
# 193                  NaN             xps 13 9350              windows 10 home
# 194                  NaN             xps 13 9350              windows 10 home
# 195               lenovo              20bs00bgus       windows 7 professional
# 196               lenovo                     NaN            windows 10 64 bit
# 197                   hp             x9v54ut#aba           windows 10 edition
# 198               lenovo              20bs00bgus       windows 7 professional
# 199               lenovo              20bs00bgus       windows 7 professional
#
#                                                                                    ltable_extended_title  \
# 0    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 1    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 2    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 3    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 4    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 5    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 6    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 7    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 8    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 9    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 10                       hp elitebook 840 g4 14 core i5 7200u 8 gb 256 gb ssd 1ge40ut#aba windows 10 pro
# 11   prostar clevo pa71hs g 17.3” full hd ips g sync intel core i7 7700hq 16gb ddr4 gtx 1070 256gb nv...
# 12   prostar clevo pa71hs g 17.3” full hd ips g sync intel core i7 7700hq 16gb ddr4 gtx 1070 256gb nv...
# 13        newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 14       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 15       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 16        newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 17   dell xps 15 9560 4k uhd intel core i7 7700hq 16gb 512gb ssd nvidia gtx 1050 4gb gddr5 windows 10...
# 18               hp pavilion 15.6 hd touchscreen intel core i5 8gb 1tb hdd windows 10 15 au057cl w2l56ua
# 19       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 20   2017 hp fhd 15.6 wled intel core i5 7200u 3.1ghz 8gb ddr4 1tb hdd usb 3.1 802.11 ac hdmi windows...
# 21   lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 22                               hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 23       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 24   prostar clevo n870hp6 17.3” full hd ips intel core i7 7700hq 32gb ddr4 gtx 1060 500gb ssd 1tb hd...
# 25   lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 26                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 27      hp 15.6 touchscreen quad core amd a12 3.6ghz 8gb 1tb hdd 4gb amd radeon r7 hdmi windows 10 t8tjg
# 28   2018 rca cambio 10.1 2 1 touchscreen tablet pc intel quad core 2gb 32gb microsoft office windows...
# 29   2018 rca cambio 10.1 2 1 touchscreen tablet pc intel quad core 2gb 32gb microsoft office windows...
# ..                                                                                                   ...
# 170  hp omen 17 17.3 uhd 4k vr ready intel i7 2tb hdd 512gb ssd 17.3 uhd 3840 x 2160 32gb geforce gtx...
# 171           lenovo thinkpad t470s windows 10 intel core i7 7600u 16gb 512gb ssd 14 ips wqhd 2560x1440
# 172  lg 14z970 a.aas7u1 gram intel i7 8gb 14 touchscreen elite suite 17 standard software bundle core...
# 173  lenovo thinkpad t470p 14 pc intel i7 quad core nvidia geforce 940mx 14 fhd 1920x1080 ips 32gb 51...
# 174                                                  samsung np900x3t k01us 9 13.3 titan windows 10 home
# 175  hp omen 17 17.3 uhd 4k vr ready intel i7 2tb hdd 512gb ssd 17.3 uhd 3840 x 2160 32gb geforce gtx...
# 176              dell xps 13 9365 13.3 qhd touch intel core i7 7y75 16gb 512gb ssd windows 10 9x0t5 home
# 177         dell tfg4h latitude 3380 13.3 hdf intel core i3 6006u 4gb ddr4 128gb solid state windows 10
# 178              dell xps 13 9365 13.3 qhd touch intel core i7 7y75 16gb 512gb ssd windows 10 9x0t5 home
# 179                       acer aspire 5 a517 51g 54gk intel core i5 8 gb 256 gb ssd 17.3 windows 10 home
# 180                       acer aspire 5 a517 51g 54gk intel core i5 8 gb 256 gb ssd 17.3 windows 10 home
# 181                             hp 17.3 hd intel core i5 7200u 8gb 1tb optical hd windows 10 1kv31ua#aba
# 182                             hp 17.3 hd intel core i5 7200u 8gb 1tb optical hd windows 10 1kv31ua#aba
# 183  alienware aw15r2 8469slv 15.6 uhd 6th intel core i7 16 gb 1 tb hdd 256 gb sata ssd nvidia geforc...
# 184  2018 hp envy x360 2 1 15.6 full hd touchscreen pc intel quad core i7 8550u 12gb 1tb 7200rpm hddb...
# 185  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 186                                surface book wz3 00001 13.5 2 1 microsoft microsoft windows 10 64 bit
# 187     dell 4hcnk latitude 7480 14 fhd touch intel core i5 7300u 8gb ddr4 256gb solid state windows 10
# 188                hp envy x360 2 1 15.6 touch intel core i5 8gb 750gb hp envy 15 u010dx x360 windows 10
# 189  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 190  lenovo thinkpad p51 20hh000gus intel quad core i7 7820hq 8gb 256gb nvme ssd 15.6 fhd ips 1920x10...
# 191  lenovo thinkpad p51 20hh000gus intel quad core i7 7820hq 8gb 256gb nvme ssd 15.6 fhd ips 1920x10...
# 192  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 193                              dell xps 13 9350 13.3 intel core i5 6200u 8gb 128gb ssd windows 10 home
# 194                              dell xps 13 9350 13.3 intel core i5 6200u 8gb 128gb ssd windows 10 home
# 195  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 196  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 197      hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 198  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 199  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
#
#                                                                                     rtable_product_title  \
# 0    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 2tb nvme ssd 14 ips wqhd 2560x1440...
# 1    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 1tb nvme ssd 14 ips wqhd 2560x1440...
# 2    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 1tb nvme ssd 14 ips wqhd 2560x1440...
# 3    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 2tb nvme ssd 14 ips wqhd 2560x1440 ...
# 4    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 2tb nvme ssd 14 ips wqhd 2560x1440...
# 5    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 1tb nvme ssd 14 ips wqhd 2560x1440 ...
# 6    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 256gb nvme ssd 14 ips wqhd 2560x14...
# 7    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 256gb nvme ssd 14 ips wqhd 2560x14...
# 8    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 9    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 10                                                 hp zbook 15u g4 15.6 core i5 7200u 8 gb 256 gb ssd us
# 11   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 512gb ssd 1...
# 12   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 128gb ssd 1...
# 13   hp pavilion 15 cc564nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 14                                                   hp zbook 15u g3 15.6 core i7 6500u 16 gb 512 gb ssd
# 15                                                   hp zbook 15 g3 15.6 core i7 6820hq 16 gb 256 gb ssd
# 16   hp pavilion 15 cc563nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 17               refurbished dell xps 15 9560 i7 7700hq 16gb 512gb ssd uhd 4k touch gtx 1050 fingerprint
# 18                    hp pavilion 15 au020wm 15.6 manhattan windows 10 intel core i5 6200u 8gb 1tb drive
# 19                                               hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd
# 20          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 21   2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7500u 180gb ssd 8gb 14 wqhd ips 2...
# 22              hp pavilion 15 au030wm 15.6 manhattan touch windows 10 intel core i5 6200u 8gb 1tb drive
# 23                                               hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd
# 24   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 256gb nvme ...
# 25                                            lenovo thinkpad x1 carbon 14 core i5 6200u 8 gb 180 gb ssd
# 26                              hp 15.6 touchscreen 2 1 windows 10 intel core i3 7100u 8gb 1tb assorted
# 27   hp 15.6 touchscreen latest amd quad core a12 9720p 2.7 ghz 8gb ddr4 1tb hdd amd radeon r7 mouse ...
# 28                                rca cambio 10.1 2 1 tablet 32gb intel atom z3735f quad core windows 10
# 29                                rca cambio 10.1 2 1 tablet 32gb intel atom z3735f quad core windows 10
# ..                                                                                                   ...
# 170  hp omen 15 15.6 uhd 4k intel i7 quad core 2tb hdd 512gb ssd 15.6 uhd 3840 x 2160 32gb geforce gt...
# 171  lenovo thinkpad x1 yoga 4g lte multimode windows 10 intel i7 7600u 512gb ssd nvme 16gb 14 wqhd i...
# 172  samsung np800g5m x02us 15.6 odyssey intel i7 256gb elite suite 17 standard software bundle corel...
# 173     lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 512gb ssd 14 ips fhd 1920x1080 ac wifi
# 174                                                              samsung 9 13.3 8gb np900x3n k01us titan
# 175  hp omen 17 17.3 uhd 4k intel i7 quad core 1tb hdd 256gb ssd 17.3 uhd 3840 x 2160 16gb geforce gt...
# 176                           dell xps 13 9365 intel core i7 7y75 x2 1.3ghz 16gb 512gb ssd 13.3 silver
# 177                refurbished dell 3340 13.3 windows 10 intel core i3 4010u 4gb 128gb solid state drive
# 178                           dell xps 13 9365 intel core i7 7y75 x2 1.3ghz 16gb 512gb ssd 13.3 silver
# 179                              refurbished acer intel core i5 2.50 ghz 8 gb 256 gb ssd windows 10 home
# 180                              refurbished acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10 home
# 181  hp pavilion touchscreen hd 15.6 intel core i5 7200u 8gb 1tb b&o sound optical hd windows 10 mine...
# 182  hp pavilion touchscreen hd 15.6 intel core i5 7200u 8gb 1tb b&o sound optical hd windows 10 mine...
# 183  refurbished alienware 15 fhd 15.6 intel core i7 4710hq 16 gb 1 tb hdd 128 gb ssd nvidia geforce ...
# 184         hp envy x360 convertible 2 1 full hd ips 15.6 touchscreen intel core i7 8550u 12gb 1tb drive
# 185               lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb platinum grey
# 186                                                   microsoft surface book 13.5 touchscreen 2 1 intel
# 187       refurbished dell 14 latitude e6440 pc intel core i5 4300m 8gb 256gb solid state windows 10 pro
# 188             hp pavilion 15 bk020wm x360 15.6 touch 2 1 windows 10 intel core i5 6200u 8gb 1tb silver
# 189                                           lenovo thinkpad x1 carbon 14 core i7 7500u 8 gb 256 gb ssd
# 190  pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb nvme ssd 14 ips fhd 1920x108...
# 191  pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb nvme ssd 14 ips fhd 1920x108...
# 192                                           lenovo thinkpad x1 carbon 14 core i5 7200u 8 gb 128 gb ssd
# 193                   refurbished dell xps 13 9350 i5 6200u 8gb 128gb ssd fhd infinity windows 10 silver
# 194  refurbished dell xps 13 9350 i5 6200u 8gb 128gb ssd fhd 1080p touch infinity edge windows 10 silver
# 195                                           lenovo thinkpad x1 carbon 14 core i7 6500u 8 gb 256 gb ssd
# 196                  lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb denim blue
# 197                                              hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd
# 198                                           lenovo thinkpad x1 carbon 14 core i5 7300u 8 gb 512 gb ssd
# 199                                          lenovo thinkpad x1 carbon 14 core i5 7300u 16 gb 256 gb ssd
#
#                rtable_brand        rtable_model       rtable_operating_system  \
# 0                    lenovo                 NaN                     windows 7
# 1                    lenovo                 NaN                     windows 7
# 2                    lenovo                 NaN                     windows 7
# 3                    lenovo                 NaN                     windows 7
# 4                    lenovo                 NaN                     windows 7
# 5                    lenovo                 NaN                     windows 7
# 6                    lenovo                 NaN                     windows 7
# 7                    lenovo                 NaN                     windows 7
# 8                    lenovo                2017                     windows 7
# 9                    lenovo                2017                     windows 7
# 10                       hp         2hj12ut#aba                    windows 10
# 11                  prostar              n855hj         microsoft windows 10
# 12                  prostar              n855hj         microsoft windows 10
# 13                       hp         1ku26ua#aba                    windows 10
# 14                       hp         v1h65ut#aba                   windows 10
# 15                       hp         x9u00ut#aba                    windows 10
# 16                       hp         1ku25ua#aba                    windows 10
# 17                     dell                 NaN       windows 10 professional
# 18                       hp         w2l54ua#aba                    windows 10
# 19                       hp         x9t82ut#aba                    windows 10
# 20                       hp                 NaN                    windows 10
# 21                   lenovo                2017                     windows 7
# 22                       hp         w2l55ua#aba                    windows 10
# 23                       hp         t6e17ut#aba                   windows 10
# 24                  prostar              n855hj         microsoft windows 10
# 25                   lenovo          20k4002uus                     windows 7
# 26                       hp         1kt67ua#aba                    windows 10
# 27                       hp                 NaN             microsoft windows
# 28                      rca                 NaN             microsoft windows
# 29                      rca                 NaN             microsoft windows
# ..                      ...                 ...                           ...
# 170     michaelelectronics2                 NaN                           NaN
# 171                  lenovo                 NaN                    windows 10
# 172                 samsung  e1samnp800g5mx02us                           NaN
# 173                  lenovo                 NaN                    windows 10
# 174                 samsung              4t9874  microsoft windows windows 10
# 175     michaelelectronics2                 NaN                           NaN
# 176                    dell      1493282306 rfb                    windows 10
# 177                latitude           wa5 30736                    windows 10
# 178                    dell      1493282305 rfb                    windows 10
# 179                    acer        nx.gstaa.001                    windows 10
# 180                    acer        nx.gtsaa.005                    windows 10
# 181  b & h publishing group          15 cc057cl                    windows 10
# 182  b & h publishing group          15 cc057cl                    windows 10
# 183                    dell                 NaN             microsoft windows
# 184                      hp          15 aq267cl             microsoft windows
# 185                  lenovo          80xr00a7us                    windows 10
# 186               microsoft                 NaN            windows 10 edition
# 187                latitude            wa5 1199                    windows 10
# 188                      hp         w2m07ua#aba                    windows 10
# 189                  lenovo          20hr0057us                   windows 10
# 190                  lenovo                 NaN                    windows 10
# 191                  lenovo                 NaN                    windows 10
# 192                  lenovo          20hr0011us                   windows 10
# 193                    dell  xps9350 1340slv rb       windows 10 professional
# 194                    dell                 NaN                           NaN
# 195                  lenovo          20k4002rus                     windows 7
# 196                  lenovo          80xr00alus                    windows 10
# 197                      hp         t6e16ut#aba                     windows 7
# 198                  lenovo          20hr003eus                   windows 10
# 199                  lenovo          20hr000mus                   windows 10
#
#                                                                                    rtable_extended_title
# 0      pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 2tb nvme ssd 14 ips wqhd 2560x1440
# 1      pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 1tb nvme ssd 14 ips wqhd 2560x1440
# 2      pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 1tb nvme ssd 14 ips wqhd 2560x1440
# 3       pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 2tb nvme ssd 14 ips wqhd 2560x1440
# 4      pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 2tb nvme ssd 14 ips wqhd 2560x1440
# 5       pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 1tb nvme ssd 14 ips wqhd 2560x1440
# 6    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 256gb nvme ssd 14 ips wqhd 2560x1440
# 7    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 256gb nvme ssd 14 ips wqhd 2560x1440
# 8    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 9    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 10                          hp zbook 15u g4 15.6 core i5 7200u 8 gb 256 gb ssd us 2hj12ut#aba windows 10
# 11   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 512gb ssd 1...
# 12   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 128gb ssd 1...
# 13   hp pavilion 15 cc564nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 14                           hp zbook 15u g3 15.6 core i7 6500u 16 gb 512 gb ssd v1h65ut#aba windows 10
# 15                            hp zbook 15 g3 15.6 core i7 6820hq 16 gb 256 gb ssd x9u00ut#aba windows 10
# 16   hp pavilion 15 cc563nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 17      refurbished dell xps 15 9560 i7 7700hq 16gb 512gb ssd uhd 4k touch gtx 1050 windows professional
# 18              hp pavilion 15 au020wm 15.6 manhattan windows 10 intel core i5 6200u 8gb 1tb w2l54ua#aba
# 19                        hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd x9t82ut#aba windows 10
# 20          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 21   2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7500u 180gb ssd 8gb 14 wqhd ips 2...
# 22        hp pavilion 15 au030wm 15.6 manhattan touch windows 10 intel core i5 6200u 8gb 1tb w2l55ua#aba
# 23                       hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd t6e17ut#aba windows 10
# 24   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 256gb nvme ...
# 25                       lenovo thinkpad x1 carbon 14 core i5 6200u 8 gb 180 gb ssd 20k4002uus windows 7
# 26                   hp 15.6 touchscreen 2 1 windows 10 intel core i3 7100u 8gb 1tb assorted 1kt67ua#aba
# 27   hp 15.6 touchscreen latest amd quad core a12 9720p 2.7 ghz 8gb ddr4 1tb hdd amd radeon r7 mouse ...
# 28                      rca cambio 10.1 2 1 tablet 32gb intel atom z3735f quad core windows 10 microsoft
# 29                      rca cambio 10.1 2 1 tablet 32gb intel atom z3735f quad core windows 10 microsoft
# ..                                                                                                   ...
# 170  hp omen 15 15.6 uhd 4k intel i7 quad core 2tb hdd 512gb ssd 15.6 uhd 3840 x 2160 32gb geforce gt...
# 171  lenovo thinkpad x1 yoga 4g lte multimode windows 10 intel i7 7600u 512gb ssd nvme 16gb 14 wqhd i...
# 172  samsung np800g5m x02us 15.6 odyssey intel i7 256gb elite suite 17 standard software bundle corel...
# 173            lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 512gb ssd 14 ips fhd 1920x1080
# 174                          samsung 9 13.3 8gb np900x3n k01us titan 4t9874 microsoft windows windows 10
# 175  hp omen 17 17.3 uhd 4k intel i7 quad core 1tb hdd 256gb ssd 17.3 uhd 3840 x 2160 16gb geforce gt...
# 176  dell xps 13 9365 intel core i7 7y75 x2 1.3ghz 16gb 512gb ssd 13.3 silver  1493282306 rfb windows 10
# 177   refurbished dell 3340 13.3 windows 10 intel core i3 4010u 4gb 128gb solid state latitude wa5 30736
# 178  dell xps 13 9365 intel core i7 7y75 x2 1.3ghz 16gb 512gb ssd 13.3 silver  1493282305 rfb windows 10
# 179                      refurbished acer intel core i5 2.50 ghz 8 gb 256 gb ssd windows 10 nx.gstaa.001
# 180                      refurbished acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10 nx.gtsaa.005
# 181  hp pavilion touchscreen hd 15.6 intel core i5 7200u 8gb 1tb b&o sound optical hd windows 10 mine...
# 182  hp pavilion touchscreen hd 15.6 intel core i5 7200u 8gb 1tb b&o sound optical hd windows 10 mine...
# 183  refurbished alienware 15 fhd 15.6 intel core i7 4710hq 16 gb 1 tb hdd 128 gb ssd nvidia geforce ...
# 184  hp envy x360 convertible 2 1 full hd ips 15.6 touchscreen intel core i7 8550u 12gb 1tb 15 aq267c...
# 185         lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb platinum 80xr00a7us
# 186                                 microsoft surface book 13.5 touchscreen 2 1 intel windows 10 edition
# 187  refurbished dell 14 latitude e6440 pc intel core i5 4300m 8gb 256gb solid state windows 10 wa5 1199
# 188        hp pavilion 15 bk020wm x360 15.6 touch 2 1 windows 10 intel core i5 6200u 8gb 1tb w2m07ua#aba
# 189                    lenovo thinkpad x1 carbon 14 core i7 7500u 8 gb 256 gb ssd 20hr0057us windows 10
# 190   pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb nvme ssd 14 ips fhd 1920x1080
# 191   pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb nvme ssd 14 ips fhd 1920x1080
# 192                    lenovo thinkpad x1 carbon 14 core i5 7200u 8 gb 128 gb ssd 20hr0011us windows 10
# 193  refurbished dell xps 13 9350 i5 6200u 8gb 128gb ssd fhd infinity windows 10 xps9350 1340slv rb p...
# 194        refurbished dell xps 13 9350 i5 6200u 8gb 128gb ssd fhd 1080p touch infinity edge windows 10
# 195                        lenovo thinkpad x1 carbon 14 core i7 6500u 8 gb 256 gb ssd 20k4002rus windows
# 196            lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb denim 80xr00alus
# 197                          hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd t6e16ut#aba windows
# 198                    lenovo thinkpad x1 carbon 14 core i5 7300u 8 gb 512 gb ssd 20hr003eus windows 10
# 199                   lenovo thinkpad x1 carbon 14 core i5 7300u 16 gb 256 gb ssd 20hr000mus windows 10
#
# [200 rows x 13 columns]

# %%
len(C)
# Out:
# 7326

# %% [markdown]
# Looking at the dedug output, we observe that the current blocking sequence does not seem to drop a lot of potential matches and has also reduced the candidate set to a good extent. Thus, we stop the blocking step and proceed with the matching step.

# %% [markdown]
# # Step 3: Reading in the labeled sample

# %% [markdown]
# We randomly sample 450 tuple pairs for labeling purposes and write the sample data to a csv. We then label the csv and use the labeled csv from then on.

# %%
# # Sample  candidate set
S = em.sample_table(C, 450)
## em.to_csv_metadata(S, 'data/labeled.csv')

# %%
# # Loading the labeled data
path_S = 'data/labeled.csv'
S = em.read_csv_metadata(path_S, 
                         key='_id',
                         ltable=A, rtable=B, 
                         fk_ltable='ltable_id', fk_rtable='rtable_id')

#showing some examples of labeled sample
S.head(5)
# Out:
#    _id ltable_id rtable_id  ltable_model  \
# 0    5        a0     w2300  nh.q28aa.001
# 1   26     a1011      w685         t8tjg
# 2   30      a102     w1746   c300sa dh02
# 3   44     a1031     w4581  a515 51 596k
# 4   65     a1047     w1400       n850hp6
#
#                                                                                  ltable_extended_title  \
# 0  acer predator helios 300 15.6 full hd intel core i7 7700hq 16gb ddr4 256gb ssd geforce gtx 1060 ...
# 1  2018 lenovo thinkpad 11e 4h 11.6 intel i3 7100u 128gb m.2 ssd 4gb ddr4 802.11ac win10 t8tjg windows
# 2                     asus chromebook c300sa compact 13.3 intel celeron 4gb 16gb emmc asus c300sa dh02
# 3                           acer 15.6 intel core i5 3.40ghz 8gb 256gb ssd windows 10 a515 51 596k home
# 4  prostar clevo n850hp6 15.6” fhd ips 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1060 120gb ssd ...
#
#    rtable_model  \
# 0  nh.q1caa.001
# 1         t8tjg
# 2   c300sa dh02
# 3  nx.gnpaa.016
# 4        n855hj
#
#                                                                                  rtable_extended_title  \
# 0         acer 15.6 intel core i7 2.6ghz 16 gb 1 tb hdd 256 gb ssd windows 10 g9 593 72vt nh.q1caa.001
# 1                                   dell chromebook 11 3189 11.6 celeron n3060 4 gb 64 gb ssd t8tjg os
# 2                                             c300sa dh02 cel n3060 4gb 16gb 13.3in chrome asus chrome
# 3               refurbished acer aspire 3 intel core i5 2.5 ghz 8gb 256 gb ssd windows 10 nx.gnpaa.016
# 4  prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 8gb ddr4 gtx 1050 1tb hdd wind...
#
#    match
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1

# %% [markdown]
# # Step 4: Splitting labeled data into development and evaluation set

# %% [markdown]
# In this step, we split the labeled data set S into a development set I and an evaluation set J.

# %%
IJ = em.split_train_test(S, train_proportion=0.7, random_state=0)
I = IJ['train']
J = IJ['test']

# %% [markdown]
# # Step 5: Creating a set of ML-matchers.

# %%
# Create a set of ML-matchers
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')
nb = em.NBMatcher(name='NaiveBayes')

# %% [markdown]
# ### Creating features

# %% [markdown]
# Next, we need to create a set of features for the development set. *py_entitymatching* provides a way to automatically generate features based on the attributes in the input tables. For the purposes of this guide, we use the automatically generated features.

# %%
# Remove bad features from auto-feature-generation
AA = A.drop(['id','product_title','model','operating_system'],axis=1)
BB = B.drop(['id','product_title','model','operating_system'],axis=1)

AA.keys(), BB.keys()
# Out:
# (Index(['brand', 'extended_title'], dtype='object'),
#  Index(['brand', 'extended_title'], dtype='object'))

# %%
match_t = em.get_tokenizers_for_matching([3,5,10])
match_s = em.get_sim_funs_for_matching()
atypes1 = em.get_attr_types(AA)
atypes2 = em.get_attr_types(BB)
match_c = em.get_attr_corres(AA, BB)
feature_table = em.get_features(AA, BB, atypes1, atypes2, match_c, match_t, match_s)

# %%
feature_table['feature_name']
# Out:
# 0                          brand_brand_jac_qgm_3_qgm_3
# 1                      brand_brand_cos_dlm_dc0_dlm_dc0
# 2                      brand_brand_jac_dlm_dc0_dlm_dc0
# 3                                      brand_brand_mel
# 4                                 brand_brand_lev_dist
# 5                                  brand_brand_lev_sim
# 6                                      brand_brand_nmw
# 7                                       brand_brand_sw
# 8        extended_title_extended_title_jac_qgm_3_qgm_3
# 9    extended_title_extended_title_cos_dlm_dc0_dlm_dc0
# Name: feature_name, dtype: object

# %% [markdown]
# This function generates a function that returns 1 if both or neither tuples' attribute contain any of the passed in values and 0 otherwise.

# %%
def generateContainsValueFeature(values, name=None, attribute='extended_title'):
    if type(values) is str:
        values = [values]
    def containsValueFeature(a,b):
        return int(any([value.lower() in a[attribute].lower() for value in values]) 
                   == any([value.lower() in b[attribute].lower() for value in values]))
    return containsValueFeature, name if name else values[0]

# %% [markdown]
# Use this to generate many new features.

# %%
brands = ['lg','toshiba','hp','dell','lenovo','prostar','acer','samsung','apple','asus','panasonic','msi']
models = ['zephyrus','zenbook','flex','omen','xps','x1','carbon','yoga',
          'latitude','inspiron','elitebook','clevo','spectre',
          'macbook','pavilion','ideapad','legion']
thinkpads = [['p40','p50','p51','p71'],['430','460','470','560','570']]
asus = ['swift','aspire','spin']
models = models + thinkpads + asus
sizes = [' 13',' 14',' 15',' 17']
operating_systems = ['chrome','windows','mac']
cpus = [['i3','i5','i7'],['celeron','pentium'],['m3','m5'],'amd']
miscellaneous = ['2-in-1','gtx','touch']
keywords = models \
    + sizes  \
    + operating_systems \
    + cpus \
    + miscellaneous
new_features = [generateContainsValueFeature(value) for value in keywords]

for feature in new_features:
    em.add_blackbox_feature(feature_table, feature[1], feature[0])

# %% [markdown]
# This function generates a function that returns 1 if both tuples contain the same value for any of the values passed in and 0 otherwise.

# %%
def generateContainsValueFromValuesetFeature(valueset, name=None, attribute='extended_title'):
    def sharesValue(a,b,values):
        if type(values) is str:
            values = [values]
        return int(any([value.lower() in a[attribute].lower() and value.lower() in b[attribute].lower() for value in values]))
    def containsValueFromValueset(a,b):
        return any([sharesValue(a,b,values) for values in valueset[1]])
    return containsValueFromValueset, valueset[0]

# %%
valuesets = [('brands',brands), 
             ('models', models), 
             ('sizes', sizes), 
             ('cpus', cpus), 
             ('operating_systems',operating_systems)]

new_features = [generateContainsValueFromValuesetFeature(valueset) for valueset in valuesets]

for feature in new_features:
    em.add_blackbox_feature(feature_table, feature[1], feature[0])

# %%
# List the names of the features generated
feature_table['feature_name']
# Out:
# 0                           brand_brand_jac_qgm_3_qgm_3
# 1                       brand_brand_cos_dlm_dc0_dlm_dc0
# 2                       brand_brand_jac_dlm_dc0_dlm_dc0
# 3                                       brand_brand_mel
# 4                                  brand_brand_lev_dist
# 5                                   brand_brand_lev_sim
# 6                                       brand_brand_nmw
# 7                                        brand_brand_sw
# 8         extended_title_extended_title_jac_qgm_3_qgm_3
# 9     extended_title_extended_title_cos_dlm_dc0_dlm_dc0
# 10                                             zephyrus
# 11                                              zenbook
# 12                                                 flex
# 13                                                 omen
# 14                                                  xps
# 15                                                   x1
# 16                                               carbon
# 17                                                 yoga
# 18                                             latitude
# 19                                             inspiron
# 20                                            elitebook
# 21                                                clevo
# 22                                              spectre
# 23                                              macbook
# 24                                             pavilion
# 25                                              ideapad
# 26                                               legion
# 27                                                  p40
# 28                                                  430
# 29                                                swift
# 30                                               aspire
# 31                                                 spin
# 32                                                   13
# 33                                                   14
# 34                                                   15
# 35                                                   17
# 36                                               chrome
# 37                                              windows
# 38                                                  mac
# 39                                                   i3
# 40                                              celeron
# 41                                                   m3
# 42                                                  amd
# 43                                               2-in-1
# 44                                                  gtx
# 45                                                touch
# 46                                               brands
# 47                                               models
# 48                                                sizes
# 49                                                 cpus
# 50                                    operating_systems
# Name: feature_name, dtype: object

# %% [markdown]
# ### Converting the development set to feature vectors

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=feature_table, 
                            attrs_after='match',
                            show_progress=False)
H.fillna(0, inplace=True)
H.head()
# Out:
#       _id ltable_id rtable_id  brand_brand_jac_qgm_3_qgm_3  \
# 221  3372     a1997     w2968                         1.00
# 439  6763      a891     w2599                         0.04
# 191  2875     a1919     w3250                         1.00
# 239  3626     a1997     w3468                         1.00
# 433  6651      a878     w2294                         1.00
#
#      brand_brand_cos_dlm_dc0_dlm_dc0  brand_brand_jac_dlm_dc0_dlm_dc0  \
# 221                              1.0                              1.0
# 439                              0.0                              0.0
# 191                              1.0                              1.0
# 239                              1.0                              1.0
# 433                              1.0                              1.0
#
#      brand_brand_mel  brand_brand_lev_dist  brand_brand_lev_sim  \
# 221          1.00000                   0.0               1.0000
# 439          0.60625                  13.0               0.1875
# 191          1.00000                   0.0               1.0000
# 239          1.00000                   0.0               1.0000
# 433          1.00000                   0.0               1.0000
#
#      brand_brand_nmw  ...    amd  2-in-1  gtx  touch  brands  models  sizes  \
# 221              6.0  ...      1       1    1      0    True    True   True
# 439             -7.0  ...      1       1    1      1    True   False  False
# 191              6.0  ...      1       1    1      1    True    True   True
# 239              6.0  ...      1       1    1      1    True    True   True
# 433              6.0  ...      1       1    1      1    True    True   True
#
#      cpus  operating_systems  match
# 221  True               True      1
# 439  True               True      0
# 191  True               True      1
# 239  True               True      1
# 433  True               True      1
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Selecting the best matcher using cross-validation

# %% [markdown]
# Now, we select the best matcher using k-fold cross-validation. For the purposes of this guide, we use five fold cross validation and use the 'precision' metric to select the best matcher.

# %%
# Select the best ML matcher using CV
result = em.select_matcher(
        matchers=[dt, rf, svm, ln, lg, nb], 
        table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
        k=5,
        target_attr='match', 
        metric_to_select_matcher='precision', 
        random_state=0)
result['cv_stats']
# result
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.954048        0.937980    0.945281
# 1            RF           0.963564        0.972000    0.967336
# 2           SVM           0.893285        0.992000    0.939676
# 3        LinReg           0.962487        0.952694    0.957178
# 4        LogReg           0.913782        0.960000    0.935088
# 5    NaiveBayes           0.946487        0.942230    0.943907

# %% [markdown]
# ### Debugging matcher

# %% [markdown]
# We observe that the best matcher is not maximizing F1. We debug the matcher to see what might be wrong.
# To do this, first we split the feature vectors into train and test.

# %%
#  Split feature vectors into train and test
UV = em.split_train_test(H, train_proportion=0.5)
U = UV['train']
V = UV['test']

# %% [markdown]
# Next, we debug the matcher using GUI. For the purposes of this guide, we use random forest matcher for debugging purposes.

# %%
# Debug rf using GUI
# em.vis_debug_dt(result['selected_matcher'], U, V, 
#         exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
#         target_attr='match')

# %% [markdown]
# ##  Evaluating the matching output

# %% [markdown]
# From the GUI, we observe that phone numbers seem to be an important attribute, but they are in different format. Current features does not capture and adding a feature incorporating this difference in format can potentially improve
# the F1 numbers.

# %% [markdown]
# Now, we repeat extracting feature vectors (this time with updated feature table), imputing table and selecting the best matcher again using cross-validation.

# %% [raw]
# H = em.extract_feature_vecs(I, feature_table=feature_table, attrs_after='match', show_progress=False)
# H.fillna(0, inplace=True)

# %%
# Select the best ML matcher using CV
result = em.select_matcher(
        [dt, rf, svm, ln, lg, nb], 
        table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
        k=5,
        target_attr='match', 
        metric_to_select_matcher='precision', 
        random_state=0)
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.954048        0.937980    0.945281
# 1            RF           0.963564        0.972000    0.967336
# 2           SVM           0.893285        0.992000    0.939676
# 3        LinReg           0.962487        0.952694    0.957178
# 4        LogReg           0.913782        0.960000    0.935088
# 5    NaiveBayes           0.946487        0.942230    0.943907

# %% [markdown]
# Evaluating the matching outputs for the evaluation set typically involves the following four steps:
# 1. Converting the evaluation set to feature vectors
# 2. Training matcher using the feature vectors extracted from the development set
# 3. Predicting the evaluation set using the trained matcher
# 4. Evaluating the predicted matches

# %% [markdown]
# ### Converting the evaluation set to  feature vectors

# %% [markdown]
# As before, we convert to the feature vectors (using the feature table and the evaluation set)

# %%
# Convert J into a set of feature vectors using feature table
L = em.extract_feature_vecs(
        J, 
        feature_table=feature_table,
        attrs_after='match', 
        show_progress=False)
L.fillna(0, inplace=True)
L.head()
# Out:
#       _id ltable_id rtable_id  brand_brand_jac_qgm_3_qgm_3  \
# 124  1764     a1561       w15                          0.0
# 54    705     a1269     w3092                          1.0
# 268  4200     a2294     w1544                          1.0
# 293  4614     a2439     w3188                          1.0
# 230  3469     a1997     w3210                          1.0
#
#      brand_brand_cos_dlm_dc0_dlm_dc0  brand_brand_jac_dlm_dc0_dlm_dc0  \
# 124                              0.0                              0.0
# 54                               1.0                              1.0
# 268                              1.0                              1.0
# 293                              1.0                              1.0
# 230                              1.0                              1.0
#
#      brand_brand_mel  brand_brand_lev_dist  brand_brand_lev_sim  \
# 124              0.0                   0.0                  0.0
# 54               1.0                   0.0                  1.0
# 268              1.0                   0.0                  1.0
# 293              1.0                   0.0                  1.0
# 230              1.0                   0.0                  1.0
#
#      brand_brand_nmw  ...    amd  2-in-1  gtx  touch  brands  models  sizes  \
# 124              0.0  ...      1       1    1      1    True    True  False
# 54               6.0  ...      1       1    1      0    True    True   True
# 268              7.0  ...      1       1    1      1    True    True   True
# 293              6.0  ...      1       1    1      1    True    True   True
# 230              6.0  ...      1       1    1      1    True    True   True
#
#      cpus  operating_systems  match
# 124  True               True      0
# 54   True               True      1
# 268  True               True      1
# 293  True               True      1
# 230  True               True      1
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Training the selected matcher

# %% [markdown]
# Now, we train the matcher using all of the feature vectors from the development set. For the purposes of this guide we use random forest as the selected matcher.

# %%
# Train using feature vectors from I 
result['selected_matcher'].fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'], 
       target_attr='match')

# %% [markdown]
# ### Predicting the matches

# %% [markdown]
# Next, we predict the matches for the evaluation set (using the feature vectors extracted from it).

# %%
# Predict on L 
predictions = result['selected_matcher'].predict(
        table=L, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'], 
        append=True, 
        target_attr='predicted', 
        inplace=False)

# %% [markdown]
# ### Evaluating the predictions

# %% [markdown]
# Finally, we evaluate the accuracy of predicted outputs

# %%
# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'match', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 94.51% (86/91)
# Recall : 92.47% (86/93)
# F1 : 93.48%
# False positives : 5 (out of 91 positive predictions)
# False negatives : 7 (out of 44 negative predictions)

# %%
# em.vis_debug_dt(dt, 
#                 U, V, 
#                 exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
#                 target_attr='match')
