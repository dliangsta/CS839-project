# %% [markdown]
# # Entity matching (EM) for Laptops

# %% [markdown]
# This jupyter notebook contains the commands used for each step in the entity matching process for laptop products from Amazon and Walmart.
# We used the Basic EM workflow 3 as our guide for this process.

# %% [markdown]
# # Step 1: Reading in the input tables A, B.

# %%
import sys
import py_entitymatching as em
import pandas as pd
import os

path_A = 'data/amazon_products.csv'
path_B = 'data/walmart_products.csv'

# Load the csv files as dataframes and set the key attribute in the dataframe
A = em.read_csv_metadata(path_A, key='id')
B = em.read_csv_metadata(path_B, key='id')
print('len(A):' + str(len(A)))
print('len(B):' + str(len(B)))
print('len (A X B):' + str(len(A)*len(B)))
# Out:
# len(A):3000
# len(B):4847
# len (A X B):14541000

# %% [markdown]
# # Step 2: Block tables to get candidate set
#
# In this step, we apply a blocking sequence on the input tables to get the candidate set C.

# %%
# Create an initial blocker
ob = em.OverlapBlocker()

# Use block_tables to apply blocking over two input tables.
C1 = ob.block_tables(A,B, 'model', 'model', 
                     l_output_attrs=['id','model','extended_title'], 
                     r_output_attrs=['id','model','extended_title'],
                     overlap_size=8,
                     q_val=5,
                     word_level=False,
                     show_progress=False,
                     n_jobs=-1
                     )
len(C1)
# Out:
# 2462

# %% [markdown]
# ## Debugging blocker output

# %%
# Debug blocker output
dbg = em.debug_blocker(C1, A, B, 
                        attr_corres=[
                            ('product_title','product_title'),
                            ('brand', 'brand'), 
                            ('model','model'),
                            ('extended_title','extended_title')],
                            verbose=True)
### Display first few tuple pairs from the debug_blocker's output
dbg
# Out:
#      _id ltable_id rtable_id  \
# 0      0      a888     w3221
# 1      1      a389     w3226
# 2      2     a1838     w3122
# 3      3      a888     w3438
# 4      4     a1356     w3178
# 5      5     a1356     w3117
# 6      6     a2070     w1627
# 7      7      a389     w3337
# 8      8     a1356     w3179
# 9      9      a389     w3335
# 10    10      a389     w3221
# 11    11     a1838     w3121
# 12    12      a389     w3438
# 13    13     a1997     w3305
# 14    14     a1838     w3078
# 15    15     a1356     w3225
# 16    16      a888     w3286
# 17    17     a1356     w3180
# 18    18     a1997     w3063
# 19    19     a1838     w3077
# 20    20     a1997     w3263
# 21    21     a1356     w3149
# 22    22      a888     w3226
# 23    23     a1356     w3150
# 24    24     a1997     w3088
# 25    25      a389     w3071
# 26    26     a1997     w3257
# 27    27     a1997     w3302
# 28    28     a1997     w3141
# 29    29     a1356     w3223
# ..   ...       ...       ...
# 170  170      a389     w3290
# 171  171     a2104     w2951
# 172  172     a1838     w3072
# 173  173      a888     w3177
# 174  174      a888     w3151
# 175  175      a389     w3151
# 176  176     a2690     w2687
# 177  177     a2104     w3055
# 178  178     a2490      w344
# 179  179     a1838     w3106
# 180  180      a389     w3177
# 181  181     a2773     w4444
# 182  182      a389     w3225
# 183  183      a389     w3223
# 184  184       a40      w978
# 185  185       a70      w953
# 186  186     a1356     w3224
# 187  187     a1107     w4162
# 188  188     a1356     w3337
# 189  189     a1602      w742
# 190  190     a1356     w3335
# 191  191     a1602     w1264
# 192  192     a2110      w734
# 193  193       a70     w1177
# 194  194     a1480     w2363
# 195  195      a888     w3336
# 196  196     a1356     w3290
# 197  197     a1838     w3286
# 198  198      a777      w634
# 199  199      a888     w3290
#
#                                                                                     ltable_product_title  \
# 0    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 1    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 2    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 3    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 4    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 5    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 6                   the razer blade geforce gtx 1060 14 hd 6th gen intel core i7 16gb 512gb ssd vr ready
# 7    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 8    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 9    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 10   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 11   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 12   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 13       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 14   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 15   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 16   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 17   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 18       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 19   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 20       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 21   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 22   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 23   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 24       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 25   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 26       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 27       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 28       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 29   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# ..                                                                                                   ...
# 170  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 171  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 174  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 175  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 176  lenovo thinkpad p50 windows 10 intel i7 6700hq 64gb 500gb hdd 15.6 fhd ips 1920x1080 nvidia quad...
# 177  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 178  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 180  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 181    lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows 10 80sr002sus
# 182  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 183  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 184  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 185                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 186  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 187                     apple macbook air mqd32ll a 13 1.8ghz intel core i5 dual core 8gb 128gb ssd mac
# 188  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 189  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 190  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 191  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 192                      lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle
# 193                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                                                hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack
# 195  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 198  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
# 199  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
#
#             ltable_brand                 ltable_model  \
# 0                 lenovo                          NaN
# 1                 lenovo                          NaN
# 2                 lenovo                          NaN
# 3                 lenovo                          NaN
# 4                 lenovo                          NaN
# 5                 lenovo                          NaN
# 6                  razer           rz09 01952e72 r3u1
# 7                 lenovo                          NaN
# 8                 lenovo                          NaN
# 9                 lenovo                          NaN
# 10                lenovo                          NaN
# 11                lenovo                          NaN
# 12                lenovo                          NaN
# 13                lenovo                          NaN
# 14                lenovo                          NaN
# 15                lenovo                          NaN
# 16                lenovo                          NaN
# 17                lenovo                          NaN
# 18                lenovo                          NaN
# 19                lenovo                          NaN
# 20                lenovo                          NaN
# 21                lenovo                          NaN
# 22                lenovo                          NaN
# 23                lenovo                          NaN
# 24                lenovo                          NaN
# 25                lenovo                          NaN
# 26                lenovo                          NaN
# 27                lenovo                          NaN
# 28                lenovo                          NaN
# 29                lenovo                          NaN
# ..                   ...                          ...
# 170               lenovo                          NaN
# 171               lenovo                          NaN
# 172               lenovo                          NaN
# 173               lenovo                          NaN
# 174               lenovo                          NaN
# 175               lenovo                          NaN
# 176               lenovo                 thinkpad p50
# 177               lenovo                          NaN
# 178                   hp  hp envy x360 15t ash silver
# 179               lenovo                          NaN
# 180               lenovo                          NaN
# 181               lenovo      ideapad 510 80sr002sus
# 182               lenovo                          NaN
# 183               lenovo                          NaN
# 184                   hp          hp 15.6 touchscreen
# 185                   hp                        hp 15
# 186               lenovo                          NaN
# 187                apple                          NaN
# 188               lenovo                          NaN
# 189  michaelelectronics2                hp 17z laptop
# 190               lenovo                          NaN
# 191  michaelelectronics2                hp 17z laptop
# 192                   lg                          NaN
# 193                   hp                        hp 15
# 194                   hp                          NaN
# 195               lenovo                          NaN
# 196               lenovo                          NaN
# 197               lenovo                          NaN
# 198                 dell                        t8tjg
# 199               lenovo                          NaN
#
#                                                                                    ltable_extended_title  \
# 0    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 1    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 2    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 3    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 4    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 5    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 6    the razer blade geforce gtx 1060 14 hd 6th gen intel core i7 16gb 512gb ssd vr ready rz09 01952e...
# 7    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 8    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 9    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 10   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 11   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 12   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 13              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 14   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 15   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 16   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 17   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 18              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 19   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 20              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 21   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 22   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 23   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 24              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 25   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 26              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 27              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 28              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 29   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# ..                                                                                                   ...
# 170  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 171  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 174  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 175  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 176  lenovo thinkpad p50 windows 10 intel i7 6700hq 64gb 500gb hdd 15.6 fhd ips 1920x1080 nvidia quad...
# 177  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 178  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 180  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 181  lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows 10 80sr002su...
# 182  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 183  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 184  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 185                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 186  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 187                    apple macbook air mqd32ll a 13 1.8ghz intel core i5 dual core 8gb 128gb ssd mac x
# 188  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 189  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 190  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 191  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 192           lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle windows 10
# 193                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                                     hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack windows 10
# 195  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 198  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
# 199  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
#
#                                                                                     rtable_product_title  \
# 0    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 1    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 2    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x...
# 3    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 4    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 5    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 6           the razer blade geforce gtx 1060 14 hd 7th gen intel core i7 16gb 512gb ssd vr ready chassis
# 7    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 8    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 9    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 10   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 11   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x10...
# 12   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 13        lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 14   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x...
# 15   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 16   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 17   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440...
# 18   lenovo thinkpad t460s touch windows 8.1 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 t...
# 19   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x10...
# 20   lenovo thinkpad t460s touch windows 10 intel core i7 6600u 8gb 1tb ssd 14 ips fhd 1920x1080 touc...
# 21   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 22   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 23   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440...
# 24      lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 128gb ssd 14 ips fhd 1920x1080 ac wifi
# 25   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x1...
# 26        lenovo thinkpad t460s windows 8.1 intel core i7 6600u 8gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 27        lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 28        lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 512gb ssd 14 ips fhd 1920x1080 ac wifi
# 29   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# ..                                                                                                   ...
# 170  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 171  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 256gb ssd 8gb 14 fhd ips 1920x1080 int...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 fhd ips 1920x1080 i...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 174  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 175  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 176  lenovo thinkpad p50 windows 10 intel i7 6700hq 64gb 500gb hdd 15.6 fhd ips 1920x1080 nvidia quad...
# 177  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 1tb ssd 8gb 14 fhd ips 1920x1080 intel...
# 178  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 fhd ips 1920x1080 i...
# 180  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 181  refurbished lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows ...
# 182  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 183  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# 184  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 185                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 186  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x...
# 187                     apple 13 macbook air 1.8ghz intel core i5 dual core 8gb 128gb ssd mac mqd32ll a
# 188  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 189  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 190  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 191  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 192                      lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle
# 193                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                                                hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack
# 195  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 198  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
# 199  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
#
#             rtable_brand              rtable_model  \
# 0                 lenovo                       NaN
# 1                 lenovo                       NaN
# 2                 lenovo                       NaN
# 3                 lenovo                       NaN
# 4                 lenovo                       NaN
# 5                 lenovo                       NaN
# 6                  razer        rz09 01953e72 r3u1
# 7                 lenovo                       NaN
# 8                 lenovo                       NaN
# 9                 lenovo                       NaN
# 10                lenovo                       NaN
# 11                lenovo                       NaN
# 12                lenovo                       NaN
# 13                lenovo                       NaN
# 14                lenovo                       NaN
# 15                lenovo                       NaN
# 16                lenovo                       NaN
# 17                lenovo                       NaN
# 18                lenovo                       NaN
# 19                lenovo                       NaN
# 20                lenovo                       NaN
# 21                lenovo                       NaN
# 22                lenovo                       NaN
# 23                lenovo                       NaN
# 24                lenovo                       NaN
# 25                lenovo                       NaN
# 26                lenovo                       NaN
# 27                lenovo                       NaN
# 28                lenovo                       NaN
# 29                lenovo                       NaN
# ..                   ...                       ...
# 170               lenovo                       NaN
# 171               lenovo                       NaN
# 172               lenovo                       NaN
# 173               lenovo                       NaN
# 174               lenovo                       NaN
# 175               lenovo                       NaN
# 176               lenovo                       NaN
# 177               lenovo                       NaN
# 178  michaelelectronics2  hp 15 02336 x360 fhd me7
# 179               lenovo                       NaN
# 180               lenovo                       NaN
# 181               lenovo                       NaN
# 182               lenovo                       NaN
# 183               lenovo                       NaN
# 184                   hp                      2018
# 185                   hp                       NaN
# 186               lenovo                       NaN
# 187                apple                       NaN
# 188               lenovo                       NaN
# 189  michaelelectronics2       hp 17 02339 hdt me2
# 190               lenovo                       NaN
# 191  michaelelectronics2       hp 17 02339 hdt me8
# 192                   lg           15z970 a.aas7u1
# 193                   hp                       NaN
# 194                   hp               2kw14ua#aba
# 195               lenovo                       NaN
# 196               lenovo                       NaN
# 197               lenovo                       NaN
# 198                 dell                       NaN
# 199               lenovo                       NaN
#
#                                                                                    rtable_extended_title
# 0    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 1    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 2    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x...
# 3    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 4    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 5    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 6    the razer blade geforce gtx 1060 14 hd 7th gen intel core i7 16gb 512gb ssd vr ready rz09 01953e...
# 7    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 8    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 9    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 10   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 11   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x10...
# 12   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 13               lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080
# 14   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x...
# 15   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 16   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 17   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440...
# 18   lenovo thinkpad t460s touch windows 8.1 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 t...
# 19   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x10...
# 20   lenovo thinkpad t460s touch windows 10 intel core i7 6600u 8gb 1tb ssd 14 ips fhd 1920x1080 touc...
# 21   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 22   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 23   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440...
# 24             lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 128gb ssd 14 ips fhd 1920x1080
# 25   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x1...
# 26               lenovo thinkpad t460s windows 8.1 intel core i7 6600u 8gb 1tb ssd 14 ips fhd 1920x1080
# 27               lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080
# 28               lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 512gb ssd 14 ips fhd 1920x1080
# 29   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# ..                                                                                                   ...
# 170  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 171  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 256gb ssd 8gb 14 fhd ips 1920x1080 int...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 fhd ips 1920x1080 i...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 174  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 175  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 176  lenovo thinkpad p50 windows 10 intel i7 6700hq 64gb 500gb hdd 15.6 fhd ips 1920x1080 nvidia quad...
# 177  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 1tb ssd 8gb 14 fhd ips 1920x1080 intel...
# 178  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 fhd ips 1920x1080 i...
# 180  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 181  refurbished lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows ...
# 182  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 183  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# 184  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 185                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 186  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x...
# 187    apple 13 macbook air 1.8ghz intel core i5 dual core 8gb 128gb ssd mac mqd32ll a microsoft windows
# 188  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 189  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 190  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 191  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 192           lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle windows 10
# 193                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                         hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack 2kw14ua#aba windows 10
# 195  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 198  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
# 199  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
#
# [200 rows x 11 columns]

# %% [markdown]
# Looking at the debug blocker's output, we observe that the initial blocker is dropping a lot of potential matches.
# Blocking on the column brand alone seems incorrect.

# %%
# # Create overlap blocker
ob = em.OverlapBlocker()

# # Block tables using 'extended_title' attribute 
C2 = ob.block_tables(A, B, 'extended_title', 'extended_title', 
                     l_output_attrs=['id','model','extended_title'], 
                     r_output_attrs=['id','model','extended_title'],
                     overlap_size=25,
                     q_val=5,
                     word_level=False,
                     show_progress=False,
                     n_jobs=-1
                    )
# Updated blocking sequence
# A, B ------ overlap blocker [extended_title] ---------> C1--|
#                                                             |----> C
# A, B ------ overlap blocker [model] ------------------> C2--|

C = em.combine_blocker_outputs_via_union([C1,C2])
print ('Reduction on AxB by applying the blocker:' + str(int((len(A)*len(B))/len(C))) + 'x')
# Out:
# Reduction on AxB by applying the blocker:44x

# %%
# Debug blocker output
dbg = em.debug_blocker(C, A, B, 
                        attr_corres=[
                            ('product_title','product_title'),
                            ('brand', 'brand'), 
                            ('model','model'),
                            ('extended_title','extended_title')],
                            verbose=True)
### Display first few tuple pairs from the debug_blocker's output
dbg
# Out:
#      _id ltable_id rtable_id  \
# 0      0      a820     w4318
# 1      1     a1166     w4520
# 2      2     a1739     w3173
# 3      3     a1739       w84
# 4      4     a1739      w526
# 5      5     a2844     w1177
# 6      6     a2844      w953
# 7      7     a1739     w3220
# 8      8     a1731      w809
# 9      9     a1739      w493
# 10    10     a2209      w644
# 11    11      a114     w2061
# 12    12     a1194      w958
# 13    13      a432      w144
# 14    14      a696     w2308
# 15    15      a432      w361
# 16    16     a1679      w605
# 17    17     a2844     w2225
# 18    18     a2172     w2011
# 19    19      a410     w2530
# 20    20     a2078      w375
# 21    21     a2873      w425
# 22    22     a2544       w32
# 23    23     a1144     w1177
# 24    24     a1144      w953
# 25    25      a329      w603
# 26    26      a410      w953
# 27    27     a2785     w1212
# 28    28      a114     w2752
# 29    29     a2873      w454
# ..   ...       ...       ...
# 170  170       a12     w4070
# 171  171       a12     w4069
# 172  172       a12     w4097
# 173  173     a1202     w4132
# 174  174       a12     w4105
# 175  175      a551      w953
# 176  176      a551     w1177
# 177  177       a12     w4132
# 178  178     a2172     w1995
# 179  179     a2060     w2546
# 180  180     a2078     w3512
# 181  181     a2279      w876
# 182  182     a2094     w1380
# 183  183     a2100     w2566
# 184  184     a2116     w2546
# 185  185     a2276     w2006
# 186  186     a2124      w247
# 187  187     a2267     w2363
# 188  188     a2124     w2638
# 189  189      a197     w2308
# 190  190     a2142     w2747
# 191  191     a2267      w591
# 192  192     a2164     w2918
# 193  193      a149     w2579
# 194  194      a197     w2225
# 195  195     a2174      w714
# 196  196      a134      w585
# 197  197     a2245      w699
# 198  198     a2174     w1165
# 199  199     a2174     w1189
#
#                                                                                     ltable_product_title  \
# 0                                                   hp 15 amd a9 9420 apu 8gb 1tb windows 10 15 bw030nr
# 1                                                acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10
# 2                                                lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd
# 3                                                lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd
# 4                                                lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd
# 5                                 hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 home
# 6                                 hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 home
# 7                                                lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd
# 8                                        newest hp 15.6 hd intel pentium 8gb 1tb hdd writerhd windows 10
# 9                                                lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd
# 10                           hp 3fb86ut zbook x2 g4 tablet core i7 7600u 2.8 ghz win 10 16 gb 512 gb ssd
# 11                            hp elitebook 9470m 14 intel core i5 3427u 1.8ghz 8gb 180gb ssd windows 10
# 12   hp 15.6 hd latest intel core i5 7200u 2.5ghz 12gb ddr4 1tb hdd hdmi supermulti hd windows 10 silver
# 13                        dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10
# 14                                    hp pavilion 15 intel core i7 7500u 12gb 1tb windows 10 15 cc020nr
# 15                        dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10
# 16   hp 15 ba077cl 2017 amd amd a12 9700p quad core 2.50ghz 3.4ghz burst 8gb 1tb 15.6 1366x768 window...
# 17                                hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 home
# 18   acer aspire 5 a515 51 89up 15.6 intel core i7 8550u 1.8ghz microsoft windows 10 8gb ddr4 1tb 540...
# 19                              2017 hp pc 15.6 hd intel pentium quad core 8gb 500gb hdd hdmi windows 10
# 20                                                 hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd
# 21                                                        thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd
# 22        2017 lenovo flex 4 2 1 14 full hd touchscreen pc intel core i7 7500u 8gb 512gb ssd windows 10
# 23                                           hp 250 g5 15.6 intel core i3 5005u windows 10 8gb 1tb drive
# 24                                           hp 250 g5 15.6 intel core i3 5005u windows 10 8gb 1tb drive
# 25                                              hp 15 intel core i5 7200u 8gb 1tb windows 10 15 bs030nr
# 26                              2017 hp pc 15.6 hd intel pentium quad core 8gb 500gb hdd hdmi windows 10
# 27                          2018 dell pc 15.6 fhd intel i7 7500u 8gb ddr4 1tb hdd hdmi windows 10 silver
# 28                            hp elitebook 9470m 14 intel core i5 3427u 1.8ghz 8gb 180gb ssd windows 10
# 29                                                        thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd
# ..                                                                                                   ...
# 170                                                                              apple 13.3 macbook air
# 171                                                                              apple 13.3 macbook air
# 172                                                                              apple 13.3 macbook air
# 173                                                                    apple macbook air md760ll a 13.3
# 174                                                                              apple 13.3 macbook air
# 175                              hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 176                              hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 177                                                                              apple 13.3 macbook air
# 178  acer aspire 5 a515 51 89up 15.6 intel core i7 8550u 1.8ghz microsoft windows 10 8gb ddr4 1tb 540...
# 179                                  lenovo ideapad 300 15.6 core i7 8 gb 1 tb hdd windows 10 80q70020us
# 180                                                hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd
# 181                                           hp chromebook 11 11.6 hd intel celeron n3060 4gb 16gb emmc
# 182  omen x hp vr ready pc intel i7 7820hk quad core 32gb 2tb ssd 17.3 fhd 1920 x 1080 nvidia geforce...
# 183  hp envy 17t touch 17.3 full hd 8th gen intel core i7 8550u 4.0 ghz 16gb 2tb hdd 4gb nvidia gefor...
# 184                                                            hp 15 ba040nr 15.6 amd a10 8 gb 1 tb hdd
# 185  2018 acer aspire e5 575 15.6 full hd 7th gen intel core i7 7500u 3.5ghz 8gb ddr4 1tb hdd usb c w...
# 186                              lenovo flex 5 15.6 2 1 intel core i7 8 gb 1tb hdd windows 10 80xb0004us
# 187                                                                  hp 17.3 intel core i7 8gb 1tb black
# 188                              lenovo flex 5 15.6 2 1 intel core i7 8 gb 1tb hdd windows 10 80xb0004us
# 189                                          hp 15 bs015dx 15.6 hd touch core i5 7200u 8gb 1tb hdd black
# 190                              dell xps9350 2008slv 13.3 intel core i5 8 gb 128 gb ssd microsoft image
# 191                                                                  hp 17.3 intel core i7 8gb 1tb black
# 192                                 dell latitude e7440 14 intel core i5 i5 4300u 1.90 ghz 4gb 500gb w7p
# 193                                                     lenovo 320 15 15.6 hd amd a12 9720p 8gb 1tb gray
# 194                                          hp 15 bs015dx 15.6 hd touch core i5 7200u 8gb 1tb hdd black
# 195         2018 hp 15.6 intel core i3 7100u 2.4ghz 16gb ddr4 512gb ssd intel hd 620 hd windows 10 black
# 196                                                                    hp 17.3 intel core i5 8gb 1tb hdd
# 197           dell 6w3dr xps 13 13.3 qhd intel core i5 7200u 8gb lpddr3 128gb solid state windows 10 pro
# 198         2018 hp 15.6 intel core i3 7100u 2.4ghz 16gb ddr4 512gb ssd intel hd 620 hd windows 10 black
# 199         2018 hp 15.6 intel core i3 7100u 2.4ghz 16gb ddr4 512gb ssd intel hd 620 hd windows 10 black
#
#             ltable_brand     ltable_model  \
# 0                     hp       15 bw030nr
# 1                   acer     nx.gr7aa.007
# 2                 lenovo       20hk001jus
# 3                 lenovo       20hk001jus
# 4                 lenovo       20hk001jus
# 5                     hp       15 ay197cl
# 6                     hp       15 ay197cl
# 7                 lenovo       20hk001jus
# 8              hp laptop              NaN
# 9                 lenovo       20hk001jus
# 10                   NaN          3fb86ut
# 11                    hp            9470m
# 12                    hp    hp 15 ay117cl
# 13                  dell            t8tjg
# 14                    hp       15 cc020nr
# 15                  dell            t8tjg
# 16                    hp          1bp93ua
# 17                    hp       15 ay197cl
# 18                  acer              NaN
# 19                    hp            t8tjg
# 20                    hp        13 d010nr
# 21                lenovo       20hd0057us
# 22                lenovo              NaN
# 23                    hp      x9u74ut#aba
# 24                    hp      x9u74ut#aba
# 25                    hp       15 bs030nr
# 26                    hp            t8tjg
# 27                  dell              NaN
# 28                    hp            9470m
# 29                lenovo       20hd0057us
# ..                   ...              ...
# 170                apple        mlh72ll a
# 171                apple        mlh72ll a
# 172                apple        mlh72ll a
# 173                apple        md760ll a
# 174                apple        mlh72ll a
# 175                   hp              NaN
# 176                   hp              NaN
# 177                apple        mlh72ll a
# 178                 acer              NaN
# 179               lenovo       80q70020us
# 180                   hp        13 d010nr
# 181                   hp          x7t68ua
# 182  michaelelectronics2              NaN
# 183                   hp      hp envy 17t
# 184                   hp      w2m95ua#aba
# 185          acer_aspire              NaN
# 186               lenovo       80xb0004us
# 187                   hp            t8tjg
# 188               lenovo       80xb0004us
# 189                   hp       15 bs015dx
# 190                 dell  xps9350 2008slv
# 191                   hp            t8tjg
# 192                 dell         730 6964
# 193               lenovo            t8tjg
# 194                   hp       15 bs015dx
# 195                   hp               hp
# 196                   hp          1bq14ua
# 197                 dell            6w3dr
# 198                   hp               hp
# 199                   hp               hp
#
#                                                                                    ltable_extended_title  \
# 0                                                   hp 15 amd a9 9420 apu 8gb 1tb windows 10 15 bw030nr
# 1                                    acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10 nx.gr7aa.007
# 2               lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd lenovo 20hk001jus not applicable
# 3               lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd lenovo 20hk001jus not applicable
# 4               lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd lenovo 20hk001jus not applicable
# 5                           hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 15 ay197cl
# 6                           hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 15 ay197cl
# 7               lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd lenovo 20hk001jus not applicable
# 8                                 newest hp 15.6 hd intel pentium 8gb 1tb hdd writerhd windows 10 laptop
# 9               lenovo thinkpad p71 17.3 core i7 7700hq 8 gb 256 gb ssd lenovo 20hk001jus not applicable
# 10                   hp 3fb86ut zbook x2 g4 tablet core i7 7600u 2.8 ghz win 10 16 gb 512 gb ssd unknown
# 11                hp elitebook 9470m 14 intel core i5 3427u 1.8ghz 8gb 180gb ssd windows 10 professional
# 12   hp 15.6 hd latest intel core i5 7200u 2.5ghz 12gb ddr4 1tb hdd hdmi supermulti hd windows 10 15 ...
# 13                  dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10 t8tjg
# 14                                    hp pavilion 15 intel core i7 7500u 12gb 1tb windows 10 15 cc020nr
# 15                  dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10 t8tjg
# 16   hp 15 ba077cl 2017 amd amd a12 9700p quad core 2.50ghz 3.4ghz burst 8gb 1tb 15.6 1366x768 window...
# 17                          hp full hd 15.6 intel core i5 7200u 2.5ghz 8gb 1tb hdd windows 10 15 ay197cl
# 18   acer aspire 5 a515 51 89up 15.6 intel core i7 8550u 1.8ghz microsoft windows 10 8gb ddr4 1tb 540...
# 19                        2017 hp pc 15.6 hd intel pentium quad core 8gb 500gb hdd hdmi windows 10 t8tjg
# 20                                          hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd windows
# 21                              thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd lenovo 20hd0057us unknown
# 22        2017 lenovo flex 4 2 1 14 full hd touchscreen pc intel core i7 7500u 8gb 512gb ssd windows 10
# 23                                     hp 250 g5 15.6 intel core i3 5005u windows 10 8gb 1tb x9u74ut#aba
# 24                                     hp 250 g5 15.6 intel core i3 5005u windows 10 8gb 1tb x9u74ut#aba
# 25                                              hp 15 intel core i5 7200u 8gb 1tb windows 10 15 bs030nr
# 26                        2017 hp pc 15.6 hd intel pentium quad core 8gb 500gb hdd hdmi windows 10 t8tjg
# 27                                2018 dell pc 15.6 fhd intel i7 7500u 8gb ddr4 1tb hdd hdmi windows 10
# 28                hp elitebook 9470m 14 intel core i5 3427u 1.8ghz 8gb 180gb ssd windows 10 professional
# 29                              thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd lenovo 20hd0057us unknown
# ..                                                                                                   ...
# 170                                                                   apple 13.3 macbook air mlh72ll a x
# 171                                                                   apple 13.3 macbook air mlh72ll a x
# 172                                                                   apple 13.3 macbook air mlh72ll a x
# 173                                                         apple macbook air md760ll a 13.3 x mavericks
# 174                                                                   apple 13.3 macbook air mlh72ll a x
# 175                              hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 176                              hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 177                                                                   apple 13.3 macbook air mlh72ll a x
# 178  acer aspire 5 a515 51 89up 15.6 intel core i7 8550u 1.8ghz microsoft windows 10 8gb ddr4 1tb 540...
# 179                                 lenovo ideapad 300 15.6 core i7 8 gb 1 tb hdd windows 10 80q70020us
# 180                                         hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd windows
# 181                                hp chromebook 11 11.6 hd intel celeron n3060 4gb 16gb emmc x7t68ua os
# 182  omen x hp vr ready pc intel i7 7820hk quad core 32gb 2tb ssd 17.3 fhd 1920 x 1080 nvidia geforce...
# 183  hp envy 17t touch 17.3 full hd 8th gen intel core i7 8550u 4.0 ghz 16gb 2tb hdd 4gb nvidia gefor...
# 184                                         hp 15 ba040nr 15.6 amd a10 8 gb 1 tb hdd w2m95ua#aba windows
# 185  2018 acer aspire e5 575 15.6 full hd 7th gen intel core i7 7500u 3.5ghz 8gb ddr4 1tb hdd usb c w...
# 186                         lenovo flex 5 15.6 2 1 intel core i7 8 gb 1tb hdd windows 10 80xb0004us home
# 187                                                       hp 17.3 intel core i7 8gb 1tb t8tjg windows 10
# 188                         lenovo flex 5 15.6 2 1 intel core i7 8 gb 1tb hdd windows 10 80xb0004us home
# 189                                     hp 15 bs015dx 15.6 hd touch core i5 7200u 8gb 1tb hdd windows 10
# 190                         dell xps9350 2008slv 13.3 intel core i5 8 gb 128 gb ssd microsoft windows 10
# 191                                                       hp 17.3 intel core i7 8gb 1tb t8tjg windows 10
# 192             dell latitude e7440 14 intel core i5 i5 4300u 1.90 ghz 4gb 500gb w7p 730 6964 windows 7
# 193                                         lenovo 320 15 15.6 hd amd a12 9720p 8gb 1tb t8tjg windows 10
# 194                                     hp 15 bs015dx 15.6 hd touch core i5 7200u 8gb 1tb hdd windows 10
# 195              2018 hp 15.6 intel core i3 7100u 2.4ghz 16gb ddr4 512gb ssd intel hd 620 hd windows 10
# 196                                                 hp 17.3 intel core i5 8gb 1tb hdd 1bq14ua windows 10
# 197              dell 6w3dr xps 13 13.3 qhd intel core i5 7200u 8gb lpddr3 128gb solid state windows 10
# 198              2018 hp 15.6 intel core i3 7100u 2.4ghz 16gb ddr4 512gb ssd intel hd 620 hd windows 10
# 199              2018 hp 15.6 intel core i3 7100u 2.4ghz 16gb ddr4 512gb ssd intel hd 620 hd windows 10
#
#                                                                                     rtable_product_title  \
# 0                                  manufacturer hp 15 bw070nr 15.6 amd a9 9420 3.0ghz 4gb 1tb windows 10
# 1                                   refurbished acer amd fx series 3 ghz 8 gb 256 gb ssd windows 10 home
# 2                                             lenovo thinkpad x1 carbon 14 core i7 7600u 8 gb 256 gb ssd
# 3                                            lenovo thinkpad yoga 370 13.3 core i7 7500u 8 gb 256 gb ssd
# 4                                              lenovo thinkpad x1 tablet 12 core i7 7y75 8 gb 256 gb ssd
# 5                     hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 6                     hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 7                                             lenovo thinkpad x1 carbon 14 core i7 7500u 8 gb 256 gb ssd
# 8                       2017 hp touchscreen 15.6 hd intel i3 7100u dual core 8gb 1tb hdd hdmi windows 10
# 9                                               lenovo thinkpad x1 yoga 14 core i7 7600u 8 gb 256 gb ssd
# 10                                                   hp zbook 15u g4 15.6 core i7 7500u 16 gb 512 gb ssd
# 11                                    factory hp 9470m 14 windows 10 intel core i5 3437u 8gb 320gb drive
# 12   2018 hp 15.6 hd touchscreen intel dual core i5 7200u 3.1ghz 8gb ddr4 1tb hdd hdmi hd 620 dts stu...
# 13      refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10 fingerprint
# 14                               hp 15 ay107cl 15.6 hd intel core i7 7500u 16g 1tb hdd rw windows 10 red
# 15      refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10 fingerprint
# 16                       hp 15 bw040nr 15.6 touchscreen windows 10 amd quad core a12 9720p 8gb 1tb drive
# 17               hp envy 15 as014wm 15.6 full hd ips touch windows 10 intel core i7 6500u 8gb 1tb silver
# 18   acer aspire 5 a515 51 75uy 15.6 full hd 1920 x 1080 7th gen intel core i7 7500u 8gb ddr4 1tb hdd...
# 19          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 20                                       hp elitebook x360 1030 g2 13.3 core i5 7200u 8 gb 128 gb ssd us
# 21                                             lenovo thinkpad x1 tablet 12 core i7 7y75 8 gb 256 gb ssd
# 22                             lenovo flex 5 2 1 core i5 8250u 8gb 128gb ssd 14 full hd touch windows 10
# 23                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 24                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 25              hp pavilion 15 au030wm 15.6 manhattan touch windows 10 intel core i5 6200u 8gb 1tb drive
# 26                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 27                       refurbished dell inspiron 15.6 fhd touch i7 7500u 8gb 500gb hdd windows 10 grey
# 28                                         refurbished 14 hp elitebook 9470m i5 8gb 500gb windows 10 pro
# 29                                              lenovo thinkpad x1 yoga 14 core i5 7200u 8 gb 256 gb ssd
# ..                                                                                                   ...
# 170                                                                    apple macbook air 11.6 md712ll a
# 171                                                                    apple macbook air 11.6 md224ll a
# 172                                                   apple macbook air md231ll a 13.3 scratched dented
# 173                                                                    apple macbook air 13.3 md761ll a
# 174                                                                    apple macbook air 11.6 md712ll a
# 175                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 176                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 177                                                                    apple macbook air 13.3 md761ll a
# 178  acer aspire 5 a515 51 563w 15.6 full hd 1920 x 1080 7th gen intel core i5 7200u 8gb ddr4 1tb hdd...
# 179                                                  hp zbook 15 g4 15.6 core i7 7700hq 8 gb 1 tb hdd us
# 180                                               apple macbook air 13.3 core i5 8 gb 128 gb ssd english
# 181            refurbished hp 11 v020wm 11.6 chromebook touchscreen chrome intel celeron n3060 processor
# 182  hp omen 17 17.3 uhd 4k vr ready intel i7 2tb ssd 17.3 uhd 3840 x 2160 32gb geforce gtx 1060 win 10
# 183                                                  hp envy 17t core i7 8550u 16gb 17.3 full hd 1tb hdd
# 184                                                  hp zbook 15 g4 15.6 core i7 7700hq 8 gb 1 tb hdd us
# 185        acer aspire a315 51 51sl 15.6 hd 7th gen intel core i5 7200u 6gb ddr4 1tb hdd windows 10 home
# 186                     refurbished acer nitro spin 5 intel core i7 1.8 ghz 8 gb 1tb hdd windows 10 home
# 187                                                hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack
# 188                                                   lenovo 320s 15ikb 15.6 core i7 7500u 8 gb 1 tb hdd
# 189                              hp 15 ay107cl 15.6 hd intel core i7 7500u 16g 1tb hdd rw windows 10 red
# 190                                                  dell latitude 7480 14 core i5 7300u 8 gb 128 gb ssd
# 191         refurbished hp envy 15 as014wm 15.6 touchscreen windows 10 intel core i7 6500u 8gb 1tb drive
# 192                                    refurbished elitebook 14 intel core i5 i5 4300u 1.90 ghz platinum
# 193                                      hp 15.6 hd amd a12 quad core 8gb 1tb optical hd windows 10 home
# 194              hp envy 15 as014wm 15.6 full hd ips touch windows 10 intel core i7 6500u 8gb 1tb silver
# 195  2018 hp 15.6 touchscreen hd intel dual core i3 7100u 2.40ghz 8gb ddr4 1tb hdd hdmi hd 620 rw 8 h...
# 196                          hp 15 bs030nr 15.6 touchscreen windows 10 intel core i5 7200u 8gb 1tb drive
# 197                  dell 13.3 xps 13 pc intel core i7 6560u 8gb touch 256gb solid state windows 10 home
# 198  lenovo ideapad 320 15.6 hd touchscreen intel dual core i3 7100u 2.4ghz 6gb ddr4 128gb ssd hdmi r...
# 199  lenovo ideapad 320 15.6 hd touchscreen intel dual core i3 7100u 2.4ghz 6gb ddr4 256gb ssd hdmi r...
#
#     rtable_brand      rtable_model  \
# 0             hp     15 bw070nr rf
# 1           acer      nh.q2uaa.003
# 2         lenovo        20hr000hus
# 3         lenovo        20jh002fus
# 4         lenovo        20jb002nus
# 5             hp               NaN
# 6             hp               NaN
# 7         lenovo        20hr0053us
# 8             hp              2017
# 9         lenovo        20jd000qus
# 10            hp       1bs35ut#aba
# 11            hp         wa5 30166
# 12            hp              2018
# 13          dell               NaN
# 14            hp               NaN
# 15          dell               NaN
# 16            hp       1kv17ua#aba
# 17            hp        15 as014wm
# 18          acer      nx.gp4aa.004
# 19            hp               NaN
# 20            hp       1nm36ut#aba
# 21        lenovo        20jb002lus
# 22        lenovo        81c9000cus
# 23            hp               NaN
# 24            hp               NaN
# 25            hp       w2l55ua#aba
# 26            hp               NaN
# 27          dell               NaN
# 28            hp               NaN
# 29        lenovo        20jf000bus
# ..           ...               ...
# 170        apple               NaN
# 171        apple               NaN
# 172        apple               NaN
# 173        apple               NaN
# 174        apple               NaN
# 175           hp               NaN
# 176           hp               NaN
# 177        apple               NaN
# 178          NaN               NaN
# 179           hp       1jd32ut#aba
# 180        apple         mqd32ll a
# 181           hp         11 v020wm
# 182           hp               NaN
# 183           hp         17 u275cl
# 184           hp       1jd32ut#aba
# 185         acer      a315 51 51sl
# 186         acer      nh.q2yaa.002
# 187           hp       2kw14ua#aba
# 188       lenovo        80x50002us
# 189           hp               NaN
# 190         dell             7dtn9
# 191           hp        15 as014wm
# 192           hp               NaN
# 193          NaN               NaN
# 194           hp        15 as014wm
# 195           hp               NaN
# 196           hp       1kv01ua#aba
# 197         dell   xps9350 5341slv
# 198       lenovo  len320i37t 6128p
# 199       lenovo  len320i37t 6256p
#
#                                                                                    rtable_extended_title
# 0          manufacturer hp 15 bw070nr 15.6 amd a9 9420 3.0ghz 4gb 1tb windows 10 15 bw070nr rf microsoft
# 1                           refurbished acer amd fx series 3 ghz 8 gb 256 gb ssd windows 10 nh.q2uaa.003
# 2                      lenovo thinkpad x1 carbon 14 core i7 7600u 8 gb 256 gb ssd 20hr000hus windows 10
# 3                     lenovo thinkpad yoga 370 13.3 core i7 7500u 8 gb 256 gb ssd 20jh002fus windows 10
# 4                       lenovo thinkpad x1 tablet 12 core i7 7y75 8 gb 256 gb ssd 20jb002nus windows 10
# 5                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 6                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 7                      lenovo thinkpad x1 carbon 14 core i7 7500u 8 gb 256 gb ssd 20hr0053us windows 10
# 8                      2017 hp touchscreen 15.6 hd intel i3 7100u dual core 8gb 1tb hdd hdmi windows 10
# 9                        lenovo thinkpad x1 yoga 14 core i7 7600u 8 gb 256 gb ssd 20jd000qus windows 10
# 10                            hp zbook 15u g4 15.6 core i7 7500u 16 gb 512 gb ssd 1bs35ut#aba windows 10
# 11                                factory hp 9470m 14 windows 10 intel core i5 3437u 8gb 320gb wa5 30166
# 12   2018 hp 15.6 hd touchscreen intel dual core i5 7200u 3.1ghz 8gb ddr4 1tb hdd hdmi hd 620 dts stu...
# 13                 refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10
# 14                                  hp 15 ay107cl 15.6 hd intel core i7 7500u 16g 1tb hdd rw windows 10
# 15                 refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10
# 16                 hp 15 bw040nr 15.6 touchscreen windows 10 amd quad core a12 9720p 8gb 1tb 1kv17ua#aba
# 17                     hp envy 15 as014wm 15.6 full hd ips touch windows 10 intel core i7 6500u 8gb 1tb
# 18   acer aspire 5 a515 51 75uy 15.6 full hd 1920 x 1080 7th gen intel core i7 7500u 8gb ddr4 1tb hdd...
# 19          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 20                   hp elitebook x360 1030 g2 13.3 core i5 7200u 8 gb 128 gb ssd us 1nm36ut#aba windows
# 21                      lenovo thinkpad x1 tablet 12 core i7 7y75 8 gb 256 gb ssd 20jb002lus windows 10
# 22        lenovo flex 5 2 1 core i5 8250u 8gb 128gb ssd 14 full hd touch windows 10 81c9000cus microsoft
# 23                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 24                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 25        hp pavilion 15 au030wm 15.6 manhattan touch windows 10 intel core i5 6200u 8gb 1tb w2l55ua#aba
# 26                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 27                  refurbished dell inspiron 15.6 fhd touch i7 7500u 8gb 500gb hdd windows 10 microsoft
# 28                                            refurbished 14 hp elitebook 9470m i5 8gb 500gb windows 10
# 29                       lenovo thinkpad x1 yoga 14 core i5 7200u 8 gb 256 gb ssd 20jf000bus windows 10
# ..                                                                                                   ...
# 170                                                                    apple macbook air 11.6 md712ll a
# 171                                                                    apple macbook air 11.6 md224ll a
# 172                                  apple macbook air md231ll a 13.3 scratched dented microsoft windows
# 173                                                                    apple macbook air 13.3 md761ll a
# 174                                                                    apple macbook air 11.6 md712ll a
# 175                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 176                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 177                                                                    apple macbook air 13.3 md761ll a
# 178  acer aspire 5 a515 51 563w 15.6 full hd 1920 x 1080 7th gen intel core i5 7200u 8gb ddr4 1tb hdd...
# 179                           hp zbook 15 g4 15.6 core i7 7700hq 8 gb 1 tb hdd us 1jd32ut#aba windows 10
# 180                                      apple macbook air 13.3 core i5 8 gb 128 gb ssd mqd32ll a sierra
# 181                   refurbished hp 11 v020wm 11.6 chromebook touchscreen chrome intel celeron n3060 os
# 182  hp omen 17 17.3 uhd 4k vr ready intel i7 2tb ssd 17.3 uhd 3840 x 2160 32gb geforce gtx 1060 win 10
# 183                             hp envy 17t core i7 8550u 16gb 17.3 full hd 1tb hdd 17 u275cl windows 10
# 184                           hp zbook 15 g4 15.6 core i7 7700hq 8 gb 1 tb hdd us 1jd32ut#aba windows 10
# 185  acer aspire a315 51 51sl 15.6 hd 7th gen intel core i5 7200u 6gb ddr4 1tb hdd windows 10 a315 51...
# 186             refurbished acer nitro spin 5 intel core i7 1.8 ghz 8 gb 1tb hdd windows 10 nh.q2yaa.002
# 187                         hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack 2kw14ua#aba windows 10
# 188                             lenovo 320s 15ikb 15.6 core i7 7500u 8 gb 1 tb hdd 80x50002us windows 10
# 189                                 hp 15 ay107cl 15.6 hd intel core i7 7500u 16g 1tb hdd rw windows 10
# 190                 dell latitude 7480 14 core i5 7300u 8 gb 128 gb ssd 7dtn9 windows 10 french spanish
# 191              refurbished hp envy 15 as014wm 15.6 touchscreen windows 10 intel core i7 6500u 8gb 1tb
# 192                                 refurbished elitebook 14 intel core i5 i5 4300u 1.90 ghz platinum hp
# 193                                          hp 15.6 hd amd a12 quad core 8gb 1tb optical hd windows 10
# 194                    hp envy 15 as014wm 15.6 full hd ips touch windows 10 intel core i7 6500u 8gb 1tb
# 195  2018 hp 15.6 touchscreen hd intel dual core i3 7100u 2.40ghz 8gb ddr4 1tb hdd hdmi hd 620 rw 8 h...
# 196                    hp 15 bs030nr 15.6 touchscreen windows 10 intel core i5 7200u 8gb 1tb 1kv01ua#aba
# 197       dell 13.3 xps 13 pc intel core i7 6560u 8gb touch 256gb solid state windows 10 xps9350 5341slv
# 198  lenovo ideapad 320 15.6 hd touchscreen intel dual core i3 7100u 2.4ghz 6gb ddr4 128gb ssd hdmi r...
# 199  lenovo ideapad 320 15.6 hd touchscreen intel dual core i3 7100u 2.4ghz 6gb ddr4 256gb ssd hdmi r...
#
# [200 rows x 11 columns]

# %% [markdown]
# The blocker seem to have reduced the input size by 45x. However, on debugging the blocker we observe that it is still dropping potential matches. So, we are going to debug the blocker further.

# %%
def match_extended_title(attribute='extended_title',q_val=3, threshold=.5,debug=False):
    def jaccard_matcher(ltuple,rtuple, attribute=attribute, q_val=q_val, threshold=threshold,debug=debug):
        buffer = '#' * (q_val-1)
        l_attribute = buffer + ltuple[attribute] + buffer
        r_attribute = buffer + rtuple[attribute] + buffer
        l_grams = set()
        r_grams = set()
        # create sets of grams
        for attribute, grams in [(l_attribute,l_grams), (r_attribute,r_grams)]:
            for i in range(0,len(attribute)-(q_val-1)):
                grams.add(attribute[i:i+q_val])
               
        # compute jaccard
        intersection = list(set(l_grams) & set(r_grams))
        union = list(set(l_grams) | set(r_grams))
        if debug:
            print(union)
            print(intersection)
            print(len(intersection) / len(union))
        return len(intersection) / len(union) < threshold
    
    return jaccard_matcher

bb = em.BlackBoxBlocker()
bb.set_black_box_function(match_extended_title())
C3 = bb.block_candset(C2,  
                     show_progress=False,
                     n_jobs=-1
                     )
# Updated blocking sequence
# A, B --- overlap blocker [model] ---------------------> C1--------------------------------|
#                                                                                     union |---> C
# A, B --- overlap blocker [extended_title] ---> C2---> jaccard blocker [extended_title] ---|
C = em.combine_blocker_outputs_via_union([C1,C3])

# %%
# Debug again
dbg = em.debug_blocker(C, A, B)
dbg
# Out:
#      _id ltable_id rtable_id  \
# 0      0      a298     w3394
# 1      1      a298     w3250
# 2      2      a298     w3400
# 3      3      a298     w3458
# 4      4      a298     w3439
# 5      5      a298     w3327
# 6      6      a298     w3443
# 7      7      a298     w3014
# 8      8      a298     w3015
# 9      9     a2860      w790
# 10    10     a2257      w619
# 11    11     a2257      w659
# 12    12     a1883     w2492
# 13    13      a298     w3422
# 14    14     a1883      w921
# 15    15     a1883     w2762
# 16    16     a1883     w2509
# 17    17     a1701     w2530
# 18    18      a298     w3016
# 19    19      a551      w603
# 20    20     a1329     w1459
# 21    21     a2901     w2220
# 22    22     a1617     w2954
# 23    23       a70       w17
# 24    24      a998      w674
# 25    25     a1514      w557
# 26    26     a1701     w2245
# 27    27     a2637      w748
# 28    28      a791     w3469
# 29    29     a1514      w556
# ..   ...       ...       ...
# 170  170     a2041     w3055
# 171  171     a2093      w289
# 172  172     a2093      w309
# 173  173     a1608      w100
# 174  174     a2097     w2970
# 175  175     a2097     w2699
# 176  176     a2035     w2585
# 177  177     a2019     w2472
# 178  178     a2008     w3024
# 179  179     a1617     w3076
# 180  180     a1767     w2016
# 181  181     a1767     w1987
# 182  182     a1753      w104
# 183  183     a1753       w68
# 184  184     a1617     w3023
# 185  185     a1738     w1556
# 186  186     a1617     w3068
# 187  187     a1617     w3075
# 188  188     a1807      w872
# 189  189     a1617     w3104
# 190  190     a1700     w1449
# 191  191     a1617     w3146
# 192  192     a1700     w1434
# 193  193     a1685      w107
# 194  194     a1653     w3667
# 195  195     a1617     w3173
# 196  196     a1653     w3512
# 197  197     a1919      w432
# 198  198     a1954     w1071
# 199  199     a1617      w454
#
#                                                                                     ltable_product_title  \
# 0    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 1    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 2    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 3    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 4    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 5    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 6    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 7    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 8    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 9    dell xps 15 9560 4k uhd intel core i7 7700hq 16gb 512gb ssd nvidia gtx 1050 4gb gddr5 windows 10...
# 10         newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 11         newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 12                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 13   lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 14                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 15                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 16                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 17   2017 hp fhd 15.6 wled intel core i5 7200u 3.1ghz 8gb ddr4 1tb hdd usb 3.1 802.11 ac hdmi windows 10
# 18   lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 19                               hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 20   prostar clevo n870hp6 17.3” full hd ips intel core i7 7700hq 32gb ddr4 gtx 1060 500gb ssd 1tb hd...
# 21                       hp pavilion 15.6 hd touchscreen intel core i5 8gb 1tb hdd windows 10 15 au057cl
# 22                   lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 23                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 24           hp 15.6 touchscreen quad core amd a12 3.6ghz 8gb 1tb hdd 4gb amd radeon r7 hdmi windows 10
# 25   2018 rca cambio 10.1 2 1 touchscreen tablet pc intel quad core 2gb 32gb microsoft office windows...
# 26   2017 hp fhd 15.6 wled intel core i5 7200u 3.1ghz 8gb ddr4 1tb hdd usb 3.1 802.11 ac hdmi windows 10
# 27   2016 dell inspiron 5000 touchscreen 15.6 fhd 6th intel core i5 6200u 2.8ghz 8 gb 1 tb hdd hdmi 8...
# 28     msi ws63 7rk 290us ips level 15.6 nvidia quadro p3000 i7 7700hq 32gb 512gb ssd 2tb windows 10 pro
# 29   2018 rca cambio 10.1 2 1 touchscreen tablet pc intel quad core 2gb 32gb microsoft office windows...
# ..                                                                                                   ...
# 170                            lenovo thinkpad x1 carbon 20fb002rus 14 intel core i5 6200u 8gb 256gb ssd
# 171  hp envy x360 2 1 15.6 full hd ips touch quad core amd fx 9800p 8gb amd radeon r7 1tb windows 10 ...
# 172  hp envy x360 2 1 15.6 full hd ips touch quad core amd fx 9800p 8gb amd radeon r7 1tb windows 10 ...
# 173                   dell xps 13 9365 13.3 qhd touch intel core i7 7y75 16gb 512gb ssd windows 10 black
# 174  lenovo thinkpad t470p intel core i7 7700hq 14 fhd ips 16gb ddr4 500gb hdd nvidia geforce 940mx w...
# 175  lenovo thinkpad t470p intel core i7 7700hq 14 fhd ips 16gb ddr4 500gb hdd nvidia geforce 940mx w...
# 176         dell tfg4h latitude 3380 13.3 hdf intel core i3 6006u 4gb ddr4 128gb solid state windows 10
# 177                      tw dell latitude 5480 14 hd intel core i5 7300hq windows 10 8gb ddr4 512gb ssd
# 178  msi gs63 stealth 061 i7 7700hq 16gb 128gb nvme ssd 1tb hdd nvidia gtx 1050 2gb 15.6 full hd wind...
# 179                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 180  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 181  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 182                                        dell inspiron 2 1 13.3 touch intel core i7 8gb 256gb ssd gray
# 183                                        dell inspiron 2 1 13.3 touch intel core i7 8gb 256gb ssd gray
# 184                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 185  alienware aw15r2 8469slv 15.6 uhd 6th intel core i7 16 gb 1 tb hdd 256 gb sata ssd nvidia geforc...
# 186                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 187                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 188                            dell xps 13 9350 13.3 intel core i5 6200u 8gb 128gb ssd windows 10 silver
# 189                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 190  hp omen 17 17.3 uhd 4k vr ready intel i7 2tb hdd 512gb ssd 17.3 uhd 3840 x 2160 32gb geforce gtx...
# 191                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 192  hp omen 17 17.3 uhd 4k vr ready intel i7 2tb hdd 512gb ssd 17.3 uhd 3840 x 2160 32gb geforce gtx...
# 193  2018 hp envy x360 2 1 15.6 full hd touchscreen pc intel quad core i7 8550u 12gb 1tb 7200rpm hddb...
# 194                   apple mmgf2ll a macbook air 13.3 5th gen intel core i5 1.6 ghz 8 gb lpddr3 128 gb
# 195                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 196                   apple mmgf2ll a macbook air 13.3 5th gen intel core i5 1.6 ghz 8 gb lpddr3 128 gb
# 197       lenovo thinkpad t470s windows 10 intel core i7 7500u 16gb 512gb ssd 14 ips fhd 1920x1080 color
# 198  refurbished panasonic cf 31 toughbook intel core i5 2.5ghz 1tb ssd solid state 16gb ddr3 13.1 to...
# 199                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
#
#           ltable_brand       ltable_model  ltable_operating_system  \
# 0               lenovo         20fb002lus   windows 7 professional
# 1               lenovo         20fb002lus   windows 7 professional
# 2               lenovo         20fb002lus   windows 7 professional
# 3               lenovo         20fb002lus   windows 7 professional
# 4               lenovo         20fb002lus   windows 7 professional
# 5               lenovo         20fb002lus   windows 7 professional
# 6               lenovo         20fb002lus   windows 7 professional
# 7               lenovo         20fb002lus   windows 7 professional
# 8               lenovo         20fb002lus   windows 7 professional
# 9                 dell              t8tjg               windows 10
# 10                  hp                NaN               windows 10
# 11                  hp                NaN               windows 10
# 12                  hp        x9v54ut#aba       windows 10 edition
# 13              lenovo         20fb002lus   windows 7 professional
# 14                  hp        x9v54ut#aba       windows 10 edition
# 15                  hp        x9v54ut#aba       windows 10 edition
# 16                  hp        x9v54ut#aba       windows 10 edition
# 17                  hp              15 ay               windows 10
# 18              lenovo         20fb002lus   windows 7 professional
# 19                  hp                NaN               windows 10
# 20             prostar            n870hp6               windows 10
# 21                  hp            w2l56ua               windows 10
# 22              lenovo         20bs00bgus   windows 7 professional
# 23                  hp              hp 15               windows 10
# 24                  hp              t8tjg               windows 10
# 25                 NaN                NaN              android 6.0
# 26                  hp              15 ay               windows 10
# 27                dell       727363170767               windows 10
# 28                 msi            ws63290               windows 10
# 29                 NaN                NaN              android 6.0
# ..                 ...                ...                      ...
# 170             lenovo         20fb002rus   windows 7 professional
# 171        hp envy_360       hp envy x360               windows 10
# 172        hp envy_360       hp envy x360               windows 10
# 173               dell              9x0t5          windows 10 home
# 174             lenovo                NaN               windows 10
# 175             lenovo                NaN               windows 10
# 176               dell              tfg4h           windows 10 pro
# 177       tech wizards                NaN               windows 10
# 178        excaliberpc   gs63 stealth 061     microsoft windows 10
# 179             lenovo         20bs00bgus   windows 7 professional
# 180             lenovo                NaN        windows 10 64 bit
# 181             lenovo                NaN        windows 10 64 bit
# 182           dell usa  i5379 7923gry pus               windows 10
# 183           dell usa  i5379 7923gry pus               windows 10
# 184             lenovo         20bs00bgus   windows 7 professional
# 185          alienware     aw15r2 8469slv               windows 10
# 186             lenovo         20bs00bgus   windows 7 professional
# 187             lenovo         20bs00bgus   windows 7 professional
# 188                NaN        xps 13 9350          windows 10 home
# 189             lenovo         20bs00bgus   windows 7 professional
# 190                 hp     new hp omen 17                      NaN
# 191             lenovo         20bs00bgus   windows 7 professional
# 192                 hp     new hp omen 17                      NaN
# 193                 hp          envy x360               windows 10
# 194     apple computer                NaN  mac x v10.11 el capitan
# 195             lenovo         20bs00bgus   windows 7 professional
# 196     apple computer                NaN  mac x v10.11 el capitan
# 197             lenovo                NaN           windows 10 pro
# 198  quality computers  cf31i525161tbssdn   windows 7 professional
# 199             lenovo         20bs00bgus   windows 7 professional
#
#                                                                                    ltable_extended_title  \
# 0    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 1    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 2    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 3    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 4    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 5    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 6    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 7    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 8    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 9    dell xps 15 9560 4k uhd intel core i7 7700hq 16gb 512gb ssd nvidia gtx 1050 4gb gddr5 windows 10...
# 10        newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 11        newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 12       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 13   lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 14       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 15       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 16       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 17   2017 hp fhd 15.6 wled intel core i5 7200u 3.1ghz 8gb ddr4 1tb hdd usb 3.1 802.11 ac hdmi windows...
# 18   lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 19                               hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 20   prostar clevo n870hp6 17.3” full hd ips intel core i7 7700hq 32gb ddr4 gtx 1060 500gb ssd 1tb hd...
# 21               hp pavilion 15.6 hd touchscreen intel core i5 8gb 1tb hdd windows 10 15 au057cl w2l56ua
# 22   lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 23                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 24      hp 15.6 touchscreen quad core amd a12 3.6ghz 8gb 1tb hdd 4gb amd radeon r7 hdmi windows 10 t8tjg
# 25   2018 rca cambio 10.1 2 1 touchscreen tablet pc intel quad core 2gb 32gb microsoft office windows...
# 26   2017 hp fhd 15.6 wled intel core i5 7200u 3.1ghz 8gb ddr4 1tb hdd usb 3.1 802.11 ac hdmi windows...
# 27   2016 dell inspiron 5000 touchscreen 15.6 fhd 6th intel core i5 6200u 2.8ghz 8 gb 1 tb hdd hdmi 8...
# 28   msi ws63 7rk 290us ips level 15.6 nvidia quadro p3000 i7 7700hq 32gb 512gb ssd 2tb windows 10 ws...
# 29   2018 rca cambio 10.1 2 1 touchscreen tablet pc intel quad core 2gb 32gb microsoft office windows...
# ..                                                                                                   ...
# 170     lenovo thinkpad x1 carbon 20fb002rus 14 intel core i5 6200u 8gb 256gb ssd windows 7 professional
# 171  hp envy x360 2 1 15.6 full hd ips touch quad core amd fx 9800p 8gb amd radeon r7 1tb windows 10 ...
# 172  hp envy x360 2 1 15.6 full hd ips touch quad core amd fx 9800p 8gb amd radeon r7 1tb windows 10 ...
# 173              dell xps 13 9365 13.3 qhd touch intel core i7 7y75 16gb 512gb ssd windows 10 9x0t5 home
# 174  lenovo thinkpad t470p intel core i7 7700hq 14 fhd ips 16gb ddr4 500gb hdd nvidia geforce 940mx w...
# 175  lenovo thinkpad t470p intel core i7 7700hq 14 fhd ips 16gb ddr4 500gb hdd nvidia geforce 940mx w...
# 176         dell tfg4h latitude 3380 13.3 hdf intel core i3 6006u 4gb ddr4 128gb solid state windows 10
# 177          tw dell latitude 5480 14 hd intel core i5 7300hq windows 10 8gb ddr4 512gb ssd tech wizards
# 178  msi gs63 stealth 061 i7 7700hq 16gb 128gb nvme ssd 1tb hdd nvidia gtx 1050 2gb 15.6 full hd wind...
# 179  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 180  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 181  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 182            dell inspiron 2 1 13.3 touch intel core i7 8gb 256gb ssd usa i5379 7923gry pus windows 10
# 183            dell inspiron 2 1 13.3 touch intel core i7 8gb 256gb ssd usa i5379 7923gry pus windows 10
# 184  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 185  alienware aw15r2 8469slv 15.6 uhd 6th intel core i7 16 gb 1 tb hdd 256 gb sata ssd nvidia geforc...
# 186  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 187  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 188                              dell xps 13 9350 13.3 intel core i5 6200u 8gb 128gb ssd windows 10 home
# 189  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 190  hp omen 17 17.3 uhd 4k vr ready intel i7 2tb hdd 512gb ssd 17.3 uhd 3840 x 2160 32gb geforce gtx...
# 191  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 192  hp omen 17 17.3 uhd 4k vr ready intel i7 2tb hdd 512gb ssd 17.3 uhd 3840 x 2160 32gb geforce gtx...
# 193  2018 hp envy x360 2 1 15.6 full hd touchscreen pc intel quad core i7 8550u 12gb 1tb 7200rpm hddb...
# 194  apple mmgf2ll a macbook air 13.3 5th gen intel core i5 1.6 ghz 8 gb lpddr3 128 gb x v10.11 el ca...
# 195  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 196  apple mmgf2ll a macbook air 13.3 5th gen intel core i5 1.6 ghz 8 gb lpddr3 128 gb x v10.11 el ca...
# 197            lenovo thinkpad t470s windows 10 intel core i7 7500u 16gb 512gb ssd 14 ips fhd 1920x1080
# 198  refurbished panasonic cf 31 toughbook intel core i5 2.5ghz 1tb ssd solid state 16gb ddr3 13.1 to...
# 199  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
#
#                                                                                     rtable_product_title  \
# 0    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 1tb nvme ssd 14 ips wqhd 2560x1440 ...
# 1    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 256gb nvme ssd 14 ips wqhd 2560x14...
# 2    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 1tb nvme ssd 14 ips wqhd 2560x1440...
# 3    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 2tb nvme ssd 14 ips wqhd 2560x1440...
# 4    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 2tb nvme ssd 14 ips wqhd 2560x1440 ...
# 5    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 256gb nvme ssd 14 ips wqhd 2560x14...
# 6    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 2tb nvme ssd 14 ips wqhd 2560x1440...
# 7    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 8    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 9                refurbished dell xps 15 9560 i7 7700hq 16gb 512gb ssd uhd 4k touch gtx 1050 fingerprint
# 10   hp pavilion 15 cc564nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 11   hp pavilion 15 cc563nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 12                                                   hp zbook 15 g3 15.6 core i7 6820hq 16 gb 256 gb ssd
# 13   pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 1tb nvme ssd 14 ips wqhd 2560x1440...
# 14                                                   hp zbook 15u g3 15.6 core i7 6500u 16 gb 512 gb ssd
# 15                                               hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd
# 16                                               hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd
# 17          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 18   2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7500u 180gb ssd 8gb 14 wqhd ips 2...
# 19              hp pavilion 15 au030wm 15.6 manhattan touch windows 10 intel core i5 6200u 8gb 1tb drive
# 20   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 256gb nvme ...
# 21                    hp pavilion 15 au020wm 15.6 manhattan windows 10 intel core i5 6200u 8gb 1tb drive
# 22                                            lenovo thinkpad x1 carbon 14 core i5 6200u 8 gb 180 gb ssd
# 23                              hp 15.6 touchscreen 2 1 windows 10 intel core i3 7100u 8gb 1tb assorted
# 24   hp 15.6 touchscreen latest amd quad core a12 9720p 2.7 ghz 8gb ddr4 1tb hdd amd radeon r7 mouse ...
# 25                                rca cambio 10.1 2 1 tablet 32gb intel atom z3735f quad core windows 10
# 26          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 27       dell inspiron i5559 15.6 fhd touchscreen intel realsense 3d camera intel core i5 8 gb 1 tb hdd
# 28   msi ws63 7rk 290us 15.6 intel core i7 7700hq 2.8ghz 32gb ddr4 2tb hdd 512gb pci e ssd quadro p30...
# 29                                rca cambio 10.1 2 1 tablet 32gb intel atom z3735f quad core windows 10
# ..                                                                                                   ...
# 170  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 1tb ssd 8gb 14 fhd ips 1920x1080 intel...
# 171  hp envy x360 2 1 15.6 ips fhd touch amd quad core fx 9800p upto 3.6ghz 8gb ddr4 256gb ssd amd ra...
# 172  hp envy x360 2 1 15.6 ips fhd touch amd quad core fx 9800p upto 3.6ghz 8gb ddr4 512gb ssd amd ra...
# 173                           dell xps 13 9365 intel core i7 7y75 x2 1.3ghz 16gb 512gb ssd 13.3 silver
# 174               lenovo thinkpad t450s touch windows 10 intel core i7 5600u 8gb 500gb hdd 14 ips fhd 19
# 175               lenovo thinkpad t450s touch windows 10 intel core i7 5600u 12gb 500gb hdd 14 ips fhd 1
# 176                refurbished dell 3340 13.3 windows 10 intel core i3 4010u 4gb 128gb solid state drive
# 177                           dell latitude 3480 14 hd intel core i5 7200u 8gb ddr4 500gb windows 10 pro
# 178  msi gs63 stealth 061 15.6 intel core i7 7700hq 2.8ghz 16gb ddr4 1tb hdd 128gb pci e ssd gtx 1050...
# 179                                          lenovo thinkpad x1 carbon 14 core i5 7300u 16 gb 256 gb ssd
# 180                  lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb denim blue
# 181               lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb platinum grey
# 182                   dell inspiron 5379 2 1 intel core i7 8550u x4 1.8ghz 8gb 256gb ssd 13.3 win10 gray
# 183                                                  dell inspiron 2 1 13.3 intel i5 7200u 8gb 256gb ssd
# 184                                           lenovo thinkpad x1 carbon 14 core i7 7500u 8 gb 256 gb ssd
# 185  refurbished alienware 15 fhd 15.6 intel core i7 4710hq 16 gb 1 tb hdd 128 gb ssd nvidia geforce ...
# 186                                           lenovo thinkpad x1 carbon 14 core i7 6500u 8 gb 256 gb ssd
# 187                                           lenovo thinkpad x1 carbon 14 core i5 7300u 8 gb 512 gb ssd
# 188  refurbished dell xps 13 9350 i5 6200u 8gb 128gb ssd fhd 1080p touch infinity edge windows 10 silver
# 189                                             lenovo thinkpad x1 yoga 14 core i5 6300u 8 gb 256 gb ssd
# 190  hp omen 15 15.6 uhd 4k intel i7 quad core 2tb hdd 512gb ssd 15.6 uhd 3840 x 2160 32gb geforce gt...
# 191                                             lenovo thinkpad x1 yoga 14 core i5 6300u 8 gb 256 gb ssd
# 192  hp omen 17 17.3 uhd 4k intel i7 quad core 1tb hdd 256gb ssd 17.3 uhd 3840 x 2160 16gb geforce gt...
# 193         hp envy x360 convertible 2 1 full hd ips 15.6 touchscreen intel core i7 8550u 12gb 1tb drive
# 194                                                   apple macbook air 13.3 core i5 8 gb 128 gb english
# 195                                           lenovo thinkpad x1 carbon 14 core i7 7600u 8 gb 256 gb ssd
# 196                                               apple macbook air 13.3 core i5 8 gb 128 gb ssd english
# 197  lenovo thinkpad yoga 260 convertible multimode intel core i7 6500u 16gb 512gb nvme ssd 12.5 ips ...
# 198  refurbished rugged panasonic toughbook cf 31 intel core i5 2.6ghz 512gb solid state 12gb ddr3 13...
# 199                                             lenovo thinkpad x1 yoga 14 core i5 7200u 8 gb 256 gb ssd
#
#             rtable_brand         rtable_model        rtable_operating_system  \
# 0                 lenovo                  NaN                      windows 7
# 1                 lenovo                  NaN                      windows 7
# 2                 lenovo                  NaN                      windows 7
# 3                 lenovo                  NaN                      windows 7
# 4                 lenovo                  NaN                      windows 7
# 5                 lenovo                  NaN                      windows 7
# 6                 lenovo                  NaN                      windows 7
# 7                 lenovo                 2017                      windows 7
# 8                 lenovo                 2017                      windows 7
# 9                   dell                  NaN        windows 10 professional
# 10                    hp          1ku26ua#aba                     windows 10
# 11                    hp          1ku25ua#aba                     windows 10
# 12                    hp          x9u00ut#aba                     windows 10
# 13                lenovo                  NaN                      windows 7
# 14                    hp          v1h65ut#aba                    windows 10
# 15                    hp          t6e17ut#aba                    windows 10
# 16                    hp          x9t82ut#aba                     windows 10
# 17                    hp                  NaN                     windows 10
# 18                lenovo                 2017                      windows 7
# 19                    hp          w2l55ua#aba                     windows 10
# 20               prostar               n855hj          microsoft windows 10
# 21                    hp          w2l54ua#aba                     windows 10
# 22                lenovo           20k4002uus                      windows 7
# 23                    hp          1kt67ua#aba                     windows 10
# 24                    hp                  NaN              microsoft windows
# 25                   rca                  NaN              microsoft windows
# 26                    hp                 2017                     windows 10
# 27                  dell        i5559 4682slv                     windows 10
# 28                   msi                  NaN              microsoft windows
# 29                   rca                  NaN              microsoft windows
# ..                   ...                  ...                            ...
# 170               lenovo                  NaN                      windows 7
# 171                   hp  hpenvy360afxt 8256p              microsoft windows
# 172                   hp  hpenvy360afxt 8512p              microsoft windows
# 173                 dell       1493282306 rfb                     windows 10
# 174               lenovo                  NaN                     windows 10
# 175               lenovo                  NaN                     windows 10
# 176             latitude            wa5 30736                     windows 10
# 177                 dell        lati3480xpmm1                     windows 10
# 178                  msi                  NaN              microsoft windows
# 179               lenovo           20hr000mus                    windows 10
# 180               lenovo           80xr00alus                     windows 10
# 181               lenovo           80xr00a7us                     windows 10
# 182                 dell           1515571463                     windows 10
# 183                 dell        i5378 5896gry                    windows 10
# 184               lenovo           20hr0057us                    windows 10
# 185                 dell                  NaN              microsoft windows
# 186               lenovo           20k4002rus                      windows 7
# 187               lenovo           20hr003eus                    windows 10
# 188                 dell                  NaN                            NaN
# 189               lenovo           20fq0055us                    windows 10
# 190  michaelelectronics2                  NaN                            NaN
# 191               lenovo           20fq005aus  microsoft windows windows 10
# 192  michaelelectronics2                  NaN                            NaN
# 193                   hp           15 aq267cl              microsoft windows
# 194                apple            mmgf2ll a                      apple ios
# 195               lenovo           20hr000hus                    windows 10
# 196                apple            mqd32ll a                     mac sierra
# 197               lenovo                  NaN                     windows 10
# 198                   hp                  NaN              microsoft windows
# 199               lenovo           20jf000bus                    windows 10
#
#                                                                                    rtable_extended_title
# 0       pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 1tb nvme ssd 14 ips wqhd 2560x1440
# 1    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 256gb nvme ssd 14 ips wqhd 2560x1440
# 2      pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 1tb nvme ssd 14 ips wqhd 2560x1440
# 3      pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 2tb nvme ssd 14 ips wqhd 2560x1440
# 4       pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 2tb nvme ssd 14 ips wqhd 2560x1440
# 5    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 256gb nvme ssd 14 ips wqhd 2560x1440
# 6      pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 2tb nvme ssd 14 ips wqhd 2560x1440
# 7    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 8    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 9       refurbished dell xps 15 9560 i7 7700hq 16gb 512gb ssd uhd 4k touch gtx 1050 windows professional
# 10   hp pavilion 15 cc564nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 11   hp pavilion 15 cc563nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 12                            hp zbook 15 g3 15.6 core i7 6820hq 16 gb 256 gb ssd x9u00ut#aba windows 10
# 13     pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 1tb nvme ssd 14 ips wqhd 2560x1440
# 14                           hp zbook 15u g3 15.6 core i7 6500u 16 gb 512 gb ssd v1h65ut#aba windows 10
# 15                       hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd t6e17ut#aba windows 10
# 16                        hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd x9t82ut#aba windows 10
# 17          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 18   2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7500u 180gb ssd 8gb 14 wqhd ips 2...
# 19        hp pavilion 15 au030wm 15.6 manhattan touch windows 10 intel core i5 6200u 8gb 1tb w2l55ua#aba
# 20   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 256gb nvme ...
# 21              hp pavilion 15 au020wm 15.6 manhattan windows 10 intel core i5 6200u 8gb 1tb w2l54ua#aba
# 22                       lenovo thinkpad x1 carbon 14 core i5 6200u 8 gb 180 gb ssd 20k4002uus windows 7
# 23                   hp 15.6 touchscreen 2 1 windows 10 intel core i3 7100u 8gb 1tb assorted 1kt67ua#aba
# 24   hp 15.6 touchscreen latest amd quad core a12 9720p 2.7 ghz 8gb ddr4 1tb hdd amd radeon r7 mouse ...
# 25                      rca cambio 10.1 2 1 tablet 32gb intel atom z3735f quad core windows 10 microsoft
# 26          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 27   dell inspiron i5559 15.6 fhd touchscreen intel realsense 3d camera intel core i5 8 gb 1 tb hdd i...
# 28   msi ws63 7rk 290us 15.6 intel core i7 7700hq 2.8ghz 32gb ddr4 2tb hdd 512gb pci e ssd quadro p30...
# 29                      rca cambio 10.1 2 1 tablet 32gb intel atom z3735f quad core windows 10 microsoft
# ..                                                                                                   ...
# 170  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 1tb ssd 8gb 14 fhd ips 1920x1080 intel...
# 171  hp envy x360 2 1 15.6 ips fhd touch amd quad core fx 9800p upto 3.6ghz 8gb ddr4 256gb ssd amd ra...
# 172  hp envy x360 2 1 15.6 ips fhd touch amd quad core fx 9800p upto 3.6ghz 8gb ddr4 512gb ssd amd ra...
# 173  dell xps 13 9365 intel core i7 7y75 x2 1.3ghz 16gb 512gb ssd 13.3 silver  1493282306 rfb windows 10
# 174              lenovo thinkpad t450s touch windows 10 intel core i7 5600u 8gb 500gb hdd 14 ips fhd 19
# 175              lenovo thinkpad t450s touch windows 10 intel core i7 5600u 12gb 500gb hdd 14 ips fhd 1
# 176   refurbished dell 3340 13.3 windows 10 intel core i3 4010u 4gb 128gb solid state latitude wa5 30736
# 177                 dell latitude 3480 14 hd intel core i5 7200u 8gb ddr4 500gb windows 10 lati3480xpmm1
# 178  msi gs63 stealth 061 15.6 intel core i7 7700hq 2.8ghz 16gb ddr4 1tb hdd 128gb pci e ssd gtx 1050...
# 179                   lenovo thinkpad x1 carbon 14 core i5 7300u 16 gb 256 gb ssd 20hr000mus windows 10
# 180            lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb denim 80xr00alus
# 181         lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb platinum 80xr00a7us
# 182     dell inspiron 5379 2 1 intel core i7 8550u x4 1.8ghz 8gb 256gb ssd 13.3 win10 1515571463 windows
# 183                        dell inspiron 2 1 13.3 intel i5 7200u 8gb 256gb ssd i5378 5896gry windows 10
# 184                    lenovo thinkpad x1 carbon 14 core i7 7500u 8 gb 256 gb ssd 20hr0057us windows 10
# 185  refurbished alienware 15 fhd 15.6 intel core i7 4710hq 16 gb 1 tb hdd 128 gb ssd nvidia geforce ...
# 186                        lenovo thinkpad x1 carbon 14 core i7 6500u 8 gb 256 gb ssd 20k4002rus windows
# 187                    lenovo thinkpad x1 carbon 14 core i5 7300u 8 gb 512 gb ssd 20hr003eus windows 10
# 188        refurbished dell xps 13 9350 i5 6200u 8gb 128gb ssd fhd 1080p touch infinity edge windows 10
# 189                      lenovo thinkpad x1 yoga 14 core i5 6300u 8 gb 256 gb ssd 20fq0055us windows 10
# 190  hp omen 15 15.6 uhd 4k intel i7 quad core 2tb hdd 512gb ssd 15.6 uhd 3840 x 2160 32gb geforce gt...
# 191    lenovo thinkpad x1 yoga 14 core i5 6300u 8 gb 256 gb ssd 20fq005aus microsoft windows windows 10
# 192  hp omen 17 17.3 uhd 4k intel i7 quad core 1tb hdd 256gb ssd 17.3 uhd 3840 x 2160 16gb geforce gt...
# 193  hp envy x360 convertible 2 1 full hd ips 15.6 touchscreen intel core i7 8550u 12gb 1tb 15 aq267c...
# 194                                             apple macbook air 13.3 core i5 8 gb 128 gb mmgf2ll a ios
# 195                    lenovo thinkpad x1 carbon 14 core i7 7600u 8 gb 256 gb ssd 20hr000hus windows 10
# 196                                      apple macbook air 13.3 core i5 8 gb 128 gb ssd mqd32ll a sierra
# 197  lenovo thinkpad yoga 260 convertible multimode intel core i7 6500u 16gb 512gb nvme ssd 12.5 ips ...
# 198  refurbished rugged panasonic toughbook cf 31 intel core i5 2.6ghz 512gb solid state 12gb ddr3 13...
# 199                      lenovo thinkpad x1 yoga 14 core i5 7200u 8 gb 256 gb ssd 20jf000bus windows 10
#
# [200 rows x 13 columns]

# %%
len(C)
# Out:
# 7204

# %% [markdown]
# Looking at the dedug output, we observe that the current blocking sequence does not seem to drop a lot of potential matches and has also reduced the candidate set to a good extent. Thus, we stop the blocking step and proceed with the matching step.

# %% [markdown]
# # Step 3: Reading in the labeled sample

# %% [markdown]
# We randomly sample 450 tuple pairs for labeling purposes and write the sample data to a csv. We then label the csv and use the labeled csv from then on.

# %%
# # Sample  candidate set
S = em.sample_table(C, 450)
## em.to_csv_metadata(S, 'data/labeled.csv')

# %%
# # Loading the labeled data
path_S = 'data/labeled.csv'
S = em.read_csv_metadata(path_S, 
                         key='_id',
                         ltable=A, rtable=B, 
                         fk_ltable='ltable_id', fk_rtable='rtable_id')

#showing some examples of labeled sample
S.head(5)
# Out:
#    _id ltable_id rtable_id  ltable_model  \
# 0    5        a0     w2300  nh.q28aa.001
# 1   26     a1011      w685         t8tjg
# 2   30      a102     w1746   c300sa dh02
# 3   44     a1031     w4581  a515 51 596k
# 4   65     a1047     w1400       n850hp6
#
#                                                                                  ltable_extended_title  \
# 0  acer predator helios 300 15.6 full hd intel core i7 7700hq 16gb ddr4 256gb ssd geforce gtx 1060 ...
# 1  2018 lenovo thinkpad 11e 4h 11.6 intel i3 7100u 128gb m.2 ssd 4gb ddr4 802.11ac win10 t8tjg windows
# 2                     asus chromebook c300sa compact 13.3 intel celeron 4gb 16gb emmc asus c300sa dh02
# 3                           acer 15.6 intel core i5 3.40ghz 8gb 256gb ssd windows 10 a515 51 596k home
# 4  prostar clevo n850hp6 15.6” fhd ips 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1060 120gb ssd ...
#
#    rtable_model  \
# 0  nh.q1caa.001
# 1         t8tjg
# 2   c300sa dh02
# 3  nx.gnpaa.016
# 4        n855hj
#
#                                                                                  rtable_extended_title  \
# 0         acer 15.6 intel core i7 2.6ghz 16 gb 1 tb hdd 256 gb ssd windows 10 g9 593 72vt nh.q1caa.001
# 1                                   dell chromebook 11 3189 11.6 celeron n3060 4 gb 64 gb ssd t8tjg os
# 2                                             c300sa dh02 cel n3060 4gb 16gb 13.3in chrome asus chrome
# 3               refurbished acer aspire 3 intel core i5 2.5 ghz 8gb 256 gb ssd windows 10 nx.gnpaa.016
# 4  prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 8gb ddr4 gtx 1050 1tb hdd wind...
#
#    match
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1

# %% [markdown]
# # Step 4: Splitting labeled data into development and evaluation set

# %% [markdown]
# In this step, we split the labeled data set S into a development set I and an evaluation set J.

# %%
IJ = em.split_train_test(S, train_proportion=0.7, random_state=0)
I = IJ['train']
J = IJ['test']

# %% [markdown]
# # Step 5: Creating a set of ML-matchers.

# %%
# Create a set of ML-matchers
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')
nb = em.NBMatcher(name='NaiveBayes')

# %% [markdown]
# # Step 6: Selecting the best matcher using I.

# %% [markdown]
# This step includes:
#     a. Creating a feature table F.
#     b. Converting I into a set H of feature vectors (using the features in F).
#     c. Selecting the best matcher in the first iteration using cross-validation.
#     d. Debugging the matcher
#     e. Selecting the best matcher again using cross-validation.
#     Repeating the steps d and e for all the debug iterations.

# %% [markdown]
# ## Initial iteration:
# ### a. Creating a feature table F.

# %%
match_t = em.get_tokenizers_for_matching([2,3,5])
match_s = em.get_sim_funs_for_matching()
atypes1 = em.get_attr_types(A)
atypes2 = em.get_attr_types(B)
match_c = em.get_attr_corres(A, B)
feature_table = em.get_features(A, B, atypes1, atypes2, match_c, match_t, match_s)

# %% [markdown]
# ### b. Converting I into a set H of feature vectors (using the features in F).

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=feature_table, 
                            attrs_after='match',
                            show_progress=False)
#Filling in the missing values if any in H.
H.fillna(0, inplace=True)

# %% [markdown]
# ### c. Selecting the best matcher in the first iteration using cross-validation

# %%
# Select the best ML matcher using CV
result = em.select_matcher(
        matchers=[dt, rf, svm, ln, lg, nb], 
        table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
        k=5,
        target_attr='match', 
        metric_to_select_matcher='precision', 
        random_state=0)
# result
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.931906        0.849995    0.888477
# 1            RF           0.923791        0.940841    0.931533
# 2           SVM           0.872856        0.970963    0.918780
# 3        LinReg           0.894443        0.935375    0.913853
# 4        LogReg           0.888296        0.932618    0.908653
# 5    NaiveBayes           0.919928        0.773327    0.839341

# %% [markdown]
# ### d. Debugging matcher

# %%
#  Split feature vectors into train and test
UV = em.split_train_test(H, train_proportion=0.5)
U = UV['train']
V = UV['test']

# %%
# Debug rf using GUI
#em.vis_debug_dt(result['selected_matcher'], U, V, 
#                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
#                target_attr='match')

# %% [markdown]
# Making features from non-attributes like the IDs of each row resulted in false positive matches due to high similarity between the ids. There are also some dirty attributes which had erroneus values resulting in false negatives.

# %% [markdown]
# ## Iteration 2:
# ### a. Creating a feature table F.

# %%
# Remove bad features from auto-feature-generation and trying different tokenizers for matching
AA = A.drop(['id','product_title','model','operating_system'],axis=1)
BB = B.drop(['id','product_title','model','operating_system'],axis=1)

match_t = em.get_tokenizers_for_matching([3,5,10])
match_s = em.get_sim_funs_for_matching()
atypes1 = em.get_attr_types(AA)
atypes2 = em.get_attr_types(BB)
match_c = em.get_attr_corres(AA, BB)
feature_table = em.get_features(AA, BB, atypes1, atypes2, match_c, match_t, match_s)

# %% [markdown]
# ### b. Converting I into a set H of feature vectors (using the features in F).

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=feature_table, 
                            attrs_after='match',
                            show_progress=False)
#Filling in the missing values if any in H.
H.fillna(0, inplace=True)

# %% [markdown]
# ### c. Selecting the best matcher in the first iteration using cross-validation

# %%
# Select the best ML matcher using CV
result = em.select_matcher(
        matchers=[dt, rf, svm, ln, lg, nb], 
        table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
        k=5,
        target_attr='match', 
        metric_to_select_matcher='precision', 
        random_state=0)
# result
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.910556        0.912291    0.911003
# 1            RF           0.908812        0.929106    0.917972
# 2           SVM           0.827146        0.988857    0.899620
# 3        LinReg           0.898446        0.973204    0.933452
# 4        LogReg           0.884140        0.988857    0.932342
# 5    NaiveBayes           0.911270        0.927804    0.918882

# %% [markdown]
# ### d. Debugging matcher

# %%
#  Split feature vectors into train and test
UV = em.split_train_test(H, train_proportion=0.5)
U = UV['train']
V = UV['test']
result['drill_down_cv_stats']['precision']['Matcher'][0]

# %%
# Debug rf using GUI
#em.vis_debug_dt(result['drill_down_cv_stats']['precision']['Matcher'][0], U, V, 
#                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
#                target_attr='match')

# %% [markdown]
# Previous iteration seems to have improved F score and recall. Debugging further.
# A lot of useful information seems to be lost because of data being dirty.
# So trying to add more features using custom functions.

# %% [markdown]
# ### Iteration 3:
# ### a. Creating a feature table F.

# %%
# Remove bad features from auto-feature-generation and trying different tokenizers for matching
AA = A.drop(['id','product_title','model','operating_system'],axis=1)
BB = B.drop(['id','product_title','model','operating_system'],axis=1)
match_t = em.get_tokenizers_for_matching([3,5,10])
match_s = em.get_sim_funs_for_matching()
atypes1 = em.get_attr_types(AA)
atypes2 = em.get_attr_types(BB)
match_c = em.get_attr_corres(AA, BB)
feature_table = em.get_features(AA, BB, atypes1, atypes2, match_c, match_t, match_s)

# %% [markdown]
# This function generates a function that returns 1 if both or neither tuples' attribute contain any of the passed in values and 0 otherwise.

# %%
def generateContainsValueFeature(values, name=None, attribute='extended_title'):
    if type(values) is str:
        values = [values]
    def containsValueFeature(a,b):
        return int(any([value.lower() in a[attribute].lower() for value in values]) 
                   == any([value.lower() in b[attribute].lower() for value in values]))
    return containsValueFeature, name if name else values[0]

# %% [markdown]
# Use this to generate many new features.

# %%
brands = ['lg','toshiba','hp','dell','lenovo','prostar','acer','samsung','apple','asus','panasonic','msi']
models = ['zephyrus','zenbook','flex','omen','xps','x1','carbon','yoga',
          'latitude','inspiron','elitebook','clevo','spectre',
          'macbook','pavilion','ideapad','legion']
thinkpads = [['p40','p50','p51','p71'],['430','460','470','560','570']]
asus = ['swift','aspire','spin']
models = models + thinkpads + asus
sizes = [' 13',' 14',' 15',' 17']
operating_systems = ['chrome','windows','mac']
cpus = [['i3','i5','i7'],['celeron','pentium'],['m3','m5'],'amd']
miscellaneous = ['2-in-1','gtx','touch']
keywords = models \
    + sizes  \
    + operating_systems \
    + cpus \
    + miscellaneous
new_features = [generateContainsValueFeature(value) for value in keywords]

for feature in new_features:
    em.add_blackbox_feature(feature_table, feature[1], feature[0])

# %% [markdown]
# This function generates a function that returns 1 if both tuples contain the same value for any of the values passed in and 0 otherwise.

# %%
def generateContainsValueFromValuesetFeature(valueset, name=None, attribute='extended_title'):
    def sharesValue(a,b,values):
        if type(values) is str:
            values = [values]
        return int(any([value.lower() in a[attribute].lower() and value.lower() in b[attribute].lower() for value in values]))
    def containsValueFromValueset(a,b):
        return any([sharesValue(a,b,values) for values in valueset[1]])
    return containsValueFromValueset, valueset[0]

# %%
valuesets = [('brands',brands), 
             ('models', models), 
             ('sizes', sizes), 
             ('cpus', cpus), 
             ('operating_systems',operating_systems)]

new_features = [generateContainsValueFromValuesetFeature(valueset) for valueset in valuesets]

for feature in new_features:
    em.add_blackbox_feature(feature_table, feature[1], feature[0])
# Out:
# Input feature name is already present in feature table
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-44-82fafd4ca47c> in <module>()
#       8
#       9 for feature in new_features:
# ---> 10     em.add_blackbox_feature(feature_table, feature[1], feature[0])
#
# /usr/local/lib/python3.5/dist-packages/py_entitymatching/feature/addfeatures.py in add_blackbox_feature(feature_table, feature_name, feature_function)
#     385         logger.error('Input feature name is already present in feature table')
#     386         raise AssertionError(
# --> 387             'Input feature name is already present in feature table')
#     388
#     389     feature_dict = {}
#
# AssertionError: Input feature name is already present in feature table

# %% [markdown]
# ### b. Converting I into a set H of feature vectors (using the features in F).

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=feature_table, 
                            attrs_after='match',
                            show_progress=False)
#Filling in the missing values if any in H.
H.fillna(0, inplace=True)

# %% [markdown]
# ### c. Selecting the best matcher in the first iteration using cross-validation

# %%
# Select the best ML matcher using CV
result = em.select_matcher(
        matchers=[dt, rf, svm, ln, lg, nb], 
        table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
        k=5,
        target_attr='match', 
        metric_to_select_matcher='precision', 
        random_state=0)
# result
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.954048        0.937980    0.945281
# 1            RF           0.963564        0.972000    0.967336
# 2           SVM           0.893285        0.992000    0.939676
# 3        LinReg           0.962487        0.952694    0.957178
# 4        LogReg           0.913782        0.960000    0.935088
# 5    NaiveBayes           0.946487        0.942230    0.943907

# %% [markdown]
# Previous iteration seems to have improved F score, precision, and recall. Stopping further debugging.

# %% [markdown]
# ##  Evaluating the matching output

# %% [markdown]
# From the GUI, we observe that phone numbers seem to be an important attribute, but they are in different format. Current features does not capture and adding a feature incorporating this difference in format can potentially improve
# the F1 numbers.

# %% [markdown]
# Now, we repeat extracting feature vectors (this time with updated feature table), imputing table and selecting the best matcher again using cross-validation.

# %% [raw]
# H = em.extract_feature_vecs(I, feature_table=feature_table, attrs_after='match', show_progress=False)
# H.fillna(0, inplace=True)

# %%
# Select the best ML matcher using CV
result = em.select_matcher(
        [dt, rf, svm, ln, lg, nb], 
        table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
        k=5,
        target_attr='match', 
        metric_to_select_matcher='precision', 
        random_state=0)
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.954048        0.937980    0.945281
# 1            RF           0.963564        0.972000    0.967336
# 2           SVM           0.893285        0.992000    0.939676
# 3        LinReg           0.962487        0.952694    0.957178
# 4        LogReg           0.913782        0.960000    0.935088
# 5    NaiveBayes           0.946487        0.942230    0.943907

# %% [markdown]
# Evaluating the matching outputs for the evaluation set typically involves the following four steps:
# 1. Converting the evaluation set to feature vectors
# 2. Training matcher using the feature vectors extracted from the development set
# 3. Predicting the evaluation set using the trained matcher
# 4. Evaluating the predicted matches

# %% [markdown]
# ### Converting the evaluation set to  feature vectors

# %% [markdown]
# As before, we convert to the feature vectors (using the feature table and the evaluation set)

# %%
# Convert J into a set of feature vectors using feature table
L = em.extract_feature_vecs(
        J, 
        feature_table=feature_table,
        attrs_after='match', 
        show_progress=False)
L.fillna(0, inplace=True)
L.head()
# Out:
#       _id ltable_id rtable_id  brand_brand_jac_qgm_3_qgm_3  \
# 124  1764     a1561       w15                          0.0
# 54    705     a1269     w3092                          1.0
# 268  4200     a2294     w1544                          1.0
# 293  4614     a2439     w3188                          1.0
# 230  3469     a1997     w3210                          1.0
#
#      brand_brand_cos_dlm_dc0_dlm_dc0  brand_brand_jac_dlm_dc0_dlm_dc0  \
# 124                              0.0                              0.0
# 54                               1.0                              1.0
# 268                              1.0                              1.0
# 293                              1.0                              1.0
# 230                              1.0                              1.0
#
#      brand_brand_mel  brand_brand_lev_dist  brand_brand_lev_sim  \
# 124              0.0                   0.0                  0.0
# 54               1.0                   0.0                  1.0
# 268              1.0                   0.0                  1.0
# 293              1.0                   0.0                  1.0
# 230              1.0                   0.0                  1.0
#
#      brand_brand_nmw  ...    amd  2-in-1  gtx  touch  brands  models  sizes  \
# 124              0.0  ...      1       1    1      1    True    True  False
# 54               6.0  ...      1       1    1      0    True    True   True
# 268              7.0  ...      1       1    1      1    True    True   True
# 293              6.0  ...      1       1    1      1    True    True   True
# 230              6.0  ...      1       1    1      1    True    True   True
#
#      cpus  operating_systems  match
# 124  True               True      0
# 54   True               True      1
# 268  True               True      1
# 293  True               True      1
# 230  True               True      1
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Training the selected matcher

# %% [markdown]
# Now, we train the matcher using all of the feature vectors from the development set. For the purposes of this guide we use random forest as the selected matcher.

# %%
# Train using feature vectors from I 
result['selected_matcher'].fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'], 
       target_attr='match')

# %% [markdown]
# ### Predicting the matches

# %% [markdown]
# Next, we predict the matches for the evaluation set (using the feature vectors extracted from it).

# %%
# Predict on L 
predictions = result['selected_matcher'].predict(
        table=L, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'], 
        append=True, 
        target_attr='predicted', 
        inplace=False)

# %% [markdown]
# ### Evaluating the predictions

# %% [markdown]
# Finally, we evaluate the accuracy of predicted outputs

# %%
# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'match', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 94.51% (86/91)
# Recall : 92.47% (86/93)
# F1 : 93.48%
# False positives : 5 (out of 91 positive predictions)
# False negatives : 7 (out of 44 negative predictions)

# %%
# em.vis_debug_dt(dt, 
#                 U, V, 
#                 exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
#                 target_attr='match')
