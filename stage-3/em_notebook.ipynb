# %% [markdown]
# # Entity matching (EM) for Laptops

# %% [markdown]
# This jupyter notebook contains the commands used for each step in the entity matching process for laptop products from Amazon and Walmart.
# We used the Basic EM workflow 3 as our guide for this process.

# %% [markdown]
# # Step 1: Reading in the input tables A, B.

# %%
import sys
import py_entitymatching as em
import pandas as pd
import os

path_A = 'data/amazon_products.csv'
path_B = 'data/walmart_products.csv'

# Load the csv files as dataframes and set the key attribute in the dataframe
A = em.read_csv_metadata(path_A, key='id')
B = em.read_csv_metadata(path_B, key='id')
print('len(A):' + str(len(A)))
print('len(B):' + str(len(B)))
print('len (A X B):' + str(len(A)*len(B)))
# Out:
# len(A):3000
# len(B):4847
# len (A X B):14541000

# %% [markdown]
# # Step 2: Block tables to get candidate set
#
# In this step, we apply a blocking sequence on the input tables to get the candidate set C.

# %%
# Create an initial blocker
ob = em.OverlapBlocker()

# Use block_tables to apply blocking over two input tables.
C1 = ob.block_tables(A,B, 'model', 'model', 
                     l_output_attrs=['id','model','extended_title'], 
                     r_output_attrs=['id','model','extended_title'],
                     overlap_size=8,
                     q_val=5,
                     word_level=False,
                     show_progress=False,
                     n_jobs=-1
                     )
len(C1)
# Out:
# 2597

# %% [markdown]
# ## Debugging blocker output

# %%
# Debug blocker output
dbg = em.debug_blocker(C1, A, B, 
                        attr_corres=[
                            ('product_title','product_title'),
                            ('brand', 'brand'), 
                            ('model','model'),
                            ('extended_title','extended_title')],
                            verbose=True)
### Display first few tuple pairs from the debug_blocker's output
dbg
# Out:
#      _id ltable_id rtable_id  \
# 0      0      a888     w3286
# 1      1      a389     w3226
# 2      2     a1997     w3302
# 3      3     a1356     w3150
# 4      4      a888     w3438
# 5      5     a1356     w3180
# 6      6     a1356     w3117
# 7      7      a888     w3221
# 8      8      a389     w3337
# 9      9      a389     w3221
# 10    10     a1356     w3178
# 11    11     a1838     w3122
# 12    12      a888     w3226
# 13    13     a1356     w3225
# 14    14      a389     w3335
# 15    15      a389     w3438
# 16    16     a1997     w3184
# 17    17     a1997     w3305
# 18    18     a1838     w3121
# 19    19     a1356     w3149
# 20    20     a1997     w3059
# 21    21     a1997     w3063
# 22    22     a1838     w3078
# 23    23     a1356     w3223
# 24    24     a1838     w3077
# 25    25     a1356     w3179
# 26    26     a1997     w3258
# 27    27     a1997     w3142
# 28    28     a1997     w3090
# 29    29     a1997     w3182
# ..   ...       ...       ...
# 170  170     a1172      w689
# 171  171      a888     w3177
# 172  172      a389     w3116
# 173  173      a888     w3151
# 174  174     a1838     w3176
# 175  175     a2104     w3055
# 176  176     a1838     w3045
# 177  177      a389     w3177
# 178  178     a2490      w344
# 179  179      a389     w3290
# 180  180      a389     w3223
# 181  181      a389     w3225
# 182  182     a2104     w2951
# 183  183     a1838     w3181
# 184  184     a2773     w4444
# 185  185       a40      w978
# 186  186     a1107     w4162
# 187  187     a1356     w3337
# 188  188     a1356     w3335
# 189  189     a1356     w3224
# 190  190     a1602     w1264
# 191  191     a1602      w742
# 192  192     a2110      w734
# 193  193       a70     w1177
# 194  194       a70      w953
# 195  195     a1480     w2363
# 196  196     a1356     w3290
# 197  197     a1838     w3286
# 198  198      a888     w3336
# 199  199      a777      w634
#
#                                                                                     ltable_product_title  \
# 0    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 1    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 2        lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 3    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 4    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 5    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 6    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 7    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 8    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 9    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 10   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 11   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 12   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 13   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 14   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 15   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 16       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 17       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 18   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 19   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 20       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 21       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 22   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 23   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 24   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 25   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 26       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 27       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 28       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 29       lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# ..                                                                                                   ...
# 170                                     hp 15 bs095ms 15.6 touchscreen intel core i5 7200u 8gb 2tb win10
# 171  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 174  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 175  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 176  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 177  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 178  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 180  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 181  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 182  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 183  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 184    lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows 10 80sr002sus
# 185  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 186                     apple macbook air mqd32ll a 13 1.8ghz intel core i5 dual core 8gb 128gb ssd mac
# 187  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 188  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 189  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 190  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 191  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 192                      lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle
# 193                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 195                                                hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 198  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 199  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
#
#             ltable_brand                 ltable_model  \
# 0                 lenovo                          NaN
# 1                 lenovo                          NaN
# 2                 lenovo                          NaN
# 3                 lenovo                          NaN
# 4                 lenovo                          NaN
# 5                 lenovo                          NaN
# 6                 lenovo                          NaN
# 7                 lenovo                          NaN
# 8                 lenovo                          NaN
# 9                 lenovo                          NaN
# 10                lenovo                          NaN
# 11                lenovo                          NaN
# 12                lenovo                          NaN
# 13                lenovo                          NaN
# 14                lenovo                          NaN
# 15                lenovo                          NaN
# 16                lenovo                          NaN
# 17                lenovo                          NaN
# 18                lenovo                          NaN
# 19                lenovo                          NaN
# 20                lenovo                          NaN
# 21                lenovo                          NaN
# 22                lenovo                          NaN
# 23                lenovo                          NaN
# 24                lenovo                          NaN
# 25                lenovo                          NaN
# 26                lenovo                          NaN
# 27                lenovo                          NaN
# 28                lenovo                          NaN
# 29                lenovo                          NaN
# ..                   ...                          ...
# 170                   hp                          NaN
# 171               lenovo                          NaN
# 172               lenovo                          NaN
# 173               lenovo                          NaN
# 174               lenovo                          NaN
# 175               lenovo                          NaN
# 176               lenovo                          NaN
# 177               lenovo                          NaN
# 178                   hp  hp envy x360 15t ash silver
# 179               lenovo                          NaN
# 180               lenovo                          NaN
# 181               lenovo                          NaN
# 182               lenovo                          NaN
# 183               lenovo                          NaN
# 184               lenovo      ideapad 510 80sr002sus
# 185                   hp          hp 15.6 touchscreen
# 186                apple                          NaN
# 187               lenovo                          NaN
# 188               lenovo                          NaN
# 189               lenovo                          NaN
# 190  michaelelectronics2                hp 17z laptop
# 191  michaelelectronics2                hp 17z laptop
# 192                   lg                          NaN
# 193                   hp                        hp 15
# 194                   hp                        hp 15
# 195                   hp                          NaN
# 196               lenovo                          NaN
# 197               lenovo                          NaN
# 198               lenovo                          NaN
# 199                 dell                        t8tjg
#
#                                                                                    ltable_extended_title  \
# 0    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 1    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 2               lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 3    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 4    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 5    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 6    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 7    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 8    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 9    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 10   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 11   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 12   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 13   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 14   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 15   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 16              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 17              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 18   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 19   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 20              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 21              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 22   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 23   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 24   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 25   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 26              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 27              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 28              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# 29              lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080
# ..                                                                                                   ...
# 170                             hp 15 bs095ms 15.6 touchscreen intel core i5 7200u 8gb 2tb win10 windows
# 171  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 174  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 175  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 176  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 177  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 178  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 180  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 181  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 182  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 512gb ssd 8gb 14 fhd ips 1920x1080 int...
# 183  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 184  lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows 10 80sr002su...
# 185  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 186                    apple macbook air mqd32ll a 13 1.8ghz intel core i5 dual core 8gb 128gb ssd mac x
# 187  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 188  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 189  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 190  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 191  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 192           lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle windows 10
# 193                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 195                                     hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack windows 10
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 198  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 199  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
#
#                                                                                     rtable_product_title  \
# 0    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 1    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 2         lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 3    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440...
# 4    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 5    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440...
# 6    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 7    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 8    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 9    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 10   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 11   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x...
# 12   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 13   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 14   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 15   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 16      lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 512gb ssd 14 ips fhd 1920x1080 ac wifi
# 17        lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 18   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x10...
# 19   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 20   lenovo thinkpad t460s touch windows 7 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 tou...
# 21   lenovo thinkpad t460s touch windows 8.1 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 t...
# 22   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x...
# 23   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# 24   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x10...
# 25   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 26          lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 27      lenovo thinkpad t460s windows 8.1 intel core i7 6600u 8gb 512gb ssd 14 ips fhd 1920x1080 ac wifi
# 28     lenovo thinkpad t460s windows 8.1 intel core i7 6600u 12gb 256gb ssd 14 ips fhd 1920x1080 ac wifi
# 29      lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 128gb ssd 14 ips fhd 1920x1080 ac wifi
# ..                                                                                                   ...
# 170                                     hp 15 bs095ms 15.6 touchscreen intel core i5 7200u 8gb 2tb win10
# 171  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 174  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 inte...
# 175  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 1tb ssd 8gb 14 fhd ips 1920x1080 intel...
# 176  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 fhd ips 1920x1080 i...
# 177  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 178  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 180  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# 181  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 182  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 256gb ssd 8gb 14 fhd ips 1920x1080 int...
# 183  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 in...
# 184  refurbished lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows ...
# 185  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 186                     apple 13 macbook air 1.8ghz intel core i5 dual core 8gb 128gb ssd mac mqd32ll a
# 187  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 188  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 189  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x...
# 190  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 191  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 192                      lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle
# 193                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 195                                                hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 198  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 199  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
#
#             rtable_brand              rtable_model  \
# 0                 lenovo                       NaN
# 1                 lenovo                       NaN
# 2                 lenovo                       NaN
# 3                 lenovo                       NaN
# 4                 lenovo                       NaN
# 5                 lenovo                       NaN
# 6                 lenovo                       NaN
# 7                 lenovo                       NaN
# 8                 lenovo                       NaN
# 9                 lenovo                       NaN
# 10                lenovo                       NaN
# 11                lenovo                       NaN
# 12                lenovo                       NaN
# 13                lenovo                       NaN
# 14                lenovo                       NaN
# 15                lenovo                       NaN
# 16                lenovo                       NaN
# 17                lenovo                       NaN
# 18                lenovo                       NaN
# 19                lenovo                       NaN
# 20                lenovo                       NaN
# 21                lenovo                       NaN
# 22                lenovo                       NaN
# 23                lenovo                       NaN
# 24                lenovo                       NaN
# 25                lenovo                       NaN
# 26                lenovo                       NaN
# 27                lenovo                       NaN
# 28                lenovo                       NaN
# 29                lenovo                       NaN
# ..                   ...                       ...
# 170                   hp                       oem
# 171               lenovo                       NaN
# 172               lenovo                       NaN
# 173               lenovo                       NaN
# 174               lenovo                       NaN
# 175               lenovo                       NaN
# 176               lenovo                       NaN
# 177               lenovo                       NaN
# 178  michaelelectronics2  hp 15 02336 x360 fhd me7
# 179               lenovo                       NaN
# 180               lenovo                       NaN
# 181               lenovo                       NaN
# 182               lenovo                       NaN
# 183               lenovo                       NaN
# 184               lenovo                       NaN
# 185                   hp                      2018
# 186                apple                       NaN
# 187               lenovo                       NaN
# 188               lenovo                       NaN
# 189               lenovo                       NaN
# 190  michaelelectronics2       hp 17 02339 hdt me8
# 191  michaelelectronics2       hp 17 02339 hdt me2
# 192                   lg           15z970 a.aas7u1
# 193                   hp                       NaN
# 194                   hp                       NaN
# 195                   hp               2kw14ua#aba
# 196               lenovo                       NaN
# 197               lenovo                       NaN
# 198               lenovo                       NaN
# 199                 dell                       NaN
#
#                                                                                    rtable_extended_title
# 0    lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 1    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 2                lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080
# 3    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440...
# 4    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 5    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440...
# 6    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 7    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 8    lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 9    lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560...
# 10   lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 int...
# 11   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x...
# 12   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x1...
# 13   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 14   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 15   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 2tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 16             lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 512gb ssd 14 ips fhd 1920x1080
# 17               lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080
# 18   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb nvme ssd 16gb 14 fhd ips 1920x10...
# 19   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 20   lenovo thinkpad t460s touch windows 7 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 tou...
# 21   lenovo thinkpad t460s touch windows 8.1 intel core i7 6600u 8gb 256gb ssd 14 ips fhd 1920x1080 t...
# 22   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x...
# 23   lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# 24   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb nvme ssd 16gb 14 fhd ips 1920x10...
# 25   lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 26                 lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 1tb ssd 14 ips fhd 1920x1080
# 27             lenovo thinkpad t460s windows 8.1 intel core i7 6600u 8gb 512gb ssd 14 ips fhd 1920x1080
# 28            lenovo thinkpad t460s windows 8.1 intel core i7 6600u 12gb 256gb ssd 14 ips fhd 1920x1080
# 29             lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 128gb ssd 14 ips fhd 1920x1080
# ..                                                                                                   ...
# 170               hp 15 bs095ms 15.6 touchscreen intel core i5 7200u 8gb 2tb win10 oem microsoft windows
# 171  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 172  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 128gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 173  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 174  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 inte...
# 175  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 1tb ssd 8gb 14 fhd ips 1920x1080 intel...
# 176  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 180gb ssd 16gb 14 fhd ips 1920x1080 i...
# 177  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb ssd 16gb 14 wqhd ips 2560x1440 ...
# 178  hp envy x360 15t 2 1 convertible pc amd 7th gen quad core fx 9800p apu amd radeon r7 16gb 512gb ...
# 179  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 180  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440...
# 181  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 512gb ssd 16gb 14 wqhd ips 2560x1440 i...
# 182  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 256gb ssd 8gb 14 fhd ips 1920x1080 int...
# 183  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb ssd 16gb 14 fhd ips 1920x1080 in...
# 184  refurbished lenovo ideapad 510 15.6 fhd intel core i5 8 gb 1tb hdd nvidia geforce 940mx windows ...
# 185  2018 hp 15.6 hd touchscreen pc quad core amd a12 3.6ghz 8gb ddr4 sdram 1tb hdd hdmi dvd±rw amd r...
# 186    apple 13 macbook air 1.8ghz intel core i5 dual core 8gb 128gb ssd mac mqd32ll a microsoft windows
# 187  lenovo thinkpad x1 carbon 4 windows 7 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x144...
# 188  lenovo thinkpad x1 carbon 4 windows 8.1 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x1...
# 189  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 256gb nvme ssd 16gb 14 wqhd ips 2560x...
# 190  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 191  hp 17z 17.3 hd touchscreen amd dual core a6 9220 apu amd radeon r4 16gb 1tb hdd 17.3inch touch 1...
# 192           lg gram intel i7 16gb 15.6 touchscreen 15z970 a.aas7u1 software extended bundle windows 10
# 193                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 194                  hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 195                         hp 17.3 hd intel core i7 7500u 8gb 2tb hd 2 care pack 2kw14ua#aba windows 10
# 196  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb ssd 16gb 14 wqhd ips 2560x1440 in...
# 197  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 fhd ips 1920x108...
# 198  lenovo thinkpad x1 carbon 4 windows 10 intel core i7 6600u 1tb nvme ssd 16gb 14 wqhd ips 2560x14...
# 199  top dell inspiron 15.6 touchscreen 7th intel core i3 7100u 2.4ghz 8 gb ddr4 1 tb hdd hdmi rw hdm...
#
# [200 rows x 11 columns]

# %% [markdown]
# Looking at the debug blocker's output, we observe that the initial blocker is dropping a lot of potential matches.
# Blocking on the column brand alone seems incorrect.

# %%
# # Create overlap blocker
ob = em.OverlapBlocker()

# # Block tables using 'extended_title' attribute 
C2 = ob.block_tables(A, B, 'extended_title', 'extended_title', 
                     l_output_attrs=['id','model','extended_title'], 
                     r_output_attrs=['id','model','extended_title'],
                     overlap_size=25,
                     q_val=5,
                     word_level=False,
                     show_progress=False,
                     n_jobs=-1
                    )
# Updated blocking sequence
# A, B ------ overlap blocker [extended_title] ---------> C1--|
#                                                             |----> C
# A, B ------ overlap blocker [model] ------------------> C2--|

C = em.combine_blocker_outputs_via_union([C1,C2])
print ('Reduction on AxB by applying the blocker:' + str(int((len(A)*len(B))/len(C))) + 'x')
# Out:
# Reduction on AxB by applying the blocker:42x

# %%
# Debug blocker output
dbg = em.debug_blocker(C, A, B, 
                        attr_corres=[
                            ('product_title','product_title'),
                            ('brand', 'brand'), 
                            ('model','model'),
                            ('extended_title','extended_title')],
                            verbose=True)
### Display first few tuple pairs from the debug_blocker's output
dbg
# Out:
#      _id ltable_id rtable_id  \
# 0      0     a1166     w4520
# 1      1     a2024     w2957
# 2      2     a2209      w644
# 3      3     a1731      w809
# 4      4      a410     w2530
# 5      5     a2544       w32
# 6      6     a2144     w2300
# 7      7     a2144     w2632
# 8      8     a2144     w1389
# 9      9     a2841       w22
# 10    10     a2873     w3148
# 11    11      a251       w68
# 12    12     a1608      w380
# 13    13      a551     w2245
# 14    14      a432      w144
# 15    15     a1206     w3138
# 16    16     a2873      w477
# 17    17     a1206     w3141
# 18    18      a735       w68
# 19    19      a257      w869
# 20    20      a432      w361
# 21    21     a2078      w375
# 22    22      a854      w552
# 23    23     a2627     w2421
# 24    24     a2804     w3321
# 25    25     a2873     w3323
# 26    26     a2804     w3217
# 27    27     a2804     w3244
# 28    28     a2873       w84
# 29    29     a2804     w3211
# ..   ...       ...       ...
# 170  170       a12     w4096
# 171  171      a600     w1707
# 172  172       a12     w4097
# 173  173     a1202     w4132
# 174  174      a253      w382
# 175  175       a12     w4069
# 176  176       a12     w4070
# 177  177       a12     w4132
# 178  178     a2519     w4539
# 179  179     a2804     w3305
# 180  180     a2804     w3328
# 181  181     a2804     w3381
# 182  182     a2804     w3386
# 183  183     a2047     w2453
# 184  184     a2047     w2184
# 185  185     a2047     w1404
# 186  186     a2814     w2389
# 187  187     a2821      w644
# 188  188     a1952     w3603
# 189  189     a1952     w3946
# 190  190     a2018     w3536
# 191  191     a2047     w2517
# 192  192     a2047     w2765
# 193  193     a2804     w3319
# 194  194     a2056     w2530
# 195  195     a2841      w558
# 196  196     a2060     w1195
# 197  197     a2060     w2546
# 198  198     a2068     w1389
# 199  199     a2068     w2632
#
#                                                                                     ltable_product_title  \
# 0                                                acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10
# 1              lenovo thinkpad t570 20h9000nus core i7 7600u 2.8 ghz win 10 8 gb 256 gb ssd 15.6 ips fhd
# 2                            hp 3fb86ut zbook x2 g4 tablet core i7 7600u 2.8 ghz win 10 16 gb 512 gb ssd
# 3                                        newest hp 15.6 hd intel pentium 8gb 1tb hdd writerhd windows 10
# 4                               2017 hp pc 15.6 hd intel pentium quad core 8gb 500gb hdd hdmi windows 10
# 5         2017 lenovo flex 4 2 1 14 full hd touchscreen pc intel core i7 7500u 8gb 512gb ssd windows 10
# 6    acer aspire v nitro vn7 15.6 fhd touchscreen intel core i7 6500u 2.50 ghz nvidia geforce gtx 950...
# 7    acer aspire v nitro vn7 15.6 fhd touchscreen intel core i7 6500u 2.50 ghz nvidia geforce gtx 950...
# 8    acer aspire v nitro vn7 15.6 fhd touchscreen intel core i7 6500u 2.50 ghz nvidia geforce gtx 950...
# 9    2018 hp envy x360 2 1 convertible 15.6 full hd touchscreen pc intel core i7 8550u quad core 12gb...
# 10                                                        thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd
# 11                             dell inspiron 2 1 7000 7373 13.3 fhd touch 8th gen i5 8250u 8gb 256gb ssd
# 12                    dell xps 13 9365 13.3 qhd touch intel core i7 7y75 16gb 512gb ssd windows 10 black
# 13                               hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 14                        dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10
# 15                          lenovo t460s 20f9003cus 14 intel i7 6600u 2.6ghz 8gb 256gb ssd windows 7 64
# 16                                                        thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd
# 17                          lenovo t460s 20f9003cus 14 intel i7 6600u 2.6ghz 8gb 256gb ssd windows 7 64
# 18                   dell inspiron 2 1 15 i7579 5588gry pus 15.6 fhd touch i5 7200u 8gb 256gb ssd silver
# 19                              dell xps 9350 1340slv 13.3 intel core i5 8 gb 128 gb ssd microsoft image
# 20                        dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10
# 21                                                 hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd
# 22                                     hp pavilion 15 intel core i5 7200u 8gb 1tb windows 10 15 cc010nr
# 23           2018 acer 15.6 intel core i3 7100u 2.4ghz 4gb 128gb ssd intel hd 620 sd hdmi hd windows 10
# 24               lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 25                                                        thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd
# 26               lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 27               lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 28                                                        thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd
# 29               lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# ..                                                                                                   ...
# 170                                                                              apple 13.3 macbook air
# 171                                                                  dell chromebook 11 3180 d44pv 11.6
# 172                                                                              apple 13.3 macbook air
# 173                                                                    apple macbook air md760ll a 13.3
# 174                                     dell xps 13 9365 2 1 13.3 fhd touch i7 7y75 8gb 256gb ssd silver
# 175                                                                              apple 13.3 macbook air
# 176                                                                              apple 13.3 macbook air
# 177                                                                              apple 13.3 macbook air
# 178                                              acer intel core i5 2.50 ghz 8 gb 256 gb ssd windows 10
# 179              lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 180              lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 181              lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 182              lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 183                                     lenovo thinkpad t470 14 core i5 7200u 8 gb 500 gb hdd 20hd000tus
# 184                                     lenovo thinkpad t470 14 core i5 7200u 8 gb 500 gb hdd 20hd000tus
# 185                                     lenovo thinkpad t470 14 core i5 7200u 8 gb 500 gb hdd 20hd000tus
# 186    dell latitude 5480 14.0 hd lcd intel core 7th i5 7300u 4 gb ddr4 256 gb ssd camera windows 10 pro
# 187  hp spectre x360 15.6 convertible 2.7 ghz intel core i7 7500u 16 gb sdram 512 gb ssd windows 10 6...
# 188                                                                   apple macbook md212ll a 13 retina
# 189                                                                   apple macbook md212ll a 13 retina
# 190                              apple macbook mluq2ll a 13 2.0ghz dual core intel core i5 256gb retina
# 191                                     lenovo thinkpad t470 14 core i5 7200u 8 gb 500 gb hdd 20hd000tus
# 192                                     lenovo thinkpad t470 14 core i5 7200u 8 gb 500 gb hdd 20hd000tus
# 193              lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 194  2018 hp pc 17.3 hd wled intel i7 7500u 8gb ddr4 256gb ssd intel 620 rw 802.11ac hdmi windows 10 ...
# 195  2018 hp envy x360 2 1 convertible 15.6 full hd touchscreen pc intel core i7 8550u quad core 12gb...
# 196                                  lenovo ideapad 300 15.6 core i7 8 gb 1 tb hdd windows 10 80q70020us
# 197                                  lenovo ideapad 300 15.6 core i7 8 gb 1 tb hdd windows 10 80q70020us
# 198  alienware aw17r3 7092slv 17.3 fhd 6th intel core i7 16 gb 256 gb ssd 1 tb hdd nvidia geforce gtx...
# 199  alienware aw17r3 7092slv 17.3 fhd 6th intel core i7 16 gb 256 gb ssd 1 tb hdd nvidia geforce gtx...
#
#       ltable_brand          ltable_model  \
# 0             acer          nx.gr7aa.007
# 1           lenovo            20h9000nus
# 2              NaN               3fb86ut
# 3        hp laptop                   NaN
# 4               hp                 t8tjg
# 5           lenovo                   NaN
# 6             acer                   NaN
# 7             acer                   NaN
# 8             acer                   NaN
# 9               hp                   NaN
# 10          lenovo            20hd0057us
# 11            dell                 t8tjg
# 12            dell                 9x0t5
# 13              hp                   NaN
# 14            dell                 t8tjg
# 15          lenovo            20f9003cus
# 16          lenovo            20hd0057us
# 17          lenovo            20f9003cus
# 18            dell                 t8tjg
# 19            dell       xps9350 1340slv
# 20            dell                 t8tjg
# 21              hp             13 d010nr
# 22              hp            15 cc010nr
# 23            acer                  acer
# 24          lenovo            80xc0003us
# 25          lenovo            20hd0057us
# 26          lenovo            80xc0003us
# 27          lenovo            80xc0003us
# 28          lenovo            20hd0057us
# 29          lenovo            80xc0003us
# ..             ...                   ...
# 170          apple             mlh72ll a
# 171           dell                 d44pv
# 172          apple             mlh72ll a
# 173          apple             md760ll a
# 174  dell consumer  dell xps 13 9365 2 1
# 175          apple             mlh72ll a
# 176          apple             mlh72ll a
# 177          apple             mlh72ll a
# 178           acer         a517 51g 54gk
# 179         lenovo            80xc0003us
# 180         lenovo            80xc0003us
# 181         lenovo            80xc0003us
# 182         lenovo            80xc0003us
# 183         lenovo            20hd000tus
# 184         lenovo            20hd000tus
# 185         lenovo            20hd000tus
# 186           dell                   NaN
# 187             hp               z4z37ua
# 188          apple             md212ll a
# 189          apple             md212ll a
# 190          apple             mluq2ll a
# 191         lenovo            20hd000tus
# 192         lenovo            20hd000tus
# 193         lenovo            80xc0003us
# 194             hp                   NaN
# 195             hp                   NaN
# 196         lenovo            80q70020us
# 197         lenovo            80q70020us
# 198      alienware        aw17r3 7092slv
# 199      alienware        aw17r3 7092slv
#
#                                                                                    ltable_extended_title  \
# 0                                    acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10 nx.gr7aa.007
# 1      lenovo thinkpad t570 20h9000nus core i7 7600u 2.8 ghz win 10 8 gb 256 gb ssd 15.6 ips fhd unknown
# 2                    hp 3fb86ut zbook x2 g4 tablet core i7 7600u 2.8 ghz win 10 16 gb 512 gb ssd unknown
# 3                                 newest hp 15.6 hd intel pentium 8gb 1tb hdd writerhd windows 10 laptop
# 4                         2017 hp pc 15.6 hd intel pentium quad core 8gb 500gb hdd hdmi windows 10 t8tjg
# 5         2017 lenovo flex 4 2 1 14 full hd touchscreen pc intel core i7 7500u 8gb 512gb ssd windows 10
# 6    acer aspire v nitro vn7 15.6 fhd touchscreen intel core i7 6500u 2.50 ghz nvidia geforce gtx 950...
# 7    acer aspire v nitro vn7 15.6 fhd touchscreen intel core i7 6500u 2.50 ghz nvidia geforce gtx 950...
# 8    acer aspire v nitro vn7 15.6 fhd touchscreen intel core i7 6500u 2.50 ghz nvidia geforce gtx 950...
# 9    2018 hp envy x360 2 1 convertible 15.6 full hd touchscreen pc intel core i7 8550u quad core 12gb...
# 10                              thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd lenovo 20hd0057us unknown
# 11            dell inspiron 2 1 7000 7373 13.3 fhd touch 8th gen i5 8250u 8gb 256gb ssd t8tjg windows 10
# 12               dell xps 13 9365 13.3 qhd touch intel core i7 7y75 16gb 512gb ssd windows 10 9x0t5 home
# 13                               hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 14                  dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10 t8tjg
# 15              lenovo t460s 20f9003cus 14 intel i7 6600u 2.6ghz 8gb 256gb ssd windows 7 64 professional
# 16                              thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd lenovo 20hd0057us unknown
# 17              lenovo t460s 20f9003cus 14 intel i7 6600u 2.6ghz 8gb 256gb ssd windows 7 64 professional
# 18         dell inspiron 2 1 15 i7579 5588gry pus 15.6 fhd touch i5 7200u 8gb 256gb ssd t8tjg windows 10
# 19         dell xps 9350 1340slv 13.3 intel core i5 8 gb 128 gb ssd microsoft xps9350 1340slv windows 10
# 20                  dell inspiron 13 2 1 core i7 8550u 256gb ssd 8gb 13.3 full hd touch windows 10 t8tjg
# 21                                          hp envy 13 d010nr 13.3 intel core i5 8 gb 128 gb ssd windows
# 22                                     hp pavilion 15 intel core i5 7200u 8gb 1tb windows 10 15 cc010nr
# 23           2018 acer 15.6 intel core i3 7100u 2.4ghz 4gb 128gb ssd intel hd 620 sd hdmi hd windows 10
# 24              lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 25                              thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd lenovo 20hd0057us unknown
# 26              lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 27              lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 28                              thinkpad t470 14 core i7 7600u 8 gb 256 gb ssd lenovo 20hd0057us unknown
# 29              lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# ..                                                                                                   ...
# 170                                                                   apple 13.3 macbook air mlh72ll a x
# 171                                                                  dell chromebook 11 3180 d44pv 11.6
# 172                                                                   apple 13.3 macbook air mlh72ll a x
# 173                                                         apple macbook air md760ll a 13.3 x mavericks
# 174                        dell xps 13 9365 2 1 13.3 fhd touch i7 7y75 8gb 256gb ssd consumer windows 10
# 175                                                                   apple 13.3 macbook air mlh72ll a x
# 176                                                                   apple 13.3 macbook air mlh72ll a x
# 177                                                                   apple 13.3 macbook air mlh72ll a x
# 178                                 acer intel core i5 2.50 ghz 8 gb 256 gb ssd windows 10 a517 51g 54gk
# 179             lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 180             lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 181             lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 182             lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 183                             lenovo thinkpad t470 14 core i5 7200u 8 gb 500 gb hdd 20hd000tus unknown
# 184                             lenovo thinkpad t470 14 core i5 7200u 8 gb 500 gb hdd 20hd000tus unknown
# 185                             lenovo thinkpad t470 14 core i5 7200u 8 gb 500 gb hdd 20hd000tus unknown
# 186       dell latitude 5480 14.0 hd lcd intel core 7th i5 7300u 4 gb ddr4 256 gb ssd camera windows 10
# 187  hp spectre x360 15.6 convertible 2.7 ghz intel core i7 7500u 16 gb sdram 512 gb ssd windows 10 6...
# 188                                               apple macbook md212ll a 13 retina x 10.8 mountain lion
# 189                                               apple macbook md212ll a 13 retina x 10.8 mountain lion
# 190                        apple macbook mluq2ll a 13 2.0ghz dual core intel core i5 256gb retina sierra
# 191                             lenovo thinkpad t470 14 core i5 7200u 8 gb 500 gb hdd 20hd000tus unknown
# 192                             lenovo thinkpad t470 14 core i5 7200u 8 gb 500 gb hdd 20hd000tus unknown
# 193             lenovo ideapad 720s 14 fhd ips intel core i7 7500u 16gb 512gb ssd windows 10 80xc0003us
# 194     2018 hp pc 17.3 hd wled intel i7 7500u 8gb ddr4 256gb ssd intel 620 rw 802.11ac hdmi windows 10
# 195  2018 hp envy x360 2 1 convertible 15.6 full hd touchscreen pc intel core i7 8550u quad core 12gb...
# 196                                 lenovo ideapad 300 15.6 core i7 8 gb 1 tb hdd windows 10 80q70020us
# 197                                 lenovo ideapad 300 15.6 core i7 8 gb 1 tb hdd windows 10 80q70020us
# 198  alienware aw17r3 7092slv 17.3 fhd 6th intel core i7 16 gb 256 gb ssd 1 tb hdd nvidia geforce gtx...
# 199  alienware aw17r3 7092slv 17.3 fhd 6th intel core i7 16 gb 256 gb ssd 1 tb hdd nvidia geforce gtx...
#
#                                                                                     rtable_product_title  \
# 0                                   refurbished acer amd fx series 3 ghz 8 gb 256 gb ssd windows 10 home
# 1                                                lenovo thinkpad p51s 15.6 core i7 7500u 8 gb 256 gb ssd
# 2                                                    hp zbook 15u g4 15.6 core i7 7500u 16 gb 512 gb ssd
# 3                       2017 hp touchscreen 15.6 hd intel i3 7100u dual core 8gb 1tb hdd hdmi windows 10
# 4           2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 5                              lenovo flex 5 2 1 core i5 8250u 8gb 128gb ssd 14 full hd touch windows 10
# 6                        acer 15.6 intel core i7 2.6ghz 16 gb 1 tb hdd 256 gb ssd windows 10 g9 593 72vt
# 7                  refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 home
# 8                  refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 home
# 9    hp envy x360 15 aq165nr 15.6 touchscreen 2 1 windows 10 intel core i7 7500u dual core 8gb 1tb drive
# 10                                            lenovo thinkpad x1 carbon 14 core i7 6600u 8 gb 512 gb ssd
# 11                                                   dell inspiron 2 1 13.3 intel i5 7200u 8gb 256gb ssd
# 12     refurbished dell xps 13 9365 2 1 i7 7y75 16gb 256gb ssd fhd touch infinity windows 10 fingerprint
# 13          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 14      refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10 fingerprint
# 15        lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 512gb ssd 14 ips fhd 1920x1080 ac wifi
# 16                                              lenovo thinkpad x1 yoga 14 core i5 7300u 8 gb 256 gb ssd
# 17        lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 512gb ssd 14 ips fhd 1920x1080 ac wifi
# 18                                                   dell inspiron 2 1 13.3 intel i5 7200u 8gb 256gb ssd
# 19                                                   dell xps 13 9360 13.3 core i5 7200u 8 gb 256 gb ssd
# 20      refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10 fingerprint
# 21                                       hp elitebook x360 1030 g2 13.3 core i5 7200u 8 gb 128 gb ssd us
# 22              hp pavilion 15 bk020wm x360 15.6 touch 2 1 windows 10 intel core i5 6200u 8gb 1tb silver
# 23   newest acer aspire e15 15.6 fhd intel core i3 7100u 7th 4gb ddr4 1tb 5400rpm hd intel hd 620 win...
# 24   pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 512gb nvme ssd 14 ips fhd 1920x10...
# 25                                            lenovo thinkpad x1 carbon 14 core i5 6300u 8 gb 256 gb ssd
# 26   pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 512gb nvme ssd 14 ips fhd 1920x108...
# 27   pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 512gb nvme ssd 14 ips fhd 1920x10...
# 28                                           lenovo thinkpad yoga 370 13.3 core i7 7500u 8 gb 256 gb ssd
# 29   pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 512gb nvme ssd 14 ips fhd 1920x108...
# ..                                                                                                   ...
# 170                                                         apple macbook air md231ll a 13.3 refurbished
# 171                                                                              dell chromebook 11 3180
# 172                                                   apple macbook air md231ll a 13.3 scratched dented
# 173                                                                    apple macbook air 13.3 md761ll a
# 174                                refurbished dell xps 13 9365 2 1 i7 7y75 16gb 256gb ssd fhd touch w10
# 175                                                                    apple macbook air 11.6 md224ll a
# 176                                                                    apple macbook air 11.6 md712ll a
# 177                                                                    apple macbook air 13.3 md761ll a
# 178                              refurbished acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10 home
# 179       lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 180    lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 512gb ssd 14 ips wqhd 2560x1440 ac wifi
# 181       lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 182       lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 1tb ssd 14 ips fhd 1920x1080 ac wifi
# 183                                              lenovo thinkpad e570 15.6 core i5 7200u 8 gb 180 gb ssd
# 184                                              lenovo thinkpad p51s 15.6 core i7 7500u 8 gb 500 gb hdd
# 185                                              lenovo thinkpad p50 15.6 core i7 6700hq 8 gb 500 gb hdd
# 186                                                dell latitude 5580 15.6 core i5 7300u 8 gb 256 gb ssd
# 187                                                  hp zbook 15u g4 15.6 core i7 7500u 16 gb 512 gb ssd
# 188                                                                              apple macbook mc118ll a
# 189                                                                 apple macbook me864ll a 13.3 retina
# 190                     apple 13 macbook air 1.8ghz intel core i5 dual core 8gb 128gb ssd mac mqd32ll a
# 191                                                lenovo thinkpad t470 14 core i7 6500u 8 gb 256 gb ssd
# 192                                                lenovo thinkpad t450 14 core i5 5300u 8 gb 256 gb ssd
# 193  pcie touch lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 512gb nvme ssd 14 ips fhd 1...
# 194         2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 195      hp envy 15 w105wm x360 15.6 full hd ips touch 2 1 windows 10 intel core i7 6500u 8gb 1tb silver
# 196                                    refurbished dell inspiron i5559 15.6 intel core i7 8 gb 1 tb hdd
# 197                                                  hp zbook 15 g4 15.6 core i7 7700hq 8 gb 1 tb hdd us
# 198                refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 home
# 199                refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 home
#
#     rtable_brand     rtable_model  \
# 0           acer     nh.q2uaa.003
# 1         lenovo       20hb000aus
# 2             hp      1bs35ut#aba
# 3             hp             2017
# 4             hp              NaN
# 5         lenovo       81c9000cus
# 6           acer     nh.q1caa.001
# 7           acer     nh.q26aa.002
# 8           acer     nh.q1taa.001
# 9             hp      w2k50ua#aba
# 10        lenovo       20fb002sus
# 11          dell    i5378 5896gry
# 12          dell              NaN
# 13            hp             2017
# 14          dell              NaN
# 15        lenovo              NaN
# 16        lenovo       20jd000rus
# 17        lenovo              NaN
# 18          dell    i5378 5896gry
# 19          dell            djgg0
# 20          dell              NaN
# 21            hp      1nm36ut#aba
# 22            hp      w2m07ua#aba
# 23          acer              NaN
# 24        lenovo              NaN
# 25        lenovo       20fb004jus
# 26        lenovo              NaN
# 27        lenovo              NaN
# 28        lenovo       20jh002fus
# 29        lenovo              NaN
# ..           ...              ...
# 170        apple              NaN
# 171         dell            83c80
# 172        apple              NaN
# 173        apple              NaN
# 174         dell              NaN
# 175        apple              NaN
# 176        apple              NaN
# 177        apple              NaN
# 178         acer     nx.gtsaa.005
# 179       lenovo              NaN
# 180       lenovo              NaN
# 181       lenovo              NaN
# 182       lenovo              NaN
# 183       lenovo       20h500a9us
# 184       lenovo       20hb001kus
# 185       lenovo       20en0013us
# 186         dell            66txp
# 187           hp      1bs35ut#aba
# 188        apple        mc118ll a
# 189        apple  crtapme864llarb
# 190        apple        mqd32ll a
# 191       lenovo       20jm000bus
# 192       lenovo       20bv0065us
# 193       lenovo              NaN
# 194           hp              NaN
# 195           hp      x0s29ua#aba
# 196         dell              NaN
# 197           hp      1jd32ut#aba
# 198         acer     nh.q1taa.001
# 199         acer     nh.q26aa.002
#
#                                                                                    rtable_extended_title
# 0                           refurbished acer amd fx series 3 ghz 8 gb 256 gb ssd windows 10 nh.q2uaa.003
# 1                         lenovo thinkpad p51s 15.6 core i7 7500u 8 gb 256 gb ssd 20hb000aus windows 10
# 2                             hp zbook 15u g4 15.6 core i7 7500u 16 gb 512 gb ssd 1bs35ut#aba windows 10
# 3                      2017 hp touchscreen 15.6 hd intel i3 7100u dual core 8gb 1tb hdd hdmi windows 10
# 4           2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 5         lenovo flex 5 2 1 core i5 8250u 8gb 128gb ssd 14 full hd touch windows 10 81c9000cus microsoft
# 6           acer 15.6 intel core i7 2.6ghz 16 gb 1 tb hdd 256 gb ssd windows 10 g9 593 72vt nh.q1caa.001
# 7          refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 nh.q26aa.002
# 8          refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 nh.q1taa.001
# 9    hp envy x360 15 aq165nr 15.6 touchscreen 2 1 windows 10 intel core i7 7500u dual core 8gb 1tb w2...
# 10                         lenovo thinkpad x1 carbon 14 core i7 6600u 8 gb 512 gb ssd 20fb002sus windows
# 11                         dell inspiron 2 1 13.3 intel i5 7200u 8gb 256gb ssd i5378 5896gry windows 10
# 12                refurbished dell xps 13 9365 2 1 i7 7y75 16gb 256gb ssd fhd touch infinity windows 10
# 13          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 14                 refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10
# 15               lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 512gb ssd 14 ips fhd 1920x1080
# 16                       lenovo thinkpad x1 yoga 14 core i5 7300u 8 gb 256 gb ssd 20jd000rus windows 10
# 17               lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 512gb ssd 14 ips fhd 1920x1080
# 18                         dell inspiron 2 1 13.3 intel i5 7200u 8gb 256gb ssd i5378 5896gry windows 10
# 19                                  dell xps 13 9360 13.3 core i5 7200u 8 gb 256 gb ssd djgg0 windows 10
# 20                 refurbished dell xps 13 9365 2 1 i7 7y75 8gb 256gb ssd fhd touch infinity windows 10
# 21                   hp elitebook x360 1030 g2 13.3 core i5 7200u 8 gb 128 gb ssd us 1nm36ut#aba windows
# 22         hp pavilion 15 bk020wm x360 15.6 touch 2 1 windows 10 intel core i5 6200u 8gb 1tb w2m07ua#aba
# 23   newest acer aspire e15 15.6 fhd intel core i3 7100u 7th 4gb ddr4 1tb 5400rpm hd intel hd 620 win...
# 24   pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 512gb nvme ssd 14 ips fhd 1920x1080
# 25                       lenovo thinkpad x1 carbon 14 core i5 6300u 8 gb 256 gb ssd 20fb004jus windows 7
# 26    pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 512gb nvme ssd 14 ips fhd 1920x1080
# 27   pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 512gb nvme ssd 14 ips fhd 1920x1080
# 28                    lenovo thinkpad yoga 370 13.3 core i7 7500u 8 gb 256 gb ssd 20jh002fus windows 10
# 29    pcie lenovo thinkpad t460s windows 10 intel core i7 6600u 8gb 512gb nvme ssd 14 ips fhd 1920x1080
# ..                                                                                                   ...
# 170                                                   apple macbook air md231ll a 13.3 microsoft windows
# 171                                                                        dell chromebook 11 3180 83c80
# 172                                  apple macbook air md231ll a 13.3 scratched dented microsoft windows
# 173                                                                    apple macbook air 13.3 md761ll a
# 174                        refurbished dell xps 13 9365 2 1 i7 7y75 16gb 256gb ssd fhd touch w10 windows
# 175                                                                    apple macbook air 11.6 md224ll a
# 176                                                                    apple macbook air 11.6 md712ll a
# 177                                                                    apple macbook air 13.3 md761ll a
# 178                      refurbished acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10 nx.gtsaa.005
# 179              lenovo thinkpad t460s windows 10 intel core i7 6600u 12gb 1tb ssd 14 ips fhd 1920x1080
# 180           lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 512gb ssd 14 ips wqhd 2560x1440
# 181              lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 1tb ssd 14 ips fhd 1920x1080
# 182              lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 1tb ssd 14 ips fhd 1920x1080
# 183                        lenovo thinkpad e570 15.6 core i5 7200u 8 gb 180 gb ssd 20h500a9us windows 10
# 184                        lenovo thinkpad p51s 15.6 core i7 7500u 8 gb 500 gb hdd 20hb001kus windows 10
# 185                        lenovo thinkpad p50 15.6 core i7 6700hq 8 gb 500 gb hdd 20en0013us windows 10
# 186                               dell latitude 5580 15.6 core i5 7300u 8 gb 256 gb ssd 66txp windows 10
# 187                           hp zbook 15u g4 15.6 core i7 7500u 16 gb 512 gb ssd 1bs35ut#aba windows 10
# 188                                                            apple macbook mc118ll a osx 10.7 or newer
# 189                                                  apple macbook me864ll a 13.3 retina crtapme864llarb
# 190    apple 13 macbook air 1.8ghz intel core i5 dual core 8gb 128gb ssd mac mqd32ll a microsoft windows
# 191                          lenovo thinkpad t470 14 core i7 6500u 8 gb 256 gb ssd 20jm000bus windows 10
# 192                           lenovo thinkpad t450 14 core i5 5300u 8 gb 256 gb ssd 20bv0065us windows 7
# 193  pcie touch lenovo thinkpad t460s windows 10 intel core i7 6600u 20gb 512gb nvme ssd 14 ips fhd 1...
# 194         2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 195  hp envy 15 w105wm x360 15.6 full hd ips touch 2 1 windows 10 intel core i7 6500u 8gb 1tb x0s29ua...
# 196                   refurbished dell inspiron i5559 15.6 intel core i7 8 gb 1 tb hdd microsoft windows
# 197                           hp zbook 15 g4 15.6 core i7 7700hq 8 gb 1 tb hdd us 1jd32ut#aba windows 10
# 198        refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 nh.q1taa.001
# 199        refurbished acer 17.3 intel core i7 2.8 ghz 16 gb 1 tb hdd 256 gb ssd windows 10 nh.q26aa.002
#
# [200 rows x 11 columns]

# %% [markdown]
# The blocker seem to have reduced the input size by 45x. However, on debugging the blocker we observe that it is still dropping potential matches. So, we are going to debug the blocker further.

# %%
def match_extended_title(attribute='extended_title',q_val=3, threshold=.5,debug=False):
    def jaccard_matcher(ltuple,rtuple, attribute=attribute, q_val=q_val, threshold=threshold,debug=debug):
        buffer = '#' * (q_val-1)
        l_attribute = buffer + ltuple[attribute] + buffer
        r_attribute = buffer + rtuple[attribute] + buffer
        l_grams = set()
        r_grams = set()
        # create sets of grams
        for attribute, grams in [(l_attribute,l_grams), (r_attribute,r_grams)]:
            for i in range(0,len(attribute)-(q_val-1)):
                grams.add(attribute[i:i+q_val])
               
        # compute jaccard
        intersection = list(set(l_grams) & set(r_grams))
        union = list(set(l_grams) | set(r_grams))
        if debug:
            print(union)
            print(intersection)
            print(len(intersection) / len(union))
        return len(intersection) / len(union) < threshold
    
    return jaccard_matcher

bb = em.BlackBoxBlocker()
bb.set_black_box_function(match_extended_title())
C3 = bb.block_candset(C2,  
                     show_progress=False,
                     n_jobs=-1
                     )
# Updated blocking sequence
# A, B --- overlap blocker [model] ---------------------> C1--------------------------------|
#                                                                                     union |---> C
# A, B --- overlap blocker [extended_title] ---> C2---> jaccard blocker [extended_title] ---|
C = em.combine_blocker_outputs_via_union([C1,C3])

# %%
# Debug again
dbg = em.debug_blocker(C, A, B)
dbg
# Out:
#      _id ltable_id rtable_id  \
# 0      0      a298     w3394
# 1      1      a298     w3458
# 2      2      a298     w3439
# 3      3      a298     w3327
# 4      4      a298     w3400
# 5      5      a298     w3422
# 6      6      a298     w3443
# 7      7      a298     w3250
# 8      8      a298     w3015
# 9      9      a298     w3014
# 10    10     a2860      w790
# 11    11     a2257      w659
# 12    12     a2616     w1480
# 13    13      a763     w2527
# 14    14     a1883      w921
# 15    15     a1883     w2492
# 16    16     a1883     w2762
# 17    17     a1701     w2530
# 18    18     a1883     w2509
# 19    19      a298     w3016
# 20    20     a1329     w1459
# 21    21      a551      w603
# 22    22     a1269      w517
# 23    23     a1617     w2954
# 24    24     a2901     w2220
# 25    25       a70       w17
# 26    26     a2257      w619
# 27    27     a1514      w557
# 28    28      a998      w674
# 29    29     a2637      w748
# ..   ...       ...       ...
# 170  170     a2890     w2259
# 171  171     a2060     w2487
# 172  172     a2055     w4551
# 173  173     a2743     w2341
# 174  174     a2055     w4539
# 175  175     a1608      w768
# 176  176     a2054     w1175
# 177  177     a2901       w39
# 178  178     a2054     w1174
# 179  179     a1954     w1071
# 180  180     a2041     w3055
# 181  181     a1617      w454
# 182  182     a1617      w477
# 183  183     a2035     w2585
# 184  184     a2019     w2472
# 185  185     a2008     w3024
# 186  186     a2902      w902
# 187  187     a1959     w1638
# 188  188     a1957     w2341
# 189  189     a1269     w2616
# 190  190     a1738     w1556
# 191  191     a1617     w3104
# 192  192     a1767     w2016
# 193  193     a1617     w3146
# 194  194     a1767     w1987
# 195  195     a1617     w3173
# 196  196     a1753      w104
# 197  197     a1753       w68
# 198  198     a2965     w2530
# 199  199     a2965      w809
#
#                                                                                     ltable_product_title  \
# 0    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 1    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 2    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 3    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 4    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 5    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 6    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 7    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 8    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 9    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 10   dell xps 15 9560 4k uhd intel core i7 7700hq 16gb 512gb ssd nvidia gtx 1050 4gb gddr5 windows 10...
# 11         newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 12   prostar clevo pa71hs g 17.3” full hd ips g sync intel core i7 7700hq 16gb ddr4 gtx 1070 256gb nv...
# 13                                      hp elitebook 840 g4 14 core i5 7200u 8 gb 256 gb ssd 1ge40ut#aba
# 14                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 15                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 16                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 17   2017 hp fhd 15.6 wled intel core i5 7200u 3.1ghz 8gb ddr4 1tb hdd usb 3.1 802.11 ac hdmi windows 10
# 18                 hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba
# 19   lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 20   prostar clevo n870hp6 17.3” full hd ips intel core i7 7700hq 32gb ddr4 gtx 1060 500gb ssd 1tb hd...
# 21                               hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 22       lenovo thinkpad t470s windows 10 intel core i7 7600u 16gb 512gb ssd 14 ips wqhd 2560x1440 color
# 23                   lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 24                       hp pavilion 15.6 hd touchscreen intel core i5 8gb 1tb hdd windows 10 15 au057cl
# 25                    hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 26         newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 27   2018 rca cambio 10.1 2 1 touchscreen tablet pc intel quad core 2gb 32gb microsoft office windows...
# 28           hp 15.6 touchscreen quad core amd a12 3.6ghz 8gb 1tb hdd 4gb amd radeon r7 hdmi windows 10
# 29   2016 dell inspiron 5000 touchscreen 15.6 fhd 6th intel core i5 6200u 2.8ghz 8 gb 1 tb hdd hdmi 8...
# ..                                                                                                   ...
# 170                       hp stream 14 intel celeron n3050 1.6ghz 4gb 32gb windows 10 violet refurbishd
# 171                                  lenovo ideapad 300 15.6 core i7 8 gb 1 tb hdd windows 10 80q70020us
# 172                            acer aspire 5 a517 51g 54gk intel core i5 8 gb 256 gb ssd 17.3 windows 10
# 173                dell cxjv3 precision 7710 17.3 fhd intel core i7 6820hq 8gb ddr4 500gb windows 10 pro
# 174                            acer aspire 5 a517 51g 54gk intel core i5 8 gb 256 gb ssd 17.3 windows 10
# 175                   dell xps 13 9365 13.3 qhd touch intel core i7 7y75 16gb 512gb ssd windows 10 black
# 176                                    hp 17.3 hd intel core i5 7200u 8gb 1tb optical hd windows 10 gold
# 177                      hp pavilion 15.6 hd touchscreen intel core i5 8gb 1tb hdd windows 10 15 au057cl
# 178                                    hp 17.3 hd intel core i5 7200u 8gb 1tb optical hd windows 10 gold
# 179  refurbished panasonic cf 31 toughbook intel core i5 2.5ghz 1tb ssd solid state 16gb ddr3 13.1 to...
# 180                            lenovo thinkpad x1 carbon 20fb002rus 14 intel core i5 6200u 8gb 256gb ssd
# 181                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 182                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 183         dell tfg4h latitude 3380 13.3 hdf intel core i3 6006u 4gb ddr4 128gb solid state windows 10
# 184                      tw dell latitude 5480 14 hd intel core i5 7300hq windows 10 8gb ddr4 512gb ssd
# 185  msi gs63 stealth 061 i7 7700hq 16gb 128gb nvme ssd 1tb hdd nvidia gtx 1050 2gb 15.6 full hd wind...
# 186  dell inspiron i5559 full hd 1920x1080 touchscreen 15.6 intel core i7 6500u 3.1ghz 8gb ddr3 250gb...
# 187  msi gs43vr phantom 069 i7 7700hq 16gb 128gb sata ssd 1tb hdd nvidia gtx 1060 6gb 14 full hd wind...
# 188                         2018 dell pc 15.6 fhd intel i7 7500u 8gb ddr4 1tb hdd hdmi windows 10 silver
# 189      lenovo thinkpad t470s windows 10 intel core i7 7600u 16gb 512gb ssd 14 ips wqhd 2560x1440 color
# 190  alienware aw15r2 8469slv 15.6 uhd 6th intel core i7 16 gb 1 tb hdd 256 gb sata ssd nvidia geforc...
# 191                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 192  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 193                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 194  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 195                  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus
# 196                                        dell inspiron 2 1 13.3 touch intel core i7 8gb 256gb ssd gray
# 197                                        dell inspiron 2 1 13.3 touch intel core i7 8gb 256gb ssd gray
# 198                                 hp 15.6 hd pc intel core i7 6500u 8gb 1tb hdd rw hdmi dts windows 10
# 199                                 hp 15.6 hd pc intel core i7 6500u 8gb 1tb hdd rw hdmi dts windows 10
#
#           ltable_brand        ltable_model ltable_operating_system  \
# 0               lenovo          20fb002lus  windows 7 professional
# 1               lenovo          20fb002lus  windows 7 professional
# 2               lenovo          20fb002lus  windows 7 professional
# 3               lenovo          20fb002lus  windows 7 professional
# 4               lenovo          20fb002lus  windows 7 professional
# 5               lenovo          20fb002lus  windows 7 professional
# 6               lenovo          20fb002lus  windows 7 professional
# 7               lenovo          20fb002lus  windows 7 professional
# 8               lenovo          20fb002lus  windows 7 professional
# 9               lenovo          20fb002lus  windows 7 professional
# 10                dell               t8tjg              windows 10
# 11                  hp                 NaN              windows 10
# 12             prostar            pa71hs g              windows 10
# 13                  hp         1ge40ut#aba          windows 10 pro
# 14                  hp         x9v54ut#aba      windows 10 edition
# 15                  hp         x9v54ut#aba      windows 10 edition
# 16                  hp         x9v54ut#aba      windows 10 edition
# 17                  hp               15 ay              windows 10
# 18                  hp         x9v54ut#aba      windows 10 edition
# 19              lenovo          20fb002lus  windows 7 professional
# 20             prostar             n870hp6              windows 10
# 21                  hp                 NaN              windows 10
# 22              lenovo                 NaN          windows 10 pro
# 23              lenovo          20bs00bgus  windows 7 professional
# 24                  hp             w2l56ua              windows 10
# 25                  hp               hp 15              windows 10
# 26                  hp                 NaN              windows 10
# 27                 NaN                 NaN             android 6.0
# 28                  hp               t8tjg              windows 10
# 29                dell        727363170767              windows 10
# ..                 ...                 ...                     ...
# 170                 hp                 NaN              windows 10
# 171             lenovo          80q70020us              windows 10
# 172               acer       a517 51g 54gk         windows 10 home
# 173               dell               cxjv3          windows 10 pro
# 174               acer       a517 51g 54gk         windows 10 home
# 175               dell               9x0t5         windows 10 home
# 176                 hp         1kv31ua#aba              windows 10
# 177                 hp             w2l56ua              windows 10
# 178                 hp         1kv31ua#aba              windows 10
# 179  quality computers   cf31i525161tbssdn  windows 7 professional
# 180             lenovo          20fb002rus  windows 7 professional
# 181             lenovo          20bs00bgus  windows 7 professional
# 182             lenovo          20bs00bgus  windows 7 professional
# 183               dell               tfg4h          windows 10 pro
# 184       tech wizards                 NaN              windows 10
# 185        excaliberpc    gs63 stealth 061    microsoft windows 10
# 186               dell            7.15e 11              windows 10
# 187        excaliberpc  gs43vr phantom 069    microsoft windows 10
# 188               dell                 NaN          windows 10 pro
# 189             lenovo                 NaN          windows 10 pro
# 190          alienware      aw15r2 8469slv              windows 10
# 191             lenovo          20bs00bgus  windows 7 professional
# 192             lenovo                 NaN       windows 10 64 bit
# 193             lenovo          20bs00bgus  windows 7 professional
# 194             lenovo                 NaN       windows 10 64 bit
# 195             lenovo          20bs00bgus  windows 7 professional
# 196           dell usa   i5379 7923gry pus              windows 10
# 197           dell usa   i5379 7923gry pus              windows 10
# 198                 hp                 NaN              windows 10
# 199                 hp                 NaN              windows 10
#
#                                                                                    ltable_extended_title  \
# 0    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 1    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 2    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 3    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 4    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 5    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 6    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 7    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 8    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 9    lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 10   dell xps 15 9560 4k uhd intel core i7 7700hq 16gb 512gb ssd nvidia gtx 1050 4gb gddr5 windows 10...
# 11        newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 12   prostar clevo pa71hs g 17.3” full hd ips g sync intel core i7 7700hq 16gb ddr4 gtx 1070 256gb nv...
# 13                       hp elitebook 840 g4 14 core i5 7200u 8 gb 256 gb ssd 1ge40ut#aba windows 10 pro
# 14       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 15       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 16       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 17   2017 hp fhd 15.6 wled intel core i5 7200u 3.1ghz 8gb ddr4 1tb hdd usb 3.1 802.11 ac hdmi windows...
# 18       hp zbook 15 g3 15.6 windows intel core i7 2.6 ghz 16 gb 512 gb ssd space x9v54ut#aba 10 edition
# 19   lenovo thinkpad x1 carbon 20fb002lus 14 wqhd 2560x1440 ips intel core i7 6600u 512gb ssd 16gb wi...
# 20   prostar clevo n870hp6 17.3” full hd ips intel core i7 7700hq 32gb ddr4 gtx 1060 500gb ssd 1tb hd...
# 21                               hp pavilion 15.6 full hd pc intel core i5 6200u 8gb 1tb hdd windows 10
# 22            lenovo thinkpad t470s windows 10 intel core i7 7600u 16gb 512gb ssd 14 ips wqhd 2560x1440
# 23   lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 24               hp pavilion 15.6 hd touchscreen intel core i5 8gb 1tb hdd windows 10 15 au057cl w2l56ua
# 25                   hp pavilion pc intel core i3 7100u 8gb ddr4 1tb hdd 15.6 hd touchscreen windows 10
# 26        newest hp 15.6 hd touchscreen pc intel core i3 7100u dual core 8gb ddr4 1tb hdd rw windows 10
# 27   2018 rca cambio 10.1 2 1 touchscreen tablet pc intel quad core 2gb 32gb microsoft office windows...
# 28      hp 15.6 touchscreen quad core amd a12 3.6ghz 8gb 1tb hdd 4gb amd radeon r7 hdmi windows 10 t8tjg
# 29   2016 dell inspiron 5000 touchscreen 15.6 fhd 6th intel core i5 6200u 2.8ghz 8 gb 1 tb hdd hdmi 8...
# ..                                                                                                   ...
# 170                       hp stream 14 intel celeron n3050 1.6ghz 4gb 32gb windows 10 violet refurbishd
# 171                                 lenovo ideapad 300 15.6 core i7 8 gb 1 tb hdd windows 10 80q70020us
# 172                       acer aspire 5 a517 51g 54gk intel core i5 8 gb 256 gb ssd 17.3 windows 10 home
# 173                   dell cxjv3 precision 7710 17.3 fhd intel core i7 6820hq 8gb ddr4 500gb windows 10
# 174                       acer aspire 5 a517 51g 54gk intel core i5 8 gb 256 gb ssd 17.3 windows 10 home
# 175              dell xps 13 9365 13.3 qhd touch intel core i7 7y75 16gb 512gb ssd windows 10 9x0t5 home
# 176                             hp 17.3 hd intel core i5 7200u 8gb 1tb optical hd windows 10 1kv31ua#aba
# 177              hp pavilion 15.6 hd touchscreen intel core i5 8gb 1tb hdd windows 10 15 au057cl w2l56ua
# 178                             hp 17.3 hd intel core i5 7200u 8gb 1tb optical hd windows 10 1kv31ua#aba
# 179  refurbished panasonic cf 31 toughbook intel core i5 2.5ghz 1tb ssd solid state 16gb ddr3 13.1 to...
# 180     lenovo thinkpad x1 carbon 20fb002rus 14 intel core i5 6200u 8gb 256gb ssd windows 7 professional
# 181  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 182  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 183         dell tfg4h latitude 3380 13.3 hdf intel core i3 6006u 4gb ddr4 128gb solid state windows 10
# 184          tw dell latitude 5480 14 hd intel core i5 7300hq windows 10 8gb ddr4 512gb ssd tech wizards
# 185  msi gs63 stealth 061 i7 7700hq 16gb 128gb nvme ssd 1tb hdd nvidia gtx 1050 2gb 15.6 full hd wind...
# 186  dell inspiron i5559 full hd 1920x1080 touchscreen 15.6 intel core i7 6500u 3.1ghz 8gb ddr3 250gb...
# 187  msi gs43vr phantom 069 i7 7700hq 16gb 128gb sata ssd 1tb hdd nvidia gtx 1060 6gb 14 full hd wind...
# 188                               2018 dell pc 15.6 fhd intel i7 7500u 8gb ddr4 1tb hdd hdmi windows 10
# 189           lenovo thinkpad t470s windows 10 intel core i7 7600u 16gb 512gb ssd 14 ips wqhd 2560x1440
# 190  alienware aw15r2 8469slv 15.6 uhd 6th intel core i7 16 gb 1 tb hdd 256 gb sata ssd nvidia geforc...
# 191  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 192  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 193  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 194  2018 lenovo ideapad 320 15.6 hd anti intel pentium n4200 quad core 2.5ghz 4gb 1tb hdd 802.11ac h...
# 195  lenovo thinkpad x1 carbon 20bs 14 core i5 8 gb 256 gb ssd intel hd 5500 20bs00bgus windows 7 pro...
# 196            dell inspiron 2 1 13.3 touch intel core i7 8gb 256gb ssd usa i5379 7923gry pus windows 10
# 197            dell inspiron 2 1 13.3 touch intel core i7 8gb 256gb ssd usa i5379 7923gry pus windows 10
# 198                                hp 15.6 hd pc intel core i7 6500u 8gb 1tb hdd rw hdmi dts windows 10
# 199                                hp 15.6 hd pc intel core i7 6500u 8gb 1tb hdd rw hdmi dts windows 10
#
#                                                                                     rtable_product_title  \
# 0    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 1tb nvme ssd 14 ips wqhd 2560x1440 ...
# 1    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 2tb nvme ssd 14 ips wqhd 2560x1440...
# 2    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 2tb nvme ssd 14 ips wqhd 2560x1440 ...
# 3    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 256gb nvme ssd 14 ips wqhd 2560x14...
# 4    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 1tb nvme ssd 14 ips wqhd 2560x1440...
# 5    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 1tb nvme ssd 14 ips wqhd 2560x1440...
# 6    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 2tb nvme ssd 14 ips wqhd 2560x1440...
# 7    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 256gb nvme ssd 14 ips wqhd 2560x14...
# 8    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 9    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 10               refurbished dell xps 15 9560 i7 7700hq 16gb 512gb ssd uhd 4k touch gtx 1050 fingerprint
# 11   hp pavilion 15 cc563nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 12   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 128gb ssd 1...
# 13                                                 hp zbook 15u g4 15.6 core i5 7200u 8 gb 256 gb ssd us
# 14                                                   hp zbook 15u g3 15.6 core i7 6500u 16 gb 512 gb ssd
# 15                                                   hp zbook 15 g3 15.6 core i7 6820hq 16 gb 256 gb ssd
# 16                                               hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd
# 17          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 18                                               hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd
# 19   2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7500u 180gb ssd 8gb 14 wqhd ips 2...
# 20   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 256gb nvme ...
# 21              hp pavilion 15 au030wm 15.6 manhattan touch windows 10 intel core i5 6200u 8gb 1tb drive
# 22   lenovo thinkpad x1 yoga 4g lte multimode windows 10 intel i7 7600u 512gb ssd 16gb 14 wqhd ips 25...
# 23                                            lenovo thinkpad x1 carbon 14 core i5 6200u 8 gb 180 gb ssd
# 24                    hp pavilion 15 au020wm 15.6 manhattan windows 10 intel core i5 6200u 8gb 1tb drive
# 25                              hp 15.6 touchscreen 2 1 windows 10 intel core i3 7100u 8gb 1tb assorted
# 26   hp pavilion 15 cc564nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 27                                rca cambio 10.1 2 1 tablet 32gb intel atom z3735f quad core windows 10
# 28   hp 15.6 touchscreen latest amd quad core a12 9720p 2.7 ghz 8gb ddr4 1tb hdd amd radeon r7 mouse ...
# 29       dell inspiron i5559 15.6 fhd touchscreen intel realsense 3d camera intel core i5 8 gb 1 tb hdd
# ..                                                                                                   ...
# 170                              hp stream 14 ax020nr 14 celeron 1.6ghz 4gb 32gb emmc windows 10 purple
# 171                                          lenovo legion y520 15ikbn 15.6 core i7 7700hq 8 gb 1 tb hdd
# 172                              refurbished acer intel core i5 2.50 ghz 8 gb 256 gb ssd windows 10 home
# 173                        dell latitude 3580 15.6 fhd intel core i7 7500u 8gb ddr4 500gb windows 10 pro
# 174                              refurbished acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10 home
# 175                dell 13.3 xps qhd pc intel core i7 6560u 16gb touch 512gb solid state windows 10 home
# 176  hp pavilion touchscreen hd 15.6 intel core i5 7200u 8gb 1tb b&o sound optical hd windows 10 mine...
# 177                                 hp pavilion x360 15 2 1 touch core i5 7200u 8gb 1tb hdd 15.6 full hd
# 178  hp pavilion touchscreen hd 15.6 intel core i5 7200u 8gb 1tb b&o sound optical hd windows 10 mine...
# 179  refurbished rugged panasonic toughbook cf 31 intel core i5 2.6ghz 512gb solid state 12gb ddr3 13...
# 180  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 1tb ssd 8gb 14 fhd ips 1920x1080 intel...
# 181                                             lenovo thinkpad x1 yoga 14 core i5 7200u 8 gb 256 gb ssd
# 182                                             lenovo thinkpad x1 yoga 14 core i5 7300u 8 gb 256 gb ssd
# 183                refurbished dell 3340 13.3 windows 10 intel core i3 4010u 4gb 128gb solid state drive
# 184                           dell latitude 3480 14 hd intel core i5 7200u 8gb ddr4 500gb windows 10 pro
# 185  msi gs63 stealth 061 15.6 intel core i7 7700hq 2.8ghz 16gb ddr4 1tb hdd 128gb pci e ssd gtx 1050...
# 186  dell inspiron 15.6 full hd 1920x1080 touchscreen latest intel skylake core i5 6200u 8gb 250gb ss...
# 187  msi gs43vr phantom 069 14 intel core i7 7700hq 2.8ghz 16gb ddr4 1tb hdd 128gb ssd gtx 1060 dvdâ±...
# 188                        dell latitude 3580 15.6 fhd intel core i7 7500u 8gb ddr4 500gb windows 10 pro
# 189  2017 lenovo thinkpad x1 carbon 5th gen windows 10 intel core i7 7600u 512gb ssd 8gb 14 fhd ips 1...
# 190  refurbished alienware 15 fhd 15.6 intel core i7 4710hq 16 gb 1 tb hdd 128 gb ssd nvidia geforce ...
# 191                                             lenovo thinkpad x1 yoga 14 core i5 6300u 8 gb 256 gb ssd
# 192                  lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb denim blue
# 193                                             lenovo thinkpad x1 yoga 14 core i5 6300u 8 gb 256 gb ssd
# 194               lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb platinum grey
# 195                                           lenovo thinkpad x1 carbon 14 core i7 7600u 8 gb 256 gb ssd
# 196                   dell inspiron 5379 2 1 intel core i7 8550u x4 1.8ghz 8gb 256gb ssd 13.3 win10 gray
# 197                                                  dell inspiron 2 1 13.3 intel i5 7200u 8gb 256gb ssd
# 198         2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 199                     2017 hp touchscreen 15.6 hd intel i3 7100u dual core 8gb 1tb hdd hdmi windows 10
#
#                rtable_brand     rtable_model        rtable_operating_system  \
# 0                    lenovo              NaN                      windows 7
# 1                    lenovo              NaN                      windows 7
# 2                    lenovo              NaN                      windows 7
# 3                    lenovo              NaN                      windows 7
# 4                    lenovo              NaN                      windows 7
# 5                    lenovo              NaN                      windows 7
# 6                    lenovo              NaN                      windows 7
# 7                    lenovo              NaN                      windows 7
# 8                    lenovo             2017                      windows 7
# 9                    lenovo             2017                      windows 7
# 10                     dell              NaN        windows 10 professional
# 11                       hp      1ku25ua#aba                     windows 10
# 12                  prostar           n855hj          microsoft windows 10
# 13                       hp      2hj12ut#aba                     windows 10
# 14                       hp      v1h65ut#aba                    windows 10
# 15                       hp      x9u00ut#aba                     windows 10
# 16                       hp      t6e17ut#aba                    windows 10
# 17                       hp              NaN                     windows 10
# 18                       hp      x9t82ut#aba                     windows 10
# 19                   lenovo             2017                      windows 7
# 20                  prostar           n855hj          microsoft windows 10
# 21                       hp      w2l55ua#aba                     windows 10
# 22                   lenovo              NaN                     windows 10
# 23                   lenovo       20k4002uus                      windows 7
# 24                       hp      w2l54ua#aba                     windows 10
# 25                       hp      1kt67ua#aba                     windows 10
# 26                       hp      1ku26ua#aba                     windows 10
# 27                      rca              NaN              microsoft windows
# 28                       hp              NaN              microsoft windows
# 29                     dell    i5559 4682slv                     windows 10
# ..                      ...              ...                            ...
# 170                      hp          x7s45ua                     windows 10
# 171                  lenovo       80wk001jus                     windows 10
# 172                    acer     nx.gstaa.001                     windows 10
# 173                    dell    lati3580hpm4g                     windows 10
# 174                    acer     nx.gtsaa.005                     windows 10
# 175                    dell  xps9350 8008slv                     windows 10
# 176  b & h publishing group       15 cc057cl                     windows 10
# 177                      hp              NaN           microsoft windows 10
# 178  b & h publishing group       15 cc057cl                     windows 10
# 179                      hp              NaN              microsoft windows
# 180                  lenovo              NaN                      windows 7
# 181                  lenovo       20jf000bus                    windows 10
# 182                  lenovo       20jd000rus                    windows 10
# 183                latitude        wa5 30736                     windows 10
# 184                    dell    lati3480xpmm1                     windows 10
# 185                     msi              NaN              microsoft windows
# 186                    dell              NaN                            NaN
# 187                     msi              NaN              microsoft windows
# 188                    dell    lati3580hpm4g                     windows 10
# 189                  lenovo             2017                     windows 10
# 190                    dell              NaN              microsoft windows
# 191                  lenovo       20fq0055us                    windows 10
# 192                  lenovo       80xr00alus                     windows 10
# 193                  lenovo       20fq005aus  microsoft windows windows 10
# 194                  lenovo       80xr00a7us                     windows 10
# 195                  lenovo       20hr000hus                    windows 10
# 196                    dell       1515571463                     windows 10
# 197                    dell    i5378 5896gry                    windows 10
# 198                      hp              NaN                     windows 10
# 199                      hp             2017                     windows 10
#
#                                                                                    rtable_extended_title
# 0       pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 1tb nvme ssd 14 ips wqhd 2560x1440
# 1      pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 2tb nvme ssd 14 ips wqhd 2560x1440
# 2       pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 8gb 2tb nvme ssd 14 ips wqhd 2560x1440
# 3    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 256gb nvme ssd 14 ips wqhd 2560x1440
# 4      pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 1tb nvme ssd 14 ips wqhd 2560x1440
# 5      pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 20gb 1tb nvme ssd 14 ips wqhd 2560x1440
# 6      pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 2tb nvme ssd 14 ips wqhd 2560x1440
# 7    pcie lenovo thinkpad t460s windows 7 intel core i7 6600u 12gb 256gb nvme ssd 14 ips wqhd 2560x1440
# 8    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 9    2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7600u 180gb ssd 8gb 14 wqhd ips 2...
# 10      refurbished dell xps 15 9560 i7 7700hq 16gb 512gb ssd uhd 4k touch gtx 1050 windows professional
# 11   hp pavilion 15 cc563nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 12   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 128gb ssd 1...
# 13                          hp zbook 15u g4 15.6 core i5 7200u 8 gb 256 gb ssd us 2hj12ut#aba windows 10
# 14                           hp zbook 15u g3 15.6 core i7 6500u 16 gb 512 gb ssd v1h65ut#aba windows 10
# 15                            hp zbook 15 g3 15.6 core i7 6820hq 16 gb 256 gb ssd x9u00ut#aba windows 10
# 16                       hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd t6e17ut#aba windows 10
# 17          2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 18                        hp zbook studio g3 15.6 core i7 6700hq 16 gb 512 gb ssd x9t82ut#aba windows 10
# 19   2017 lenovo thinkpad x1 carbon 5th gen windows 7 intel core i7 7500u 180gb ssd 8gb 14 wqhd ips 2...
# 20   prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1050 256gb nvme ...
# 21        hp pavilion 15 au030wm 15.6 manhattan touch windows 10 intel core i5 6200u 8gb 1tb w2l55ua#aba
# 22   lenovo thinkpad x1 yoga 4g lte multimode windows 10 intel i7 7600u 512gb ssd 16gb 14 wqhd ips 25...
# 23                       lenovo thinkpad x1 carbon 14 core i5 6200u 8 gb 180 gb ssd 20k4002uus windows 7
# 24              hp pavilion 15 au020wm 15.6 manhattan windows 10 intel core i5 6200u 8gb 1tb w2l54ua#aba
# 25                   hp 15.6 touchscreen 2 1 windows 10 intel core i3 7100u 8gb 1tb assorted 1kt67ua#aba
# 26   hp pavilion 15 cc564nr 15.6 touchscreen windows 10 intel core i3 7100u dual core 8gb 1tb hybrid ...
# 27                      rca cambio 10.1 2 1 tablet 32gb intel atom z3735f quad core windows 10 microsoft
# 28   hp 15.6 touchscreen latest amd quad core a12 9720p 2.7 ghz 8gb ddr4 1tb hdd amd radeon r7 mouse ...
# 29   dell inspiron i5559 15.6 fhd touchscreen intel realsense 3d camera intel core i5 8 gb 1 tb hdd i...
# ..                                                                                                   ...
# 170                       hp stream 14 ax020nr 14 celeron 1.6ghz 4gb 32gb emmc windows 10 purple x7s45ua
# 171                    lenovo legion y520 15ikbn 15.6 core i7 7700hq 8 gb 1 tb hdd 80wk001jus windows 10
# 172                      refurbished acer intel core i5 2.50 ghz 8 gb 256 gb ssd windows 10 nx.gstaa.001
# 173              dell latitude 3580 15.6 fhd intel core i7 7500u 8gb ddr4 500gb windows 10 lati3580hpm4g
# 174                      refurbished acer intel core i5 1.60 ghz 8 gb 256 gb ssd windows 10 nx.gtsaa.005
# 175     dell 13.3 xps qhd pc intel core i7 6560u 16gb touch 512gb solid state windows 10 xps9350 8008slv
# 176  hp pavilion touchscreen hd 15.6 intel core i5 7200u 8gb 1tb b&o sound optical hd windows 10 mine...
# 177            hp pavilion x360 15 2 1 touch core i5 7200u 8gb 1tb hdd 15.6 full hd microsoft windows 10
# 178  hp pavilion touchscreen hd 15.6 intel core i5 7200u 8gb 1tb b&o sound optical hd windows 10 mine...
# 179  refurbished rugged panasonic toughbook cf 31 intel core i5 2.6ghz 512gb solid state 12gb ddr3 13...
# 180  lenovo thinkpad x1 carbon 4 windows 7 intel core i5 6200u 1tb ssd 8gb 14 fhd ips 1920x1080 intel...
# 181                      lenovo thinkpad x1 yoga 14 core i5 7200u 8 gb 256 gb ssd 20jf000bus windows 10
# 182                      lenovo thinkpad x1 yoga 14 core i5 7300u 8 gb 256 gb ssd 20jd000rus windows 10
# 183   refurbished dell 3340 13.3 windows 10 intel core i3 4010u 4gb 128gb solid state latitude wa5 30736
# 184                 dell latitude 3480 14 hd intel core i5 7200u 8gb ddr4 500gb windows 10 lati3480xpmm1
# 185  msi gs63 stealth 061 15.6 intel core i7 7700hq 2.8ghz 16gb ddr4 1tb hdd 128gb pci e ssd gtx 1050...
# 186  dell inspiron 15.6 full hd 1920x1080 touchscreen latest intel skylake core i5 6200u 8gb 250gb ss...
# 187  msi gs43vr phantom 069 14 intel core i7 7700hq 2.8ghz 16gb ddr4 1tb hdd 128gb ssd gtx 1060 dvdâ±...
# 188              dell latitude 3580 15.6 fhd intel core i7 7500u 8gb ddr4 500gb windows 10 lati3580hpm4g
# 189  2017 lenovo thinkpad x1 carbon 5th gen windows 10 intel core i7 7600u 512gb ssd 8gb 14 fhd ips 1...
# 190  refurbished alienware 15 fhd 15.6 intel core i7 4710hq 16 gb 1 tb hdd 128 gb ssd nvidia geforce ...
# 191                      lenovo thinkpad x1 yoga 14 core i5 6300u 8 gb 256 gb ssd 20fq0055us windows 10
# 192            lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb denim 80xr00alus
# 193    lenovo thinkpad x1 yoga 14 core i5 6300u 8 gb 256 gb ssd 20fq005aus microsoft windows windows 10
# 194         lenovo ideapad 320 15.6 windows 10 intel pentium n4200 quad core 4gb 1tb platinum 80xr00a7us
# 195                    lenovo thinkpad x1 carbon 14 core i7 7600u 8 gb 256 gb ssd 20hr000hus windows 10
# 196     dell inspiron 5379 2 1 intel core i7 8550u x4 1.8ghz 8gb 256gb ssd 13.3 win10 1515571463 windows
# 197                        dell inspiron 2 1 13.3 intel i5 7200u 8gb 256gb ssd i5378 5896gry windows 10
# 198         2017 hp 17.3 hd wled backlight pc intel core i5 8gb ddr4 1tb hdd usb 3.1 hdmi rw windows 10
# 199                    2017 hp touchscreen 15.6 hd intel i3 7100u dual core 8gb 1tb hdd hdmi windows 10
#
# [200 rows x 13 columns]

# %% [markdown]
# Looking at the dedug output, we observe that the current blocking sequence does not seem to drop a lot of potential matches and has also reduced the candidate set to a good extent. Thus, we stop the blocking step and proceed with the matching step.

# %% [markdown]
# # Step 3: Reading in the labeled sample

# %% [markdown]
# We randomly sample 450 tuple pairs for labeling purposes and write the sample data to a csv. We then manually labeled the csv and use the labeled csv from then on.

# %%
# # Sample  candidate set
S = em.sample_table(C, 450)
## em.to_csv_metadata(S, 'data/labeled.csv')

# %%
# # Loading the saved labeled data
path_S = 'data/labeled.csv'
S = em.read_csv_metadata(path_S, 
                         key='_id',
                         ltable=A, rtable=B, 
                         fk_ltable='ltable_id', fk_rtable='rtable_id')

#showing some examples of labeled sample
S.head(5)
# Out:
#    _id ltable_id rtable_id  ltable_model  \
# 0    5        a0     w2300  nh.q28aa.001
# 1   26     a1011      w685         t8tjg
# 2   30      a102     w1746   c300sa dh02
# 3   44     a1031     w4581  a515 51 596k
# 4   65     a1047     w1400       n850hp6
#
#                                                                                  ltable_extended_title  \
# 0  acer predator helios 300 15.6 full hd intel core i7 7700hq 16gb ddr4 256gb ssd geforce gtx 1060 ...
# 1  2018 lenovo thinkpad 11e 4h 11.6 intel i3 7100u 128gb m.2 ssd 4gb ddr4 802.11ac win10 t8tjg windows
# 2                     asus chromebook c300sa compact 13.3 intel celeron 4gb 16gb emmc asus c300sa dh02
# 3                           acer 15.6 intel core i5 3.40ghz 8gb 256gb ssd windows 10 a515 51 596k home
# 4  prostar clevo n850hp6 15.6” fhd ips 1920x1080 intel core i7 7700hq 16gb ddr4 gtx 1060 120gb ssd ...
#
#    rtable_model  \
# 0  nh.q1caa.001
# 1         t8tjg
# 2   c300sa dh02
# 3  nx.gnpaa.016
# 4        n855hj
#
#                                                                                  rtable_extended_title  \
# 0         acer 15.6 intel core i7 2.6ghz 16 gb 1 tb hdd 256 gb ssd windows 10 g9 593 72vt nh.q1caa.001
# 1                                   dell chromebook 11 3189 11.6 celeron n3060 4 gb 64 gb ssd t8tjg os
# 2                                             c300sa dh02 cel n3060 4gb 16gb 13.3in chrome asus chrome
# 3               refurbished acer aspire 3 intel core i5 2.5 ghz 8gb 256 gb ssd windows 10 nx.gnpaa.016
# 4  prostar clevo n855hj 15.6” full hd 1920x1080 intel core i7 7700hq 8gb ddr4 gtx 1050 1tb hdd wind...
#
#    match
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1

# %% [markdown]
# # Step 4: Splitting labeled data into development and evaluation set

# %% [markdown]
# In this step, we split the labeled data set S into a development set I and an evaluation set J.

# %%
IJ = em.split_train_test(S, train_proportion=0.7, random_state=0)
I = IJ['train']
J = IJ['test']

# %% [markdown]
# # Step 5: Creating a set of ML-matchers.

# %%
# Create a set of ML-matchers
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')
nb = em.NBMatcher(name='NaiveBayes')

# %% [markdown]
# # Step 6: Selecting the best matcher using I.

# %% [markdown]
# This step includes:
#     1. Creating a feature table F.
#     2. Converting I into a set H of feature vectors (using the features in F).
#     3. Selecting the best matcher in the first iteration using cross-validation.
#     4. Debugging the matcher
#     5. Selecting the best matcher again using cross-validation.
# Repeating the steps 4 and 5 for all the debug iterations.

# %% [markdown]
# ## Initial iteration:
# ### a. Creating a feature table F.

# %%
match_t = em.get_tokenizers_for_matching([2,3,5])
match_s = em.get_sim_funs_for_matching()
atypes1 = em.get_attr_types(A)
atypes2 = em.get_attr_types(B)
match_c = em.get_attr_corres(A, B)
feature_table = em.get_features(A, B, atypes1, atypes2, match_c, match_t, match_s)

# %% [markdown]
# ### b. Converting I into a set H of feature vectors (using the features in F).

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=feature_table, 
                            attrs_after='match',
                            show_progress=False)
#Filling in the missing values if any in H.
H.fillna(0, inplace=True)

# %% [markdown]
# ### c. Selecting the best matcher in the first iteration using cross-validation

# %%
# Select the best ML matcher using CV
result = em.select_matcher(
        matchers=[dt, rf, svm, ln, lg, nb], 
        table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
        k=5,
        target_attr='match', 
        metric_to_select_matcher='precision', 
        random_state=0)
# result
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.931906        0.849995    0.888477
# 1            RF           0.923791        0.940841    0.931533
# 2           SVM           0.872856        0.970963    0.918780
# 3        LinReg           0.894443        0.935375    0.913853
# 4        LogReg           0.888296        0.932618    0.908653
# 5    NaiveBayes           0.919928        0.773327    0.839341

# %% [markdown]
# ### d. Debugging matcher

# %%
#  Split feature vectors into train and test
UV = em.split_train_test(H, train_proportion=0.5)
U = UV['train']
V = UV['test']

# %%
# Debug rf using GUI
#em.vis_debug_dt(result['selected_matcher'], U, V, 
#                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
#                target_attr='match')

# %% [markdown]
# Making features from non-attributes like the IDs of each row resulted in false positive matches due to high similarity between the ids. There are also some dirty attributes which had erroneus values resulting in false negatives.

# %% [markdown]
# ## Iteration 2:
# ### a. Creating a feature table F.

# %%
# Remove bad features from auto-feature-generation and trying different tokenizers for matching
AA = A.drop(['id','product_title','model','operating_system'],axis=1)
BB = B.drop(['id','product_title','model','operating_system'],axis=1)

match_t = em.get_tokenizers_for_matching([3,5,10])
match_s = em.get_sim_funs_for_matching()
atypes1 = em.get_attr_types(AA)
atypes2 = em.get_attr_types(BB)
match_c = em.get_attr_corres(AA, BB)
feature_table = em.get_features(AA, BB, atypes1, atypes2, match_c, match_t, match_s)

# %% [markdown]
# ### b. Converting I into a set H of feature vectors (using the features in F).

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=feature_table, 
                            attrs_after='match',
                            show_progress=False)
#Filling in the missing values if any in H.
H.fillna(0, inplace=True)

# %% [markdown]
# ### c. Selecting the best matcher using cross-validation

# %%
# Select the best ML matcher using CV
result = em.select_matcher(
        matchers=[dt, rf, svm, ln, lg, nb], 
        table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
        k=5,
        target_attr='match', 
        metric_to_select_matcher='precision', 
        random_state=0)
# result
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.910556        0.912291    0.911003
# 1            RF           0.908812        0.929106    0.917972
# 2           SVM           0.827146        0.988857    0.899620
# 3        LinReg           0.898446        0.973204    0.933452
# 4        LogReg           0.884140        0.988857    0.932342
# 5    NaiveBayes           0.911270        0.927804    0.918882

# %% [markdown]
# ### d. Debugging matcher

# %%
#  Split feature vectors into train and test
UV = em.split_train_test(H, train_proportion=0.5)
U = UV['train']
V = UV['test']
result['drill_down_cv_stats']['precision']['Matcher'][0]

# %%
# Debug rf using GUI
    #em.vis_debug_dt(result['drill_down_cv_stats']['precision']['Matcher'][0], U, V, 
#                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
#                target_attr='match')

# %% [markdown]
# Previous iteration seems to have improved F score and recall. Debugging further.
# A lot of useful information seems to be lost because of data being dirty.
# So trying to add more features using custom functions.

# %% [markdown]
# ### Iteration 3:
# ### a. Creating a feature table F.

# %%
# Remove bad features from auto-feature-generation and trying different tokenizers for matching
AA = A.drop(['id','product_title','model','operating_system'],axis=1)
BB = B.drop(['id','product_title','model','operating_system'],axis=1)
match_t = em.get_tokenizers_for_matching([3,5,10])
match_s = em.get_sim_funs_for_matching()
atypes1 = em.get_attr_types(AA)
atypes2 = em.get_attr_types(BB)
match_c = em.get_attr_corres(AA, BB)
feature_table = em.get_features(AA, BB, atypes1, atypes2, match_c, match_t, match_s)

# %% [markdown]
# This function generates a function that returns 1 if both or neither tuples' attribute contain any of the passed in values and 0 otherwise.

# %%
def generateContainsValueFeature(values, name=None, attribute='extended_title'):
    if type(values) is str:
        values = [values]
    def containsValueFeature(a,b):
        return int(any([value.lower() in a[attribute].lower() for value in values]) 
                   == any([value.lower() in b[attribute].lower() for value in values]))
    return containsValueFeature, name if name else values[0]

# %% [markdown]
# Use this to generate many new features.

# %%
brands = ['lg','toshiba','hp','dell','lenovo','prostar','acer','samsung','apple','asus','panasonic','msi']
models = ['zephyrus','zenbook','flex','omen','xps','x1','carbon','yoga',
          'latitude','inspiron','elitebook','clevo','spectre',
          'macbook','pavilion','ideapad','legion']
thinkpads = [['p40','p50','p51','p71'],['430','460','470','560','570']]
asus = ['swift','aspire','spin']
models = models + thinkpads + asus
sizes = [' 13',' 14',' 15',' 17']
operating_systems = ['chrome','windows','mac']
cpus = [['i3','i5','i7'],['celeron','pentium'],['m3','m5'],'amd']
miscellaneous = ['2-in-1','gtx','touch']
keywords = models \
    + sizes  \
    + operating_systems \
    + cpus \
    + miscellaneous
new_features = [generateContainsValueFeature(value) for value in keywords]

for feature in new_features:
    em.add_blackbox_feature(feature_table, feature[1], feature[0])

# %% [markdown]
# This function generates a function that returns 1 if both tuples contain the same value for any of the values passed in and 0 otherwise.

# %%
def generateContainsValueFromValuesetFeature(valueset, name=None, attribute='extended_title'):
    def sharesValue(a,b,values):
        if type(values) is str:
            values = [values]
        return int(any([value.lower() in a[attribute].lower() and value.lower() in b[attribute].lower() for value in values]))
    def containsValueFromValueset(a,b):
        return any([sharesValue(a,b,values) for values in valueset[1]])
    return containsValueFromValueset, valueset[0]

# %%
valuesets = [('brands',brands), 
             ('models', models), 
             ('sizes', sizes), 
             ('cpus', cpus), 
             ('operating_systems',operating_systems)]

new_features = [generateContainsValueFromValuesetFeature(valueset) for valueset in valuesets]

for feature in new_features:
    em.add_blackbox_feature(feature_table, feature[1], feature[0])

# %% [markdown]
# ### b. Converting I into a set H of feature vectors (using the features in F).

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=feature_table, 
                            attrs_after='match',
                            show_progress=False)
#Filling in the missing values if any in H.
H.fillna(0, inplace=True)

# %% [markdown]
# ### c. Selecting the best matcher using cross-validation

# %%
# Select the best ML matcher using CV
result = em.select_matcher(
        matchers=[dt, rf, svm, ln, lg, nb], 
        table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'],
        k=5,
        target_attr='match', 
        metric_to_select_matcher='precision', 
        random_state=0)
# result
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.954048        0.937980    0.945281
# 1            RF           0.963564        0.972000    0.967336
# 2           SVM           0.893285        0.992000    0.939676
# 3        LinReg           0.962487        0.952694    0.957178
# 4        LogReg           0.913782        0.960000    0.935088
# 5    NaiveBayes           0.946487        0.942230    0.943907

# %% [markdown]
# Previous iteration seems to have improved F score, precision, and recall. Stopping further debugging.

# %% [markdown]
# # Step 7: Evaluating the best matcher Y using J.
#
# This step includes:
# 1. Converting J into a set L of feature vectors.
# 2. Filling in the missing values if any in L.
# 3. Training the best matcher Y using I.
# 4. Computing the accuracy of Y

# %% [markdown]
# ## a. Converting J into a set L of feature vectors.

# %% [markdown]
# As before, we convert to the feature vectors (using the feature table and the evaluation set)

# %%
# Convert J into a set of feature vectors using feature table
L = em.extract_feature_vecs(
        J, 
        feature_table=feature_table,
        attrs_after='match', 
        show_progress=False)

# %% [markdown]
# ## b. Filling in the missing values if any in L.

# %%
#Filling in the missing values if any in L.
L.fillna(0, inplace=True)

# %% [markdown]
# ## c. Predicting the matches
#
# ### For each of the six learning methods, we train the matcher based on that method on I, and then report its precision/recall/F-1 on J.

# %%
for i in range (0,6):
    learning_method = result['drill_down_cv_stats']['precision']['Matcher'][i]
    
    # we train the matcher based on that method on I
    learning_method.fit(table=H, 
           exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'], 
           target_attr='match')

    # we then report its precision/recall/F-1 on J.
    predictions = learning_method.predict(
            table=L, 
            exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'], 
            append=True, 
            target_attr='predicted', 
            inplace=False)

    # Evaluate the predictions
    eval_result = em.eval_matches(predictions, 'match', 'predicted')
    print('Learning method:' + result['drill_down_cv_stats']['precision']['Name'][i])
    em.print_eval_summary(eval_result)
    print('')
# Out:
# Learning method:DecisionTree
# Precision : 93.62% (88/94)
# Recall : 94.62% (88/93)
# F1 : 94.12%
# False positives : 6 (out of 94 positive predictions)
# False negatives : 5 (out of 41 negative predictions)
#
# Learning method:RF
# Precision : 94.51% (86/91)
# Recall : 92.47% (86/93)
# F1 : 93.48%
# False positives : 5 (out of 91 positive predictions)
# False negatives : 7 (out of 44 negative predictions)
#
# Learning method:SVM
# Precision : 80.56% (87/108)
# Recall : 93.55% (87/93)
# F1 : 86.57%
# False positives : 21 (out of 108 positive predictions)
# False negatives : 6 (out of 27 negative predictions)
#
# Learning method:LinReg
# Precision : 93.68% (89/95)
# Recall : 95.7% (89/93)
# F1 : 94.68%
# False positives : 6 (out of 95 positive predictions)
# False negatives : 4 (out of 40 negative predictions)
#
# Learning method:LogReg
# Precision : 88.78% (87/98)
# Recall : 93.55% (87/93)
# F1 : 91.1%
# False positives : 11 (out of 98 positive predictions)
# False negatives : 6 (out of 37 negative predictions)
#
# Learning method:NaiveBayes
# Precision : 93.55% (87/93)
# Recall : 93.55% (87/93)
# F1 : 93.55%
# False positives : 6 (out of 93 positive predictions)
# False negatives : 6 (out of 42 negative predictions)

# %% [markdown]
# ### For the final best matcher Y selected, train it on I, then report its precision/recall/F-1 on J.

# %%
# Train best matcher on I 
print ('Final best matcher Y:')
result['selected_matcher'].fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'], 
       target_attr='match')

# Predict on L 
predictions = result['selected_matcher'].predict(
        table=L, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'match'], 
        append=True, 
        target_attr='predicted', 
        inplace=False)

# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'match', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Final best matcher Y:
# Precision : 94.51% (86/91)
# Recall : 92.47% (86/93)
# F1 : 93.48%
# False positives : 5 (out of 91 positive predictions)
# False negatives : 7 (out of 44 negative predictions)
